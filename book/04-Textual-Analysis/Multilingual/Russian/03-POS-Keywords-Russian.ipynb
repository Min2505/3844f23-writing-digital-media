# %% [markdown]
# # Part-of-Speech Tagging for Russian

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# In this lesson, we're going to learn about the textual analysis methods *part-of-speech tagging* and *keyword extraction* for Russian-language texts. These methods will help us computationally parse sentences and better understand words in context.

# %% [markdown]
# ---

# %% [markdown]
# ## spaCy and Natural Language Processing (NLP)

# %% [markdown]
# To computationally identify parts of speech, we're going to use the natural language processing library spaCy. For a more extensive introduction to NLP and spaCy, see the previous lesson.
#
# To parse sentences, spaCy relies on machine learning models that were trained on large amounts of labeled text data. If you've used the preprocessing or named entity recognition notebooks for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ## Install spaCy

# %% [markdown]
# To use spaCy, we first need to install the library.
#
# Russian models are only available starting in spaCy 3.0.
#
# If you run into errors because spaCy 2.x is installed, you can run `!pip uninstall spacy -y` first, then run the cell below.

# %%
# !pip install -U spacy>=3.0

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Then we're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 400
pd.options.display.max_colwidth = 400

# %% [markdown]
# We're also going to import the `Counter` module for counting nouns, verbs, adjectives, etc., and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ## Download Language Model

# %% [markdown]
# Next we need to download the Russian-language model (`ru_core_news_md`), which will be processing and making predictions about our texts. You can read more about the corpus it was trained on, on the [spaCy model page](https://spacy.io/models/ru). You can download the `ru_core_news_md` model by running the cell below:

# %%
# !python -m spacy download ru_core_news_md
# Out:
# Collecting ru-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_md-3.7.0/ru_core_news_md-3.7.0-py3-none-any.whl (41.9 MB)
#      ---------------------------------------- 0.0/41.9 MB ? eta -:--:--
#      ---------------------------------------- 0.4/41.9 MB 8.7 MB/s eta 0:00:05
#       --------------------------------------- 0.9/41.9 MB 9.7 MB/s eta 0:00:05
#      - -------------------------------------- 1.4/41.9 MB 10.8 MB/s eta 0:00:04
#      - -------------------------------------- 1.8/41.9 MB 9.7 MB/s eta 0:00:05
#      -- ------------------------------------- 2.3/41.9 MB 9.8 MB/s eta 0:00:05
#      -- ------------------------------------- 2.7/41.9 MB 9.6 MB/s eta 0:00:05
#      --- ------------------------------------ 3.4/41.9 MB 10.2 MB/s eta 0:00:04
#      --- ------------------------------------ 3.8/41.9 MB 10.5 MB/s eta 0:00:04
#      --- ------------------------------------ 4.1/41.9 MB 10.1 MB/s eta 0:00:04
#      ---- ----------------------------------- 4.6/41.9 MB 10.1 MB/s eta 0:00:04
#      ---- ----------------------------------- 5.0/41.9 MB 10.0 MB/s eta 0:00:04
#      ----- ---------------------------------- 5.3/41.9 MB 9.8 MB/s eta 0:00:04
#      ----- ---------------------------------- 5.8/41.9 MB 9.7 MB/s eta 0:00:04
#      ----- ---------------------------------- 6.2/41.9 MB 9.7 MB/s eta 0:00:04
#      ------ --------------------------------- 6.6/41.9 MB 9.6 MB/s eta 0:00:04
#      ------ --------------------------------- 6.7/41.9 MB 9.5 MB/s eta 0:00:04
#      ------ --------------------------------- 7.3/41.9 MB 9.3 MB/s eta 0:00:04
#      ------- -------------------------------- 7.8/41.9 MB 9.3 MB/s eta 0:00:04
#      ------- -------------------------------- 8.2/41.9 MB 9.4 MB/s eta 0:00:04
#      -------- ------------------------------- 8.7/41.9 MB 9.5 MB/s eta 0:00:04
#      -------- ------------------------------- 9.3/41.9 MB 9.6 MB/s eta 0:00:04
#      --------- ------------------------------ 9.8/41.9 MB 9.6 MB/s eta 0:00:04
#      --------- ------------------------------ 10.3/41.9 MB 9.6 MB/s eta 0:00:04
#      ---------- ----------------------------- 10.7/41.9 MB 9.6 MB/s eta 0:00:04
#      ---------- ----------------------------- 11.2/41.9 MB 9.6 MB/s eta 0:00:04
#      ----------- ---------------------------- 11.7/41.9 MB 9.8 MB/s eta 0:00:04
#      ----------- ---------------------------- 12.1/41.9 MB 9.6 MB/s eta 0:00:04
#      ------------ --------------------------- 12.7/41.9 MB 9.6 MB/s eta 0:00:04
#      ------------ --------------------------- 13.2/41.9 MB 9.8 MB/s eta 0:00:03
#      ------------- -------------------------- 13.7/41.9 MB 9.8 MB/s eta 0:00:03
#      ------------- -------------------------- 14.2/41.9 MB 9.8 MB/s eta 0:00:03
#      ------------- -------------------------- 14.5/41.9 MB 9.9 MB/s eta 0:00:03
#      -------------- ------------------------ 15.1/41.9 MB 10.1 MB/s eta 0:00:03
#      -------------- ------------------------ 15.6/41.9 MB 10.1 MB/s eta 0:00:03
#      -------------- ------------------------ 16.1/41.9 MB 10.2 MB/s eta 0:00:03
#      --------------- ----------------------- 16.5/41.9 MB 10.2 MB/s eta 0:00:03
#      --------------- ----------------------- 17.1/41.9 MB 10.7 MB/s eta 0:00:03
#      ---------------- ---------------------- 17.6/41.9 MB 10.7 MB/s eta 0:00:03
#      ---------------- ---------------------- 18.1/41.9 MB 10.7 MB/s eta 0:00:03
#      ----------------- --------------------- 18.6/41.9 MB 10.7 MB/s eta 0:00:03
#      ----------------- --------------------- 19.2/41.9 MB 10.7 MB/s eta 0:00:03
#      ------------------ -------------------- 19.7/41.9 MB 10.7 MB/s eta 0:00:03
#      ------------------ -------------------- 20.1/41.9 MB 10.7 MB/s eta 0:00:03
#      ------------------- ------------------- 20.6/41.9 MB 10.7 MB/s eta 0:00:02
#      ------------------- ------------------- 21.1/41.9 MB 10.7 MB/s eta 0:00:02
#      -------------------- ------------------ 21.6/41.9 MB 10.7 MB/s eta 0:00:02
#      -------------------- ------------------ 22.0/41.9 MB 10.7 MB/s eta 0:00:02
#      --------------------- ----------------- 22.6/41.9 MB 10.7 MB/s eta 0:00:02
#      --------------------- ----------------- 23.2/41.9 MB 10.9 MB/s eta 0:00:02
#      ---------------------- ---------------- 23.7/41.9 MB 10.7 MB/s eta 0:00:02
#      ---------------------- ---------------- 24.2/41.9 MB 10.7 MB/s eta 0:00:02
#      ----------------------- --------------- 24.8/41.9 MB 10.9 MB/s eta 0:00:02
#      ----------------------- --------------- 25.2/41.9 MB 10.9 MB/s eta 0:00:02
#      ----------------------- --------------- 25.7/41.9 MB 10.9 MB/s eta 0:00:02
#      ------------------------ -------------- 26.2/41.9 MB 10.9 MB/s eta 0:00:02
#      ------------------------ -------------- 26.7/41.9 MB 10.9 MB/s eta 0:00:02
#      ------------------------- ------------- 27.2/41.9 MB 10.9 MB/s eta 0:00:02
#      ------------------------- ------------- 27.8/41.9 MB 10.9 MB/s eta 0:00:02
#      -------------------------- ------------ 28.3/41.9 MB 10.9 MB/s eta 0:00:02
#      -------------------------- ------------ 28.8/41.9 MB 10.9 MB/s eta 0:00:02
#      --------------------------- ----------- 29.3/41.9 MB 10.9 MB/s eta 0:00:02
#      --------------------------- ----------- 29.7/41.9 MB 10.7 MB/s eta 0:00:02
#      ---------------------------- ---------- 30.3/41.9 MB 10.7 MB/s eta 0:00:02
#      ---------------------------- ---------- 30.7/41.9 MB 10.9 MB/s eta 0:00:02
#      ----------------------------- --------- 31.2/41.9 MB 10.9 MB/s eta 0:00:01
#      ----------------------------- --------- 31.7/41.9 MB 10.9 MB/s eta 0:00:01
#      ----------------------------- --------- 32.2/41.9 MB 10.9 MB/s eta 0:00:01
#      ------------------------------ -------- 32.6/41.9 MB 10.7 MB/s eta 0:00:01
#      ------------------------------ -------- 33.1/41.9 MB 10.7 MB/s eta 0:00:01
#      ------------------------------- ------- 33.5/41.9 MB 10.6 MB/s eta 0:00:01
#      ------------------------------- ------- 34.0/41.9 MB 10.6 MB/s eta 0:00:01
#      -------------------------------- ------ 34.5/41.9 MB 10.6 MB/s eta 0:00:01
#      -------------------------------- ------ 35.0/41.9 MB 10.6 MB/s eta 0:00:01
#      --------------------------------- ----- 35.6/41.9 MB 10.7 MB/s eta 0:00:01
#      --------------------------------- ----- 36.1/41.9 MB 10.6 MB/s eta 0:00:01
#      --------------------------------- ----- 36.4/41.9 MB 10.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 36.7/41.9 MB 10.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 37.3/41.9 MB 10.4 MB/s eta 0:00:01
#      ----------------------------------- --- 37.8/41.9 MB 10.4 MB/s eta 0:00:01
#      ----------------------------------- --- 38.3/41.9 MB 10.4 MB/s eta 0:00:01
#      ------------------------------------ -- 38.7/41.9 MB 10.2 MB/s eta 0:00:01
#      ------------------------------------ -- 39.2/41.9 MB 10.2 MB/s eta 0:00:01
#      ------------------------------------- - 39.8/41.9 MB 10.4 MB/s eta 0:00:01
#      ------------------------------------- - 40.2/41.9 MB 10.2 MB/s eta 0:00:01
#      ------------------------------------- - 40.7/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.2/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.8/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.9/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.9/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.9/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.9/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.9/41.9 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  41.9/41.9 MB 10.2 MB/s eta 0:00:01
#      ---------------------------------------- 41.9/41.9 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\minh\anaconda3\lib\site-packages (from ru-core-news-md==3.7.0) (3.7.2)
# Requirement already satisfied: pymorphy3>=1.0.0 in c:\users\minh\anaconda3\lib\site-packages (from ru-core-news-md==3.7.0) (1.2.1)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\minh\anaconda3\lib\site-packages (from pymorphy3>=1.0.0->ru-core-news-md==3.7.0) (0.7.2)
# Requirement already satisfied: docopt-ng>=0.6 in c:\users\minh\anaconda3\lib\site-packages (from pymorphy3>=1.0.0->ru-core-news-md==3.7.0) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in c:\users\minh\anaconda3\lib\site-packages (from pymorphy3>=1.0.0->ru-core-news-md==3.7.0) (2.4.417150.4580142)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\minh\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\minh\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\minh\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\minh\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\minh\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\minh\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\minh\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\minh\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\minh\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->ru-core-news-md==3.7.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_md')

# %% [markdown]
# *Note: spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including German, French, Spanish, Portuguese, Russian, Italian, Dutch, Greek, Norwegian, and Lithuanian*.
#
# *spaCy offers language and tokenization support for other language via external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean.*

# %% [markdown]
# ## Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it with `spacy.load()` and assign it to the variable `nlp`.

# %%
nlp = spacy.load('ru_core_news_md')

# %% [markdown]
# ## Create a Processed spaCy Document

# %% [markdown]
# Whenever we use spaCy, our first step will be to create a processed spaCy `document` with the loaded NLP model `nlp()`. Most of the heavy NLP lifting is done in this line of code. After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.

# %%
filepath = '../texts/ru.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## spaCy Part-of-Speech Tagging
# The tags that spaCy uses for part-of-speech are based on work done by [Universal Dependencies](https://universaldependencies.org/), an effort to create a set of part-of-speech tags that work across many different languages. Texts from various languages are annotated using this common set of tags, and contributed to a common repository that can be used to train models like spaCy.
#
# The Universal Dependencies page has information about the annotated corpora available for each language; it's worth looking into the corpora that were annotated for your language.

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# Above is a POS chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different parts of speech that spaCy can identify as well as their corresponding labels. To quickly see spaCy's POS tagging in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) on our sample `document` with the `style=` parameter set to "dep" (short for dependency parsing):

# %% [markdown]
# ## Get Part-Of-Speech Tags

# %% [markdown]
# To get part of speech tags for every word in a document, we have to iterate through all the tokens in the document and pull out the `.lemma_` attribute for each token, which gives us the un-inflected version of the word. We'll also pull out the  `.pos_` attribute for each token. We can get even finer-grained dependency information with the attribute `.dep_`.

# %%
for token in document:
    print(token.lemma_, token.pos_, token.dep_)
# Out:
# яблони PROPN nsubj
# цвести VERB ROOT
# * PUNCT punct
#
#
#  SPACE dep
# i ADJ amod
#
#  SPACE dep
# зачем ADV advmod
# она PRON nsubj
# так ADV advmod
# сделать VERB conj
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# не PART advmod
# уметь VERB ccomp
# жить VERB xcomp
# без ADP case
# нее PRON obl
# ? PUNCT punct
# это PRON obj
# она PRON nsubj
# сделать VERB ROOT
# , PUNCT punct
# я PRON nsubj
# не PART advmod
# виноватый ADJ conj
# … PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# написать VERB ROOT
# это PRON obj
# – PUNCT punct
# и CCONJ cc
# мне PRON iobj
# стать VERB parataxis
# странный ADJ xcomp
# . PUNCT punct
# говорить VERB ROOT
# точно ADV advmod
# о ADP case
# возлюбленной NOUN obl
# . PUNCT punct
# но CCONJ cc
# возлюбленной NOUN nsubj
# у ADP case
# меня PRON obl
# нет VERB ROOT
# . PUNCT punct
# это PRON obj
# мой DET det
# мать NOUN nsubj
# сделать VERB ROOT
# так ADV advmod
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# умирать VERB advcl
# без ADP case
# нее PRON obl
# . PUNCT punct
# если SCONJ mark
# человек NOUN obj
# держать VERB advcl
# в ADP case
# тепло NOUN obl
# весь DET det
# жизнь NOUN obj
# , PUNCT punct
# а CCONJ cc
# потом ADV advmod
# неодетый ADJ conj
# выгнать VERB xcomp
# на ADP case
# двадцатиградусный ADJ amod
# мороз NOUN obl
# , PUNCT punct
# он PRON nsubj
# непременно ADV advmod
# умереть VERB ROOT
# . PUNCT punct
# и CCONJ cc
# я PRON nsubj
# умереть VERB ROOT
# . PUNCT punct
# умру VERB ROOT
# из ADP case
# - ADP case
# за ADP case
# нее PRON nmod
# . PUNCT punct
#
#
#  SPACE dep
# давно ADV advmod
# уж PART advmod
# мне PRON iobj
# хотеться VERB ROOT
# рассказать VERB xcomp
# кто PRON iobj
# - PRON iobj
# нибудь PRON iobj
# все PRON obj
# , PUNCT punct
# о ADP case
# что PRON obl
# я PRON nsubj
# думать VERB acl:relcl
# , PUNCT punct
# или CCONJ cc
# хоть ADV advmod
# написать VERB conj
# . PUNCT punct
# рассказать VERB xcomp
# некому NOUN obj
# , PUNCT punct
# никто PRON nsubj
# не PART advmod
# хотеть VERB ROOT
# , PUNCT punct
# чтобы SCONJ mark
# я PRON nsubj
# рассказывать VERB ccomp
# , PUNCT punct
# так ADV advmod
# уж PART advmod
# хороший ADJ advmod
# я PRON nsubj
# написать VERB ccomp
# . PUNCT punct
# Все PART advmod
# - PART advmod
# таки PART advmod
# лёгкий ADJ ROOT
# . PUNCT punct
#
#
#  SPACE dep
# мне PRON iobj
# казаться VERB ROOT
# , PUNCT punct
# что SCONJ mark
# этот DET det
# последний ADJ amod
# день NOUN nsubj
# – PUNCT punct
# важный ADJ amod
# и CCONJ cc
# значительный ADJ conj
# день NOUN ccomp
# для ADP case
# меня PRON nmod
# . PUNCT punct
# я PRON nsubj
# до ADP case
# что PRON obl
# - PRON obj
# то PRON obl
# дойти VERB ROOT
# , PUNCT punct
# кончить VERB conj
# половина NOUN obj
# мой DET det
# жизнь NOUN nmod
# , PUNCT punct
# а CCONJ cc
# далёкий ADV advmod
# дорога NOUN nsubj
# прямой ADJ amod
# , PUNCT punct
# унылый ADJ conj
# , PUNCT punct
# быстрый ADJ conj
# и CCONJ cc
# такой DET det
# однообразный ADJ conj
# , PUNCT punct
# что PRON mark
# уже ADV advmod
# нельзя ADV acl:relcl
# быть AUX cop
# заметить VERB csubj
# , PUNCT punct
# идти VERB ccomp
# ли PART advmod
# вперёд ADV advmod
# или CCONJ cc
# назад ADV conj
# , PUNCT punct
# вверх ADV conj
# или CCONJ cc
# вниз ADV conj
# . PUNCT punct
# и CCONJ cc
# не PART advmod
# знать VERB ROOT
# , PUNCT punct
# нужный ADJ obl
# ли PART advmod
# покориться VERB csubj
# , PUNCT punct
# как SCONJ mark
# всегда ADV advmod
# , PUNCT punct
# и CCONJ cc
# идти VERB conj
# по ADP case
# ней PRON obl
# . PUNCT punct
#
#
#  SPACE dep
# мне PRON iobj
# теперь ADV advmod
# двадцать NUM nummod:gov
# восемь NUM nummod:gov
# год NOUN ROOT
# , PUNCT punct
# но CCONJ cc
# никто PRON nsubj
# это PRON iobj
# не PART advmod
# верить VERB conj
# , PUNCT punct
# такой DET det
# старый ADJ xcomp
# я PRON nsubj
# кадиться VERB conj
# . PUNCT punct
# я PRON nsubj
# сам ADJ acl
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# старик VERB ccomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# быть VERB ROOT
# прежде ADV advmod
# красивый ADJ amod
# и CCONJ cc
# нежный ADJ conj
# лицо NOUN nsubj
# , PUNCT punct
# как SCONJ case
# у ADP case
# мама NOUN nmod
# , PUNCT punct
# мы PRON nsubj
# с ADP case
# ней PRON obl
# часто ADV advmod
# вместе ADV advmod
# смотреться VERB conj
# в ADP case
# зеркало NOUN obl
# , PUNCT punct
# и CCONJ cc
# нам PRON iobj
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# мы PRON nsubj
# удивительно ADV advmod
# похожий ADJ ccomp
# друг PRON obl
# на ADP fixed
# друга PRON fixed
# . PUNCT punct
#
#
#  SPACE dep
# теперь ADV advmod
# она PRON nsubj
# не PART advmod
# узнать VERB ROOT
# бы AUX aux
# меня PRON obj
# . PUNCT punct
# я PRON nsubj
# согнуться VERB ROOT
# , PUNCT punct
# глаз NOUN nsubj
# потускнуть VERB conj
# , PUNCT punct
# борода NOUN nsubj
# вырасти VERB conj
# больший ADJ nsubj
# , PUNCT punct
# лицо NOUN nsubj
# стать VERB conj
# жёлтый ADJ xcomp
# , PUNCT punct
# тёмный ADJ conj
# . PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# скоро ADV advmod
# умереть VERB ccomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# нет VERB ROOT
# , PUNCT punct
# казаться VERB parataxis
# , PUNCT punct
# никакой DET det
# болезнь NOUN nsubj
# , PUNCT punct
# но CCONJ cc
# я PRON nsubj
# должный ADJ conj
# умереть VERB xcomp
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# жить VERB advcl
# тот DET nsubj
# , PUNCT punct
# кто PRON nsubj
# хотеть VERB acl:relcl
# , PUNCT punct
# кто PRON nsubj
# иметь VERB ccomp
# воля NOUN obj
# жить VERB nmod
# , PUNCT punct
# а CCONJ cc
# у ADP case
# меня PRON obl
# нет VERB conj
# воля NOUN nsubj
# . PUNCT punct
# в ADP case
# последний ADJ amod
# день NOUN obl
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# это PRON obj
# сознал VERB acl:relcl
# и CCONJ cc
# увидеть VERB conj
# , PUNCT punct
# что SCONJ mark
# мне PRON iobj
# больше ADV advmod
# и CCONJ cc
# ждать VERB conj
# нечего VERB ROOT
# – PUNCT punct
# я PRON nsubj
# даже PART advmod
# думать VERB parataxis
# о ADP case
# самоубийство NOUN obl
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# не PART advmod
# мочь VERB ROOT
# . PUNCT punct
# я PRON nsubj
# бояться VERB ROOT
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# у ADP case
# меня PRON ccomp
# пошлый ADJ amod
# и CCONJ cc
# трусливый ADJ conj
# сердце NOUN nsubj
# . PUNCT punct
# я PRON nsubj
# бояться VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# весь DET det
# это PRON obj
# она PRON nsubj
# сделать VERB ROOT
# . PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# – PUNCT punct
# что SCONJ mark
# от ADP case
# нее PRON obl
# же PART advmod
# у ADP case
# меня PRON obl
# тот DET det
# чувство NOUN nsubj
# , PUNCT punct
# которое PRON nsubj
# совсем ADV advmod
# не PART advmod
# пойти VERB acl:relcl
# , PUNCT punct
# и CCONJ cc
# одно NUM nsubj
# давать VERB ccomp
# мне PRON iobj
# счастие NOUN obj
# жизнь NOUN nmod
# – PUNCT punct
# сентиментальность NOUN appos
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# стыдиться VERB ROOT
# это DET det
# слово NOUN obj
# , PUNCT punct
# как SCONJ mark
# все PRON nsubj
# стыдиться VERB acl
# . PUNCT punct
# да PART parataxis
# , PUNCT punct
# все PRON nsubj
# стыдиться VERB ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# у ADP case
# всех PRON obl
# оно PRON nsubj
# быть VERB advcl
# … PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# музыкант NOUN ROOT
# и CCONJ cc
# если SCONJ mark
# не PART advmod
# хороший ADJ advcl
# , PUNCT punct
# то SCONJ mark
# порядочный ADJ amod
# , PUNCT punct
# как SCONJ mark
# говорить VERB parataxis
# . PUNCT punct
# думать VERB parataxis
# , PUNCT punct
# хороший ADJ ROOT
# я PRON nsubj
# и CCONJ cc
# не PART advmod
# мочь VERB conj
# быть VERB xcomp
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# , PUNCT punct
# когда SCONJ mark
# играть VERB advcl
# длинный ADJ amod
# , PUNCT punct
# трудный ADJ conj
# рапсодия NOUN obj
# и CCONJ cc
# фуга NOUN conj
# , PUNCT punct
# даже PART advmod
# соната NOUN conj
# , PUNCT punct
# я PRON nsubj
# совершенно ADV advmod
# холодный ADJ advcl
# , PUNCT punct
# и CCONJ cc
# мысль NOUN discourse
# у ADP case
# меня PRON conj
# самые ADJ amod
# обыденный ADJ nsubj
# , PUNCT punct
# скучный ADJ conj
# . PUNCT punct
# чувство NOUN nsubj
# прекрасный ADJ nmod
# редко ADV advmod
# бывать VERB ROOT
# у ADP case
# меня PRON obl
# ; PUNCT punct
# это PRON nsubj
# – PUNCT punct
# совсем ADV advmod
# не PART advmod
# сентиментальный ADJ amod
# чувство NOUN conj
# , PUNCT punct
# оно PRON nsubj
# захватывать VERB conj
# и CCONJ cc
# звать VERB conj
# вперёд ADV advmod
# , PUNCT punct
# а CCONJ cc
# мне PRON iobj
# это PRON nsubj
# трудный ADJ conj
# ; PUNCT punct
# я PRON nsubj
# любить VERB conj
# тихий ADJ amod
# умиление NOUN obj
# , PUNCT punct
# воспоминание NOUN conj
# , PUNCT punct
# когда SCONJ mark
# так ADV advmod
# сладко ADV advmod
# болеть VERB acl:relcl
# сердце NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# в ADP case
# душа NOUN conj
# глубокий ADJ amod
# тишина NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# бывать VERB parataxis
# , PUNCT punct
# играть VERB advcl
# блестеть VERB amod
# прелюдия NOUN obj
# в ADP case
# концерт NOUN nmod
# ( PUNCT punct
# теперь ADV advmod
# уж PART advmod
# давно ADV advmod
# я PRON nsubj
# не PART advmod
# выходить VERB parataxis
# на ADP case
# эстрада NOUN obl
# ) PUNCT punct
# , PUNCT punct
# я PRON nsubj
# взглядывать VERB ROOT
# на ADP case
# какой DET det
# - DET det
# нибудь DET det
# пожилой ADJ amod
# господин NOUN obl
# в ADP case
# первый ADJ amod
# ряд NOUN obl
# и CCONJ cc
# думать VERB conj
# : PUNCT punct
# " PUNCT punct
# вот PART advmod
# ты PRON nsubj
# смотреть VERB parataxis
# на ADP case
# меня PRON obl
# , PUNCT punct
# слушать VERB conj
# внимательно ADV advmod
# и CCONJ cc
# знать VERB conj
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# играть VERB ccomp
# , PUNCT punct
# потом ADV advmod
# быть AUX aux
# делать VERB conj
# толковый ADJ amod
# замечание NOUN obj
# о ADP case
# мой DET det
# „ PUNCT punct
# техника NOUN nmod
# “ PUNCT punct
# и CCONJ cc
# „ PUNCT punct
# экспрессия NOUN conj
# … PUNCT punct
# “ PUNCT punct
# а CCONJ cc
# если SCONJ mark
# бы AUX aux
# я PRON nsubj
# бросить VERB ROOT
# теперь ADV advmod
# этот DET det
# прелюдия NOUN obj
# и CCONJ cc
# сыграть VERB conj
# маленький ADJ amod
# , PUNCT punct
# простой ADJ conj
# малороссийский ADJ amod
# песенка NOUN obj
# , PUNCT punct
# которая PRON nsubj
# напомнить VERB acl:relcl
# бы AUX aux
# тебе PRON iobj
# далёкий ADJ amod
# год NOUN obj
# , PUNCT punct
# тёмный ADJ amod
# , PUNCT punct
# тёплый ADJ conj
# сад NOUN conj
# и CCONJ cc
# , PUNCT punct
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# чей DET det
# - DET det
# нибудь DET advmod
# милый ADJ amod
# , PUNCT punct
# забыть VERB conj
# глаз NOUN conj
# – PUNCT punct
# ты PRON nsubj
# встать VERB parataxis
# бы AUX aux
# и CCONJ cc
# уйти VERB conj
# , PUNCT punct
# чтобы SCONJ mark
# скрыть VERB advcl
# невольный ADJ amod
# слеза NOUN obj
# , PUNCT punct
# радостную VERB amod
# грусть NOUN conj
# и CCONJ cc
# счастие NOUN conj
# , PUNCT punct
# которого PRON obj
# не PART advmod
# давать VERB acl:relcl
# тебе PRON iobj
# блестеть VERB amod
# прелюдия NOUN obj
# . PUNCT punct
# и CCONJ cc
# непременно ADV advmod
# ты PRON nsubj
# хотеть VERB ROOT
# бы AUX aux
# скрыть VERB xcomp
# это DET det
# счастие NOUN obj
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# тебе PRON iobj
# стыдно ADV advcl
# и CCONJ cc
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# ты PRON nsubj
# один DET obj
# так ADV advmod
# чувствовать VERB ccomp
# и CCONJ cc
# другие ADJ nsubj
# не PART advmod
# понять VERB conj
# , PUNCT punct
# а CCONJ cc
# между ADP case
# тем PRON obl
# все PRON nsubj
# так ADV advmod
# же PART advmod
# чувствовать VERB conj
# – PUNCT punct
# и CCONJ cc
# каждый DET nsubj
# стыдится VERB parataxis
# , PUNCT punct
# думать VERB advcl
# , PUNCT punct
# что SCONJ mark
# он PRON nsubj
# один DET ccomp
# . PUNCT punct
# у ADP case
# каждый DET obl
# быть VERB ROOT
# светлый ADJ amod
# облако NOUN nsubj
# в ADP case
# прошлое NOUN nmod
# . PUNCT punct
#
#
#  SPACE dep
# и CCONJ cc
# у ADP case
# меня PRON obl
# оно PRON nsubj
# быть VERB ROOT
# , PUNCT punct
# как SCONJ case
# у ADP case
# всех PRON obl
# " PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# ii ADJ amod
#
#  SPACE dep
# скучный ADJ ROOT
# рассказывать VERB csubj
# с ADP case
# самого ADJ amod
# начало NOUN obl
# , PUNCT punct
# с ADV advmod
# тот DET fixed
# пора NOUN fixed
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# быть AUX cop
# ребёнок NOUN conj
# . PUNCT punct
# да CCONJ cc
# и PART fixed
# в ADP case
# двадцать NUM nummod:gov
# год NOUN obl
# я PRON nsubj
# жить VERB ROOT
# так ADV advmod
# же PART advmod
# , PUNCT punct
# как SCONJ mark
# в ADP case
# десять NUM obl
# . PUNCT punct
# только PART advmod
# в ADP case
# двадцать NUM obl
# я PRON nsubj
# быть AUX cop
# счастливый ADJ ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# перерасти VERB advcl
# мама NOUN obj
# и CCONJ cc
# мочь VERB conj
# гулять VERB xcomp
# с ADP case
# ней PRON obl
# под ADP case
# рука NOUN obl
# . PUNCT punct
# отношение NOUN nsubj:pass
# же PART advmod
# наш DET det
# не PART advmod
# изменяться VERB ROOT
# . PUNCT punct
# бывать VERB parataxis
# , PUNCT punct
# мальчик NOUN obl
# я PRON nsubj
# часто ADV advmod
# делать VERB ROOT
# ей PRON iobj
# сцена NOUN obj
# , PUNCT punct
# когда SCONJ mark
# она PRON nsubj
# уезжать VERB advcl
# в ADP case
# театр NOUN obl
# без ADP case
# меня PRON obl
# , PUNCT punct
# говорить VERB conj
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# иметь VERB ccomp
# право NOUN obj
# веселиться VERB nmod
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# должный ADJ advcl
# учить VERB xcomp
# урок NOUN obj
# . PUNCT punct
# она PRON nsubj
# серьезно ADV advmod
# умолять VERB ROOT
# простить VERB xcomp
# ее PRON obj
# , PUNCT punct
# даже PART advmod
# делалась VERB conj
# печальный ADJ xcomp
# , PUNCT punct
# если SCONJ mark
# я PRON nsubj
# дуться VERB advcl
# . PUNCT punct
# нам PRON iobj
# нельзя ADV ROOT
# было AUX cop
# ссориться VERB csubj
# . PUNCT punct
# у ADP case
# нее PRON obl
# не PART advmod
# быть VERB ROOT
# никто PRON nsubj
# , PUNCT punct
# кроме ADP case
# меня PRON obl
# . PUNCT punct
# и CCONJ cc
# у ADP case
# меня PRON obl
# быть VERB cop
# она PRON nsubj
# один DET ROOT
# . PUNCT punct
#
#
#  SPACE dep
# с ADP case
# отец NOUN obl
# я PRON nsubj
# даже PART advmod
# не PART advmod
# разговаривать VERB ROOT
# никогда ADV advmod
# . PUNCT punct
# пожилой ADJ amod
# господин NOUN nsubj
# , PUNCT punct
# вечно ADV advmod
# занять VERB acl
# какой DET det
# - DET det
# то DET det
# постройка NOUN obl
# , PUNCT punct
# жить VERB acl
# в ADP case
# другой ADJ amod
# половина NOUN obl
# дом NOUN nmod
# , PUNCT punct
# он PRON nsubj
# совсем ADV advmod
# не PART advmod
# интересовать VERB ROOT
# меня PRON obj
# . PUNCT punct
# а CCONJ cc
# мама NOUN nsubj
# быть AUX cop
# такой DET det
# молодой ADJ ROOT
# , PUNCT punct
# тоненький ADJ conj
# , PUNCT punct
# как SCONJ case
# девочка NOUN obl
# , PUNCT punct
# с ADP case
# больший ADJ amod
# чёрный ADJ amod
# глаз NOUN conj
# , PUNCT punct
# свежий ADJ conj
# , PUNCT punct
# блестящий ADJ conj
# ; PUNCT punct
# платье NOUN nsubj
# она DET det
# шуметь VERB conj
# при ADP case
# быстрый ADJ amod
# движение NOUN obl
# , PUNCT punct
# и CCONJ cc
# веять VERB conj
# от ADP case
# нее PRON obl
# какой DET det
# - DET det
# то DET det
# странный ADJ amod
# духами NOUN obl
# , PUNCT punct
# – PUNCT punct
# я PRON nsubj
# так ADV advmod
# и PART fixed
# не PART advmod
# узнать VERB conj
# , PUNCT punct
# как ADV advmod
# они PRON nsubj
# называться VERB ccomp
# . PUNCT punct
# запах NOUN nsubj
# их PRON det
# напоминать VERB ROOT
# самую ADJ amod
# ранний ADJ amod
# весна NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# Конечно ADV parataxis
# , PUNCT punct
# мы PRON nsubj
# жить VERB ROOT
# в ADP case
# петербург PROPN obl
# . PUNCT punct
# я PRON nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# у ADP case
# всех PRON obl
# быть VERB ccomp
# что PRON nsubj
# - PRON nsubj
# то PRON nsubj
# необычный ADJ nsubj
# , PUNCT punct
# светлый ADJ conj
# в ADP case
# прошлое NOUN obl
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# не PART advmod
# знать VERB ROOT
# и CCONJ cc
# сомневаться VERB conj
# , PUNCT punct
# что SCONJ mark
# мочь VERB ccomp
# быть AUX cop
# у ADP case
# человек NOUN obl
# , PUNCT punct
# которые PRON nsubj
# родиться VERB acl:relcl
# в ADP case
# петербург PROPN obl
# и CCONJ cc
# не PART advmod
# видать VERB conj
# другого ADJ amod
# солнце NOUN obj
# . PUNCT punct
# хороший ADJ ROOT
# , PUNCT punct
# если SCONJ mark
# я PRON nsubj
# ошибаться VERB advcl
# и PART advmod
# сужу NOUN obl
# по ADP case
# себя PRON nmod
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# никогда ADV advmod
# не PART advmod
# примирюсь VERB ROOT
# с ADP case
# это DET det
# низкий ADJ amod
# небо NOUN obl
# и CCONJ cc
# тёмный ADJ amod
# воздух NOUN conj
# , PUNCT punct
# с ADP case
# этот DET det
# квартира NOUN conj
# , PUNCT punct
# где ADV advmod
# я PRON nsubj
# один DET acl:relcl
# . PUNCT punct
# впрочем ADV parataxis
# , PUNCT punct
# об ADP case
# это PRON obl
# впереди ADV ROOT
# . PUNCT punct
# и CCONJ cc
# все ADV advmod
# равный ADJ fixed
# , PUNCT punct
# я PRON nsubj
# один DET conj
# в ADP case
# целое NOUN amod
# свет NOUN nmod
# , PUNCT punct
# как ADV advmod
# же PART advmod
# мне PRON iobj
# не PART advmod
# быть AUX cop
# одному NUM acl
# в ADP case
# этот DET det
# квартира NOUN nmod
# ? PUNCT punct
#
#
#  SPACE dep
# мы PRON nsubj
# жить VERB ROOT
# в ADP case
# большой ADJ amod
# город NOUN obl
# на ADP case
# юг NOUN nmod
# , PUNCT punct
# в ADP case
# свой DET det
# дом NOUN obl
# . PUNCT punct
# дом NOUN nsubj
# быть AUX cop
# новый ADJ ROOT
# , PUNCT punct
# выстроить VERB conj
# отец NOUN obl:agent
# , PUNCT punct
# неудобный ADJ conj
# и CCONJ cc
# холодный ADJ conj
# . PUNCT punct
# в ADP case
# двор NOUN obl
# быть AUX cop
# небольшой ADJ amod
# , PUNCT punct
# но CCONJ cc
# чистый ADJ amod
# сад NOUN ROOT
# , PUNCT punct
# к ADP case
# которому PRON obl
# со ADP case
# весь DET det
# сторона NOUN obl
# примыкать VERB acl:relcl
# чужой ADJ amod
# сад NOUN obj
# , PUNCT punct
# а CCONJ cc
# потому ADV advmod
# он PRON nsubj
# казаться VERB conj
# мне PRON iobj
# бесконечный ADJ xcomp
# . PUNCT punct
# отец NOUN nsubj
# все PRON nmod
# хотеть VERB ROOT
# его PRON obj
# вырубить VERB xcomp
# и CCONJ cc
# построить VERB conj
# два NUM nummod:gov
# флигель NOUN obj
# и CCONJ cc
# сарай NOUN conj
# , PUNCT punct
# но CCONJ cc
# так ADV advmod
# и PART fixed
# не PART advmod
# собраться VERB conj
# . PUNCT punct
# не PART advmod
# знать VERB ROOT
# , PUNCT punct
# впрочем ADV parataxis
# , PUNCT punct
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# теперь ADV advmod
# уж PART advmod
# и PART advmod
# нет VERB ccomp
# наш DET det
# сад NOUN nsubj
# . PUNCT punct
# не PART advmod
# знать VERB ROOT
# , PUNCT punct
# да CCONJ cc
# и CCONJ fixed
# знать VERB xcomp
# не PART advmod
# хотеть VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# никогда ADV advmod
# не PART advmod
# быть AUX cop
# в ADP case
# гимназия NOUN ROOT
# . PUNCT punct
# в ADP case
# самом ADJ amod
# дело NOUN parataxis
# , PUNCT punct
# с ADP case
# кто PRON obl
# бы AUX aux
# мама NOUN nsubj
# оставаться VERB ROOT
# ? PUNCT punct
# у ADP case
# нее PRON obl
# быть VERB ROOT
# много ADV nsubj
# знакомых NOUN obl
# , PUNCT punct
# но CCONJ cc
# никто PRON nsubj
# никогда ADV advmod
# за ADP case
# ней PRON obl
# не PART advmod
# ухаживать VERB conj
# серьезно ADV advmod
# , PUNCT punct
# хотя SCONJ mark
# и PART advmod
# знать VERB advcl
# она DET det
# отношение NOUN obj
# к ADP case
# отец NOUN nmod
# . PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# она PRON nsubj
# сама ADJ acl
# не PART advmod
# хотеть VERB ccomp
# . PUNCT punct
#
#
#  SPACE dep
# у ADP case
# меня PRON obl
# быть VERB ROOT
# хороший ADJ amod
# гимназический ADJ amod
# учитель NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# учиться VERB conj
# недурно ADV advmod
# . PUNCT punct
# мама NOUN nsubj
# , PUNCT punct
# конечно ADV parataxis
# , PUNCT punct
# учиться VERB ROOT
# со ADP case
# мною PRON obl
# , PUNCT punct
# но CCONJ cc
# ей PRON iobj
# часто ADV advmod
# надоедало VERB conj
# , PUNCT punct
# и CCONJ cc
# она PRON nsubj
# говорить VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# володя PROPN parataxis
# , PUNCT punct
# бросим VERB conj
# книга NOUN obj
# , PUNCT punct
# пойти VERB conj
# гулять VERB xcomp
# , PUNCT punct
# а CCONJ conj
# ? PUNCT punct
#
#
#  SPACE dep
# и CCONJ cc
# мы PRON nsubj
# идти VERB ROOT
# , PUNCT punct
# – PUNCT punct
# она PRON nsubj
# нарядный ADJ conj
# , PUNCT punct
# весёлый ADJ conj
# , PUNCT punct
# а CCONJ cc
# я PRON nsubj
# счастливый ADJ conj
# , PUNCT punct
# что SCONJ mark
# у ADP case
# меня PRON ccomp
# такой DET det
# хорошенький ADJ amod
# мама NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# так ADV advmod
# на ADP case
# нее PRON obl
# похожий ADJ conj
# . PUNCT punct
#
#
#  SPACE dep
# она PRON nsubj
# совсем ADV advmod
# не PART advmod
# изменяться VERB ROOT
# , PUNCT punct
# не PART advmod
# стареть VERB conj
# , PUNCT punct
# и CCONJ cc
# скоро ADV advmod
# нас PRON obj
# стать VERB conj
# принимать VERB xcomp
# за ADP case
# брат NOUN obl
# и CCONJ cc
# сестра NOUN conj
# , PUNCT punct
# особенно ADV advmod
# когда SCONJ mark
# у ADP case
# меня PRON obl
# вырасти VERB parataxis
# ус NOUN nsubj
# и CCONJ cc
# маленький ADJ amod
# борода NOUN conj
# . PUNCT punct
# мне PRON iobj
# казаться VERB ROOT
# , PUNCT punct
# что SCONJ mark
# и PART advmod
# я PRON nsubj
# не PART advmod
# измениться VERB ccomp
# внутренне ADV advmod
# . PUNCT punct
# только PART advmod
# к ADP case
# двадцать NUM nummod
# год NOUN obl
# я PRON nsubj
# серьезно ADV advmod
# стать VERB ROOT
# заниматься VERB xcomp
# музыка NOUN obl
# и CCONJ cc
# мечтать VERB conj
# о ADP case
# консерватория NOUN obl
# . PUNCT punct
# гимназический ADJ amod
# экзамен NOUN obj
# я PRON nsubj
# сдать VERB ROOT
# хорошо ADV advmod
# , PUNCT punct
# и CCONJ cc
# надо ADV conj
# было AUX cop
# на ADP case
# что PRON obl
# - PRON obl
# нибудь PRON obl
# решаться VERB csubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# ты PRON nsubj
# поедешь VERB conj
# в ADP case
# консерватория NOUN obl
# , PUNCT punct
# в ADP case
# москва PROPN conj
# , PUNCT punct
# непременно ADV advmod
# , PUNCT punct
# – PUNCT punct
# говорить VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
# – PUNCT punct
# Надо ADV ROOT
# скорее ADV advmod
# , PUNCT punct
# тебе PRON iobj
# уже ADV advmod
# двадцать NUM nummod:gov
# год NOUN obl
# . PUNCT punct
# ты PRON nsubj
# быть AUX cop
# знаменитый ADJ ROOT
# , PUNCT punct
# вот PART advmod
# увидеть VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# а CCONJ cc
# когда ADV advmod
# же PART advmod
# мы PRON nsubj
# поехать VERB parataxis
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# осень PROPN parataxis
# , PUNCT punct
# я PRON nsubj
# думать VERB parataxis
# . PUNCT punct
# хороший ADJ ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# не PART advmod
# быть VERB ROOT
# и PART advmod
# речь NOUN nsubj
# о ADP case
# том PRON nmod
# , PUNCT punct
# чтобы SCONJ mark
# мне PRON iobj
# ехать VERB advcl
# без ADP case
# мама NOUN obl
# . PUNCT punct
# с ADP case
# кто PRON obl
# бы AUX aux
# я PRON nsubj
# стать VERB ROOT
# говорить VERB xcomp
# ? PUNCT punct
# кто PRON nsubj
# бы AUX aux
# ласкать VERB ROOT
# меня PRON obj
# и CCONJ cc
# ходить VERB conj
# со ADP case
# мною PRON obl
# гулять VERB xcomp
# ? PUNCT punct
# а CCONJ cc
# кто PRON nsubj
# бы AUX aux
# ухаживать VERB ROOT
# за ADP case
# мною NOUN obl
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# заболею VERB advcl
# ? PUNCT punct
# да PART cc
# разве PART advmod
# возможный ADJ ROOT
# ей PRON iobj
# оставаться VERB csubj
# без ADP case
# меня PRON obl
# , PUNCT punct
# когда SCONJ mark
# мы PRON nsubj
# ни PART advmod
# на ADP case
# один NUM nummod
# день NOUN obl
# не PART advmod
# расставаться VERB advcl
# , PUNCT punct
# все PRON obj
# делать VERB conj
# и CCONJ cc
# обсуждать VERB conj
# сообща ADV advmod
# ? PUNCT punct
# я PRON nsubj
# и CCONJ advmod
# заниматься VERB xcomp
# не PART advmod
# стать VERB ROOT
# бы AUX aux
# без ADP case
# нее PRON obl
# . PUNCT punct
#
#
#  SPACE dep
# так ADV parataxis
# же PART advmod
# , PUNCT punct
# как SCONJ mark
# бывать VERB parataxis
# ребёнок NOUN xcomp
# , PUNCT punct
# – PUNCT punct
# я PRON nsubj
# садиться VERB ROOT
# по ADP case
# вечер NOUN obl
# у ADP case
# огонь NOUN obl
# в ADP case
# она DET det
# комната NOUN obl
# , PUNCT punct
# на ADP case
# пол NOUN conj
# , PUNCT punct
# около ADP case
# она DET det
# нога NOUN conj
# , PUNCT punct
# и CCONJ cc
# рассказывать VERB conj
# ей PRON iobj
# , PUNCT punct
# как SCONJ mark
# тот DET det
# и CCONJ advmod
# тот DET det
# барышня NOUN nsubj
# в ADP case
# меня PRON obl
# влюблены ADJ ccomp
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# за ADP case
# ними PRON obl
# ухаживать VERB advcl
# , PUNCT punct
# и CCONJ cc
# какой DET nsubj
# мне PRON iobj
# больше ADV advmod
# нравиться VERB conj
# . PUNCT punct
# мне PRON iobj
# в ADP case
# это DET det
# время NOUN obl
# казаться VERB ROOT
# , PUNCT punct
# что SCONJ mark
# весь DET det
# барышня NOUN nsubj
# должный ADJ ccomp
# быть AUX cop
# в ADP case
# меня PRON obl
# влюблены ADJ xcomp
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# я PRON nsubj
# такой DET det
# красивый ADJ advcl
# и CCONJ cc
# так ADV advmod
# хорошо ADV advmod
# играть VERB conj
# на ADP case
# фортепиано NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# знать VERB parataxis
# , PUNCT punct
# володя PROPN conj
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# мне PRON iobj
# раз NOUN obl
# мама NOUN nsubj
# , PUNCT punct
# – PUNCT punct
# ведь PART mark
# ты PRON nsubj
# совсем ADV advmod
# не PART advmod
# похожий ADJ parataxis
# на ADP case
# мужчина NOUN obl
# , PUNCT punct
# ты PRON nsubj
# совершенно ADV advmod
# женщина NOUN parataxis
# , PUNCT punct
# оттого ADV conj
# , PUNCT punct
# должный ADJ parataxis
# быть VERB xcomp
# , PUNCT punct
# мы PRON nsubj
# с ADP case
# тобой PRON obl
# так ADV advmod
# и PART fixed
# сойтись VERB conj
# … PUNCT punct
# или CCONJ cc
# это PRON obj
# я PRON nsubj
# сама ADJ acl
# так ADV advmod
# сделать VERB ROOT
# , PUNCT punct
# – PUNCT punct
# прибавить VERB parataxis
# она PRON nsubj
# подумать VERB xcomp
# . PUNCT punct
# – PUNCT punct
# ты PRON nsubj
# , PUNCT punct
# например ADV parataxis
# , PUNCT punct
# в ADP case
# мужской ADJ amod
# общество NOUN ROOT
# и CCONJ cc
# не PART advmod
# бывать VERB conj
# никогда ADV advmod
# ; PUNCT punct
# а CCONJ cc
# среди ADP case
# женщина NOUN obl
# я PRON nsubj
# тебя PRON obj
# видеть VERB conj
# – PUNCT punct
# там ADV advmod
# ты PRON nsubj
# тоже ADV advmod
# как ADV advmod
# - ADV advmod
# то ADV advmod
# не PART advmod
# ухаживать VERB parataxis
# , PUNCT punct
# а CCONJ cc
# кокетничать VERB conj
# . PUNCT punct
# не PART advmod
# знать VERB ROOT
# … PUNCT punct
# но CCONJ cc
# мне PRON iobj
# казаться VERB conj
# , PUNCT punct
# быть AUX cop
# ты PRON nsubj
# мне PRON iobj
# чужой ADJ csubj
# – PUNCT punct
# ты PRON nsubj
# мне PRON iobj
# не PART advmod
# понравиться VERB parataxis
# бы AUX aux
# . PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# страшно ADV advmod
# обидеться VERB ROOT
# и CCONJ cc
# надуться VERB conj
# . PUNCT punct
# как ADV ROOT
# ! PUNCT punct
# сама ADJ amod
# же PART advmod
# она PRON nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# похожий ADJ ccomp
# на ADP case
# нее PRON obl
# , PUNCT punct
# а CCONJ cc
# теперь ADV advmod
# я PRON nsubj
# ей PRON iobj
# не PART advmod
# нравиться VERB conj
# ! PUNCT punct
# если SCONJ mark
# это PRON nsubj
# и PART advmod
# не PART advmod
# хороший ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# похожий ADJ ccomp
# на ADP case
# женщина NOUN obl
# , PUNCT punct
# то SCONJ mark
# ведь PART advmod
# она PRON nsubj
# же PART advmod
# сама ADJ amod
# прежде ADV advmod
# это PRON fixed
# не PART advmod
# бояться VERB advcl
# ? PUNCT punct
#
#
#  SPACE dep
# да CCONJ cc
# и CCONJ fixed
# что SCONJ mark
# тут ADV advmod
# нехороший ADJ ROOT
# ? PUNCT punct
# пусть PART advmod
# я PRON nsubj
# похожий ADJ ROOT
# на ADP case
# женщина NOUN obl
# ! PUNCT punct
# я PRON nsubj
# любить VERB ROOT
# прежде ADV advmod
# всего PRON fixed
# все PRON det
# красивый ADJ obj
# – PUNCT punct
# но CCONJ cc
# без ADP case
# суровость NOUN parataxis
# , PUNCT punct
# без ADP case
# сила NOUN conj
# , PUNCT punct
# а CCONJ cc
# нежный ADJ conj
# и CCONJ cc
# простой ADJ conj
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# виноватый ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# такой DET ccomp
# … PUNCT punct
#
#
#  SPACE dep
# мама NOUN nsubj
# долго ADV advmod
# просить VERB ROOT
# у ADP case
# меня PRON obl
# прощение NOUN obj
# , PUNCT punct
# и CCONJ cc
# мы PRON nsubj
# помириться VERB conj
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# не PART advmod
# забыть VERB ROOT
# она DET det
# слово NOUN obj
# и CCONJ cc
# часто ADV advmod
# потом ADV advmod
# говорить VERB conj
# ей PRON iobj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# вот PART advmod
# сыромятников PROPN parataxis
# , PUNCT punct
# или CCONJ cc
# маремьянов PROPN nsubj
# , PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# какой DET det
# мужественные NOUN conj
# ? PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# они PRON nsubj
# должный ADJ ROOT
# нравиться VERB xcomp
# женщина NOUN iobj
# ? PUNCT punct
#
#
#  SPACE dep
# мама NOUN nsubj
# улыбалась VERB ROOT
# и CCONJ cc
# зажимала VERB conj
# мне PRON iobj
# рот NOUN obj
# свой DET det
# большой ADJ amod
# , PUNCT punct
# но CCONJ cc
# красивый ADJ conj
# рука NOUN obl
# с ADP case
# бесчисленный ADJ amod
# звенящий ADJ amod
# браслет NOUN nmod
# . PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# делаться VERB ccomp
# фат NOUN obl
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# я PRON nsubj
# все PART advmod
# - PART advmod
# таки PART advmod
# очень ADV advmod
# нравиться VERB advcl
# тамошний ADJ amod
# барышня NOUN iobj
# , PUNCT punct
# знать VERB conj
# – PUNCT punct
# жизнь NOUN nsubj
# проходить VERB parataxis
# пусто ADV advmod
# , PUNCT punct
# и CCONJ cc
# сердце NOUN nsubj:pass
# делаться VERB conj
# пошлый ADJ xcomp
# от ADP case
# этот DET det
# вечный ADJ amod
# рисовка NOUN nmod
# и CCONJ cc
# бесцельный ADJ amod
# желание NOUN conj
# нравиться VERB xcomp
# . PUNCT punct
# сам ADJ amod
# я PRON nsubj
# ни PART advmod
# разу NOUN obl
# не PART advmod
# влюбляться VERB ROOT
# . PUNCT punct
# нравиться VERB ROOT
# многие NOUN nsubj
# , PUNCT punct
# но CCONJ cc
# не PART advmod
# сильно ADV conj
# . PUNCT punct
# в ADP case
# сущность NOUN parataxis
# , PUNCT punct
# я PRON nsubj
# быть AUX cop
# очень ADV advmod
# чистый ADJ ROOT
# в ADP case
# тот DET det
# время NOUN obl
# , PUNCT punct
# как SCONJ mark
# редкий ADJ acl
# , PUNCT punct
# но CCONJ cc
# мысленно ADV advmod
# я PRON nsubj
# оказываться VERB conj
# не PART advmod
# лучше ADV advmod
# других ADJ obl
# . PUNCT punct
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# всегда ADV advmod
# чистый ADJ amod
# человек NOUN nsubj
# – PUNCT punct
# не PART advmod
# чистый ADJ ccomp
# в ADP case
# мысль NOUN obl
# ; PUNCT punct
# но CCONJ cc
# мне PRON iobj
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# это PRON nsubj
# неправда NOUN ccomp
# . PUNCT punct
# и CCONJ cc
# у ADP case
# меня PRON obl
# это PRON nsubj
# было AUX cop
# временно ADV ROOT
# и CCONJ cc
# , PUNCT punct
# я PRON nsubj
# думать VERB parataxis
# , PUNCT punct
# от ADP case
# робость NOUN conj
# , PUNCT punct
# от ADP case
# пошлый ADJ amod
# и CCONJ cc
# праздный ADJ conj
# жизнь NOUN conj
# , PUNCT punct
# и CCONJ cc
# оттого ADV conj
# , PUNCT punct
# что SCONJ mark
# меня PRON obj
# портили VERB ccomp
# и CCONJ cc
# баловать VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# iii ADJ amod
#
#  SPACE dep
# удивительный ADJ ROOT
# , PUNCT punct
# как ADV advmod
# мало ADV advmod
# меня PRON obj
# интересовать VERB ccomp
# книга NOUN nsubj
# . PUNCT punct
# я PRON nsubj
# их PRON obj
# читать VERB ROOT
# , PUNCT punct
# пока SCONJ mark
# не PART advmod
# сдать VERB advcl
# экзамен NOUN obj
# . PUNCT punct
# а CCONJ cc
# с ADV advmod
# тот DET fixed
# пора NOUN fixed
# я PRON nsubj
# заниматься VERB ROOT
# только PART advmod
# музыка NOUN obl
# . PUNCT punct
# она PRON nsubj
# один DET nummod
# меня PRON obj
# волновать VERB ROOT
# и CCONJ cc
# заставлять VERB conj
# вспоминать VERB xcomp
# то PRON obj
# , PUNCT punct
# что PRON nsubj
# не PART advmod
# быть VERB acl
# . PUNCT punct
# Для ADP case
# музыка NOUN obl
# я PRON nsubj
# мочь VERB ROOT
# забыть VERB xcomp
# многое NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# наконец ADV parataxis
# , PUNCT punct
# мы PRON nsubj
# поехать VERB ROOT
# в ADP case
# москва PROPN obl
# . PUNCT punct
# и CCONJ cc
# я PRON nsubj
# быть AUX cop
# рад ADJ ROOT
# . PUNCT punct
# я PRON nsubj
# инстинктивно ADV advmod
# чувствовать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# надо ADV ccomp
# все PRON obj
# переменить VERB csubj
# . PUNCT punct
#
#
#  SPACE dep
# с ADP case
# нами PRON obl
# поехать VERB ROOT
# наш DET det
# старый ADJ amod
# экономка NOUN nsubj
# , PUNCT punct
# без ADP case
# нее PRON obl
# мы PRON nsubj
# совсем ADV advmod
# пропасть VERB conj
# бы AUX aux
# . PUNCT punct
# я PRON nsubj
# в ADP case
# москва PROPN obl
# никогда ADV advmod
# не PART advmod
# быть VERB ROOT
# , PUNCT punct
# а CCONJ cc
# мама NOUN nsubj
# хотя PART advmod
# и PART advmod
# жить VERB conj
# там ADV advmod
# прежде ADV advmod
# , PUNCT punct
# однако ADV advmod
# ничто PRON obj
# не PART advmod
# знать VERB conj
# и CCONJ cc
# не PART advmod
# уметь VERB conj
# . PUNCT punct
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# и CCONJ cc
# суметь VERB ROOT
# бы AUX aux
# , PUNCT punct
# но CCONJ cc
# ей PRON iobj
# было AUX cop
# скучный ADJ conj
# заботиться VERB csubj
# и CCONJ cc
# суетиться VERB conj
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# это PRON obj
# отлично ADV advmod
# понимать VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# мы PRON nsubj
# нанять VERB ROOT
# хорошенький ADJ amod
# квартирка NOUN obj
# на ADP case
# малый ADJ amod
# никитский ADJ nmod
# и CCONJ cc
# зажить VERB conj
# припеваючи NOUN obj
# , PUNCT punct
# по ADV parataxis
# - ADV advmod
# товарищеский ADV advmod
# . PUNCT punct
# ездить VERB ROOT
# в ADP case
# театр NOUN obl
# , PUNCT punct
# кататься VERB xcomp
# . PUNCT punct
# Скоро ADV advmod
# явиться VERB ROOT
# знакомые NOUN nsubj
# , PUNCT punct
# найтись VERB conj
# родственник NOUN nsubj
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# стать VERB ROOT
# заниматься VERB xcomp
# ревностно ADV advmod
# и CCONJ cc
# даже PART advmod
# редко ADV advmod
# выходить VERB conj
# , PUNCT punct
# когда SCONJ mark
# у ADP case
# мама NOUN obl
# быть VERB ccomp
# гость NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# в ADP case
# консерватория NOUN obl
# я PRON nsubj
# ни PART advmod
# с ADP case
# кто PRON obl
# не PART advmod
# сошелся VERB ROOT
# , PUNCT punct
# кроме ADP case
# свой DET det
# профессор NOUN obl
# , PUNCT punct
# ещё ADV advmod
# молодой ADJ amod
# человек NOUN conj
# . PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# ему PRON iobj
# казаться VERB ROOT
# странный ADJ xcomp
# , PUNCT punct
# хотя SCONJ mark
# , PUNCT punct
# как SCONJ mark
# он PRON nsubj
# говорить VERB parataxis
# , PUNCT punct
# очень ADV advmod
# талантливый ADJ advcl
# . PUNCT punct
# он PRON nsubj
# , PUNCT punct
# однако ADV parataxis
# , PUNCT punct
# угадать VERB ROOT
# меня PRON obj
# только PART advmod
# после ADP case
# того PRON obl
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# его PRON obj
# ввести VERB acl
# к ADP case
# нам PRON obl
# , PUNCT punct
# и CCONJ cc
# он PRON nsubj
# увидать VERB conj
# мой DET det
# мама NOUN obj
# . PUNCT punct
# нас PRON obj
# друг PRON nsubj
# без ADP fixed
# друга PRON fixed
# понять VERB csubj
# было AUX cop
# нельзя ADV ROOT
# , PUNCT punct
# а CCONJ cc
# вместе ADV advmod
# , PUNCT punct
# как SCONJ mark
# говорить VERB parataxis
# , PUNCT punct
# мы PRON nsubj
# составлять VERB conj
# одно NUM nummod
# целое NOUN obj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# смотреть VERB ROOT
# , PUNCT punct
# молодой ADJ amod
# человек NOUN conj
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# мне PRON iobj
# раз NOUN obl
# профессор NOUN nsubj
# , PUNCT punct
# – PUNCT punct
# заниматься VERB conj
# хорошенько ADV advmod
# . PUNCT punct
# Из ADP case
# вас PRON obl
# должный ADJ ROOT
# выйти VERB xcomp
# что PRON obj
# - PRON obj
# нибудь PRON obj
# , PUNCT punct
# или CCONJ cc
# вы PRON nsubj
# совсем ADV advmod
# пропадете VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# и CCONJ cc
# я PRON nsubj
# заниматься VERB ROOT
# . PUNCT punct
# даже PART advmod
# лень NOUN obj
# свой DET obj
# забыть VERB ROOT
# , PUNCT punct
# не PART advmod
# заботиться VERB conj
# о ADP case
# волос NOUN obl
# и CCONJ cc
# об ADP case
# одежда NOUN conj
# , PUNCT punct
# редко ADV advmod
# выезжать VERB conj
# и CCONJ cc
# все PRON nsubj
# играть VERB conj
# свой DET det
# гамма NOUN obj
# . PUNCT punct
# я PRON nsubj
# их PRON obj
# не PART advmod
# любить VERB ROOT
# и CCONJ cc
# терпеть VERB conj
# только PART advmod
# , PUNCT punct
# как SCONJ case
# трудный ADJ amod
# лестница NOUN obj
# , PUNCT punct
# по ADP case
# которой PRON obl
# нужный ADJ acl:relcl
# взбираться VERB csubj
# наверх ADV advmod
# . PUNCT punct
# как SCONJ mark
# я PRON nsubj
# тосковать VERB ROOT
# о ADP case
# синий ADJ amod
# небо NOUN obl
# , PUNCT punct
# о ADP case
# земля NOUN conj
# , PUNCT punct
# о ADP case
# цвет NOUN conj
# ! PUNCT punct
# я PRON nsubj
# ни PART advmod
# о ADP case
# что PRON obl
# так ADV advmod
# не PART advmod
# тосковать VERB ROOT
# , PUNCT punct
# я PRON nsubj
# не PART advmod
# думать VERB conj
# , PUNCT punct
# что SCONJ mark
# будет VERB ccomp
# тоска NOUN nsubj
# . PUNCT punct
# мама NOUN nsubj
# утешала VERB ROOT
# меня PRON obj
# , PUNCT punct
# но CCONJ conj
# … PUNCT punct
# это PRON nsubj
# было AUX cop
# мой DET det
# больной ADJ amod
# место NOUN ROOT
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# тут ADV advmod
# мы PRON nsubj
# не PART advmod
# понимать VERB ccomp
# друг PRON obj
# друга PRON fixed
# , PUNCT punct
# только PART advmod
# тут ADV advmod
# . PUNCT punct
# она PRON nsubj
# даже PART advmod
# сад NOUN obj
# наш DET obj
# не PART advmod
# любить VERB ROOT
# , PUNCT punct
# – PUNCT punct
# гулять VERB xcomp
# ходить VERB parataxis
# по ADP case
# улица NOUN obl
# , PUNCT punct
# говорить VERB conj
# , PUNCT punct
# что SCONJ mark
# солнечный ADJ amod
# свет NOUN nsubj
# гораздо ADV advmod
# беспокойный ADJ ccomp
# полутьма NOUN obl
# гостиная NOUN nmod
# , PUNCT punct
# а CCONJ cc
# она DET det
# дух NOUN nsubj
# хороший ADJ conj
# запах NOUN obl
# настоящий ADJ amod
# весна NOUN nmod
# . PUNCT punct
#
#
#  SPACE dep
# когда SCONJ mark
# я PRON nsubj
# об ADP case
# это PRON obl
# думать VERB advcl
# , PUNCT punct
# приходило VERB ROOT
# невольный ADJ amod
# чувство NOUN nsubj
# на ADP case
# минута NOUN nmod
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# молодой ADJ ccomp
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# мочь VERB ccomp
# быть AUX cop
# вполне ADV advmod
# мой DET det
# товарищ NOUN xcomp
# , PUNCT punct
# что SCONJ mark
# в ADP case
# глубина NOUN obl
# душа NOUN nmod
# – PUNCT punct
# между ADP case
# нами PRON parataxis
# преграда NOUN nsubj
# . PUNCT punct
#
#
#  SPACE dep
# но CCONJ cc
# это PRON nsubj
# были AUX cop
# только PART advmod
# минута NOUN ROOT
# … PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# не PART advmod
# сошелся VERB ccomp
# ни PART advmod
# с ADP case
# кто PRON obl
# . PUNCT punct
# Близко ADV nsubj
# не PART advmod
# сходился VERB ROOT
# , PUNCT punct
# но CCONJ cc
# знакомиться VERB conj
# и CCONJ cc
# несколько NUM nummod:gov
# раз NOUN obl
# попадать VERB conj
# на ADP case
# кутёж NOUN obl
# , PUNCT punct
# не PART advmod
# ночевать VERB conj
# дома ADV advmod
# … PUNCT punct
#
#
#  SPACE dep
# мама NOUN nsubj
# расспрашивала VERB ROOT
# меня PRON obj
# с ADP case
# любопытство NOUN obl
# и CCONJ cc
# без ADP case
# всякий DET det
# упрёк NOUN conj
# , PUNCT punct
# но CCONJ cc
# я PRON nsubj
# быть AUX cop
# как ADV advmod
# - ADV advmod
# то ADV advmod
# недовольный ADJ conj
# и CCONJ cc
# рассказывать VERB conj
# подробно ADV advmod
# с ADP case
# омерзение NOUN obl
# , PUNCT punct
# хотя SCONJ mark
# не PART advmod
# без ADP case
# гордость NOUN advcl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# это PRON nsubj
# неважный ADJ parataxis
# , PUNCT punct
# володя VERB conj
# , PUNCT punct
# – PUNCT punct
# говорить VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
# – PUNCT punct
# это PRON expl
# я PRON nsubj
# все PART advmod
# так ADV advmod
# и PART fixed
# думать VERB ROOT
# . PUNCT punct
# ты PRON nsubj
# только PART advmod
# меня PRON obj
# не PART advmod
# должный ADJ ROOT
# забывать VERB xcomp
# . PUNCT punct
# понимать VERB ROOT
# , PUNCT punct
# чтобы SCONJ mark
# я PRON nsubj
# быть AUX cop
# у ADP case
# тебя PRON obl
# первый ADJ advcl
# , PUNCT punct
# и CCONJ cc
# всегда ADV advmod
# , PUNCT punct
# как SCONJ case
# ты PRON nsubj
# у ADP case
# меня PRON conj
# . PUNCT punct
# понимать VERB ROOT
# ? PUNCT punct
# иначе ADV advmod
# жить VERB csubj
# нельзя ADV ROOT
# . PUNCT punct
# понимать VERB ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# только PART advmod
# улыбаться VERB ROOT
# и CCONJ cc
# обнимать VERB conj
# ее PRON obj
# . PUNCT punct
# как SCONJ advmod
# же PART advmod
# она PRON nsubj
# мочь VERB ROOT
# быть AUX cop
# не PART advmod
# первый ADJ xcomp
# ? PUNCT punct
# кто PRON ROOT
# же PART advmod
# тогда ADV advmod
# ? PUNCT punct
#
#
#  SPACE dep
# iv ADJ nsubj
#
#  SPACE dep
# пройти VERB ROOT
# несколько NUM nummod:gov
# год NOUN nsubj
# . PUNCT punct
# я PRON nsubj
# кончать VERB ROOT
# консерватория NOUN obj
# , PUNCT punct
# выступать VERB conj
# в ADP case
# концерт NOUN obl
# – PUNCT punct
# и CCONJ cc
# с ADP case
# успех NOUN obl
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# сам ADJ acl
# быть AUX cop
# не PART advmod
# совсем ADV advmod
# довольный ADJ ROOT
# . PUNCT punct
# что PRON nsubj
# мне PRON discourse
# в ADP case
# этот DET det
# трескучий ADJ amod
# пьеса NOUN ROOT
# , PUNCT punct
# где ADV advmod
# я PRON nsubj
# так ADV advmod
# быстро ADV advmod
# перебираю VERB acl:relcl
# палец NOUN iobj
# , PUNCT punct
# и CCONJ cc
# все PRON nsubj
# удивляться VERB conj
# и CCONJ cc
# хвалить VERB conj
# меня PRON obj
# ? PUNCT punct
# когда SCONJ advmod
# же PART advmod
# я PRON nsubj
# смочь VERB ROOT
# сыграть VERB xcomp
# то PRON obj
# , PUNCT punct
# что SCONJ obj
# слышать VERB acl
# часто ADV advmod
# – PUNCT punct
# но CCONJ cc
# что PRON nsubj
# ускользать VERB parataxis
# от ADP case
# меня PRON obl
# ? PUNCT punct
# если SCONJ mark
# суметь VERB advcl
# , PUNCT punct
# если SCONJ mark
# найти VERB advcl
# – PUNCT punct
# то SCONJ mark
# все PRON nsubj
# сразу ADV advmod
# измениться VERB ROOT
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# быть AUX aux
# одно NUM nummod
# чувствовать VERB conj
# с ADP case
# тот DET det
# , PUNCT punct
# кто PRON nsubj
# слушать VERB acl:relcl
# . PUNCT punct
# мы PRON nsubj
# вместе ADV advmod
# быть AUX aux
# плакать VERB ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# оно PRON nsubj
# пройти VERB advcl
# не PART advmod
# мимо ADV advmod
# , PUNCT punct
# а CCONJ cc
# задеть VERB conj
# , PUNCT punct
# зацепить VERB conj
# самое ADJ amod
# тайный ADJ obj
# , PUNCT punct
# самое ADJ amod
# тайный ADJ conj
# , PUNCT punct
# самое ADJ amod
# глубокий ADJ conj
# , PUNCT punct
# одно NUM conj
# для ADP case
# всех PRON nmod
# … PUNCT punct
# да PART parataxis
# , PUNCT punct
# мы PRON nsubj
# быть AUX aux
# плакать VERB ROOT
# ; PUNCT punct
# потом ADV advmod
# … PUNCT punct
# потом ADV advmod
# все ADV ccomp
# равный ADJ fixed
# , PUNCT punct
# ну PART discourse
# – PUNCT punct
# умереть VERB ROOT
# . PUNCT punct
# все PRON ROOT
# равный ADJ fixed
# … PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# , PUNCT punct
# пока SCONJ mark
# я PRON nsubj
# сам ADJ acl
# не PART advmod
# чувствовать VERB advcl
# – PUNCT punct
# ничто PRON nsubj
# не PART advmod
# будет VERB ccomp
# ; PUNCT punct
# и CCONJ cc
# верить VERB conj
# без ADP case
# сомнение NOUN obl
# , PUNCT punct
# что SCONJ mark
# если SCONJ mark
# прийти VERB advcl
# к ADP case
# мне PRON obl
# – PUNCT punct
# то PRON nsubj
# и PART advmod
# к ADP case
# всем PRON obl
# прийти VERB ccomp
# , PUNCT punct
# кто PRON iobj
# я PRON nsubj
# быть AUX aux
# " PUNCT punct
# говорить VERB csubj
# " PUNCT punct
# . PUNCT punct
# я PRON nsubj
# всегда ADV advmod
# мысленно ADV advmod
# вместо ADP case
# " PUNCT punct
# играть VERB nsubj
# " PUNCT punct
# употреблять VERB ROOT
# выражение NOUN obj
# " PUNCT punct
# говорить VERB nmod
# с ADP case
# человек NOUN obl
# " PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# весь DET det
# это PRON nsubj
# было AUX cop
# не PART advmod
# умный ADJ ROOT
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# никогда ADV advmod
# не PART advmod
# считать VERB ROOT
# себя PRON obj
# умный ADJ amod
# человек NOUN xcomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# и CCONJ cc
# самолюбие NOUN conj
# тут ADV advmod
# не PART advmod
# быть VERB ROOT
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# не PART advmod
# развит VERB ccomp
# и CCONJ cc
# мало ADV advmod
# образованный ADJ conj
# . PUNCT punct
# да CCONJ cc
# и PART fixed
# пусть PART ROOT
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# к ADP case
# это PRON obl
# идти VERB ROOT
# , PUNCT punct
# у ADP case
# меня PRON conj
# другое ADJ amod
# счастие NOUN nsubj
# , PUNCT punct
# другая ADJ amod
# дорога NOUN nsubj
# меня PRON obj
# повести VERB conj
# наверх ADV advmod
# . PUNCT punct
#
#
#  SPACE dep
# мама NOUN nsubj
# раз NOUN nmod
# два NUM nummod:gov
# меня PRON obj
# оставлять VERB ROOT
# одного NUM obj
# на ADP case
# несколько NUM nummod:gov
# неделя NOUN obl
# , PUNCT punct
# ей PRON iobj
# необходимый ADJ conj
# было AUX cop
# уехать VERB csubj
# домой ADV advmod
# . PUNCT punct
# и CCONJ cc
# каждый DET det
# раз NOUN obl
# я PRON nsubj
# умирать VERB ROOT
# , PUNCT punct
# бросать VERB conj
# заниматься VERB xcomp
# , PUNCT punct
# почти ADV advmod
# не PART advmod
# есть VERB conj
# . PUNCT punct
# у ADP case
# меня PRON obl
# являться VERB ROOT
# какой DET det
# - DET det
# то DET det
# нервный ADJ amod
# ужас NOUN nsubj
# , PUNCT punct
# мне PRON iobj
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# один DET ccomp
# на ADP case
# свет NOUN nmod
# , PUNCT punct
# ее PRON nsubj
# нет VERB conj
# и CCONJ cc
# не PART advmod
# быть VERB conj
# . PUNCT punct
# главный ADJ nsubj
# – PUNCT punct
# не PART advmod
# быть VERB ROOT
# ! PUNCT punct
# а CCONJ cc
# если SCONJ mark
# не PART advmod
# быть VERB advcl
# , PUNCT punct
# – PUNCT punct
# значить VERB parataxis
# , PUNCT punct
# и PART advmod
# не PART advmod
# будет VERB ROOT
# … PUNCT punct
#
#
#  SPACE dep
# зачем ADV advmod
# она PRON nsubj
# так ADV advmod
# связала VERB ROOT
# меня PRON obj
# с ADP case
# собою NOUN obl
# , PUNCT punct
# что SCONJ mark
# жизнь NOUN nsubj
# без ADP case
# нее PRON obl
# не PART advmod
# мочь VERB ccomp
# длиться VERB xcomp
# ? PUNCT punct
# если SCONJ mark
# я PRON nsubj
# сказать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# любить VERB ccomp
# ее PRON obj
# – PUNCT punct
# это PRON nsubj
# быть AUX cop
# не PART advmod
# тот DET det
# слово NOUN parataxis
# : PUNCT punct
# не PART advmod
# любить VERB parataxis
# я PRON nsubj
# воздух NOUN obj
# , PUNCT punct
# пища NOUN conj
# , PUNCT punct
# – PUNCT punct
# а CCONJ cc
# жить VERB xcomp
# без ADP case
# них PRON obl
# не PART advmod
# мочь VERB conj
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# слабый ADJ amod
# , PUNCT punct
# слабый ADJ conj
# человек NOUN ccomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# нет VERB ROOT
# сила NOUN nsubj
# сделать VERB nmod
# против ADP case
# себя PRON obl
# , PUNCT punct
# не PART advmod
# страдать VERB conj
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# страдать VERB advcl
# … PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# быть AUX cop
# последний ADJ amod
# год NOUN ROOT
# в ADP case
# москва PROPN nmod
# , PUNCT punct
# когда SCONJ mark
# заболеть VERB advcl
# отец NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# мама NOUN nsubj
# уехать VERB conj
# перед ADP case
# рождество PROPN obl
# . PUNCT punct
# а CCONJ cc
# в ADP case
# конец NOUN obl
# январь NOUN nmod
# я PRON nsubj
# заболеть VERB ROOT
# сам ADJ acl
# , PUNCT punct
# бросить VERB conj
# все PRON obj
# и CCONJ cc
# приехать VERB conj
# домой ADV advmod
# . PUNCT punct
# что PRON nsubj
# ж PART advmod
# , PUNCT punct
# лишний ADJ amod
# год NOUN nsubj
# – PUNCT punct
# так ADV advmod
# лишний ADJ amod
# год NOUN ROOT
# , PUNCT punct
# а CCONJ cc
# заниматься VERB xcomp
# без ADP case
# нее PRON obl
# я PRON nsubj
# все ADV advmod
# равный ADJ fixed
# не PART advmod
# мочь VERB conj
# . PUNCT punct
# я PRON nsubj
# приехать VERB ROOT
# , PUNCT punct
# и CCONJ cc
# мы PRON nsubj
# целый ADJ amod
# вечер NOUN obj
# просидеть VERB conj
# вместе ADV advmod
# на ADP case
# диванчик NOUN obl
# в ADP case
# она DET det
# комната NOUN obl
# и CCONJ cc
# молчать VERB conj
# … PUNCT punct
# но CCONJ cc
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# довольный ADJ ccomp
# . PUNCT punct
# она PRON nsubj
# так ADV advmod
# же PART advmod
# не PART advmod
# мочь VERB ROOT
# жить VERB xcomp
# без ADP case
# меня PRON obl
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# без ADP case
# нее PRON obl
# … PUNCT punct
#
#
#  SPACE dep
# v ADJ obj
#
#  SPACE dep
# я PRON nsubj
# проводить VERB ROOT
# день NOUN obj
# дом NOUN nmod
# и CCONJ cc
# много ADV advmod
# играть VERB conj
# . PUNCT punct
# у ADP case
# меня PRON obl
# быть VERB ROOT
# небольшой ADJ amod
# комната NOUN nsubj
# в ADP case
# одно NUM nummod
# окно NOUN nmod
# , PUNCT punct
# и CCONJ cc
# окно NOUN obj
# это PRON obj
# выходить VERB conj
# на ADP case
# двор NOUN obl
# , PUNCT punct
# к ADP case
# сад NOUN conj
# . PUNCT punct
# я PRON nsubj
# поставить VERB ROOT
# свой DET det
# рояль NOUN obj
# к ADP case
# окно NOUN obl
# и CCONJ cc
# смотреть VERB conj
# на ADP case
# небо NOUN obl
# и CCONJ cc
# на ADP case
# дерево NOUN conj
# , PUNCT punct
# когда SCONJ mark
# играть VERB advcl
# . PUNCT punct
#
#
#  SPACE dep
# в ADP case
# середина NOUN obl
# февраль NOUN nmod
# стать VERB ROOT
# совсем ADV advmod
# уж PART advmod
# тёплый ADJ xcomp
# . PUNCT punct
# я PRON nsubj
# ходить VERB ROOT
# в ADP case
# сад NOUN obl
# и CCONJ cc
# смотреть VERB conj
# на ADP case
# голубой ADJ amod
# небо NOUN obl
# между ADP case
# голый ADJ amod
# ветвь NOUN nmod
# черешня NOUN nmod
# и CCONJ cc
# яблоня NOUN conj
# . PUNCT punct
# какой DET det
# оно PRON nsubj
# было AUX cop
# весёлый ADJ ROOT
# , PUNCT punct
# золотое VERB conj
# между ADP case
# чёрный ADJ amod
# сучьями NOUN obl
# ! PUNCT punct
# а CCONJ cc
# на ADP case
# дальний ADJ amod
# гора NOUN obl
# чуть ADV advmod
# желтеть VERB ROOT
# , PUNCT punct
# даже PART advmod
# ещё ADV advmod
# не PART advmod
# зеленела VERB conj
# , PUNCT punct
# а CCONJ cc
# желтеть VERB conj
# первый ADJ amod
# травка NOUN nsubj
# . PUNCT punct
# она PRON nsubj
# всегда ADV advmod
# из ADP case
# земля NOUN obl
# выходить VERB ROOT
# такой DET det
# светлый ADJ nsubj
# и CCONJ cc
# молодой ADJ conj
# , PUNCT punct
# что PRON nsubj
# казаться VERB parataxis
# жёлтый ADJ xcomp
# . PUNCT punct
# любить VERB ROOT
# я PRON nsubj
# этот DET det
# крошечный ADJ amod
# травинка NOUN obj
# , PUNCT punct
# первый ADJ conj
# ; PUNCT punct
# они PRON nsubj
# – PUNCT punct
# точно ADV advmod
# ребёнок NOUN conj
# , PUNCT punct
# любопытный ADJ conj
# и CCONJ cc
# неловкий ADJ conj
# , PUNCT punct
# подымать VERB conj
# серый ADJ amod
# комок NOUN obj
# земля NOUN nmod
# и CCONJ cc
# глядят VERB conj
# на ADP case
# солнце NOUN obl
# . PUNCT punct
# ах INTJ parataxis
# , PUNCT punct
# мама NOUN ROOT
# … PUNCT punct
# зачем ADV advmod
# она PRON nsubj
# не PART advmod
# ходить VERB ROOT
# со ADP case
# мной PRON obl
# в ADP case
# сад NOUN obl
# и CCONJ cc
# не PART advmod
# любить VERB conj
# того PRON obj
# , PUNCT punct
# что SCONJ obj
# я PRON nsubj
# любить VERB acl
# ? PUNCT punct
# и CCONJ cc
# опять ADV advmod
# холодный ADJ amod
# струя NOUN nsubj
# пробиралась VERB ROOT
# в ADP case
# мой DET det
# сердце NOUN obl
# , PUNCT punct
# опять ADV advmod
# отчуждённость NOUN conj
# … PUNCT punct
#
#
#  SPACE dep
# как ADV advmod
# это PRON nsubj
# странный ADJ ROOT
# ! PUNCT punct
# и CCONJ cc
# как SCONJ advmod
# больно ADV ROOT
# … PUNCT punct
#
#
#  SPACE dep
# Чем SCONJ mark
# далёкий ADV advmod
# идти VERB ROOT
# весна NOUN nsubj
# , PUNCT punct
# тем SCONJ mark
# больше ADV advmod
# я PRON nsubj
# сидеть VERB advcl
# в ADP case
# сад NOUN obl
# , PUNCT punct
# и CCONJ cc
# тем PRON obl
# радостный ADJ amod
# мне PRON iobj
# становиться VERB conj
# . PUNCT punct
# Точно ADV advmod
# я PRON nsubj
# сам ADJ acl
# расти VERB ROOT
# вместе ADV advmod
# с ADP case
# жёлтый ADJ amod
# цвет NOUN obl
# . PUNCT punct
# свой DET det
# фуга NOUN obj
# я PRON nsubj
# ...
# но CCONJ cc
# торжественно ADV advmod
# и CCONJ cc
# серьезно ADV conj
# , PUNCT punct
# и CCONJ cc
# крепкий ADV advmod
# прижиматься VERB conj
# к ADP case
# мне PRON obl
# . PUNCT punct
# я PRON nsubj
# хотеть VERB ROOT
# что PRON obj
# - PRON obj
# то PRON obj
# сказать VERB xcomp
# , PUNCT punct
# но CCONJ cc
# она PRON nsubj
# шепнуть VERB conj
# : PUNCT punct
# " PUNCT punct
# ни CCONJ cc
# слово NOUN parataxis
# " PUNCT punct
# … PUNCT punct
# – PUNCT punct
# и CCONJ cc
# посмотреть VERB parataxis
# умоляющий ADV advmod
# . PUNCT punct
# я PRON nsubj
# замолчать VERB ROOT
# – PUNCT punct
# и CCONJ cc
# рад ADJ parataxis
# быть AUX cop
# молчать VERB xcomp
# . PUNCT punct
# мне PRON iobj
# больше ADV advmod
# ничто PRON obj
# не PART advmod
# хотеться VERB ROOT
# , PUNCT punct
# кроме ADP case
# того PRON obl
# , PUNCT punct
# что PRON nsubj
# быть VERB acl
# . PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# это PRON nsubj
# и PART advmod
# есть AUX cop
# счастие NOUN ccomp
# . PUNCT punct
# весь DET det
# сад NOUN nsubj
# наполнялся VERB ROOT
# новый ADJ amod
# , PUNCT punct
# сильный ADJ conj
# аромат NOUN obl
# . PUNCT punct
# месяц NOUN nsubj
# никнул VERB ROOT
# и CCONJ cc
# уходить VERB conj
# с ADP case
# небо NOUN obl
# , PUNCT punct
# но CCONJ cc
# яблоня NOUN nsubj
# не PART advmod
# темнеть VERB conj
# . PUNCT punct
# они PRON nsubj
# были AUX cop
# белый ADJ ROOT
# не PART advmod
# от ADP case
# лунный ADJ amod
# свет NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# когда SCONJ mark
# пройти VERB advcl
# время NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# все PRON nsubj
# круг NOUN xcomp
# нас PRON obj
# стать VERB ROOT
# ясный ADJ xcomp
# и CCONJ cc
# холодный ADJ conj
# , PUNCT punct
# небо NOUN nsubj
# позеленеть VERB conj
# , PUNCT punct
# и CCONJ cc
# утренний ADJ amod
# сумерки NOUN nsubj
# спуститься VERB conj
# , PUNCT punct
# – PUNCT punct
# я PRON nsubj
# взглянуть VERB parataxis
# близко ADV advmod
# в ADP case
# лицо NOUN obl
# марта PROPN nmod
# , PUNCT punct
# марта PROPN nsubj
# сидеть VERB conj
# все PART obj
# в ADP case
# тот DET det
# же PART advmod
# положение NOUN obl
# , PUNCT punct
# прижаться VERB advcl
# к ADP case
# мне PRON obl
# . PUNCT punct
# она PRON nsubj
# поднять VERB ROOT
# глаз NOUN obj
# и CCONJ cc
# улыбнуться VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# пора NOUN parataxis
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# она PRON nsubj
# . PUNCT punct
# – PUNCT punct
# сейчас ADV advmod
# будет VERB ROOT
# солнце NOUN nsubj
# . PUNCT punct
# яблони PROPN nsubj
# цвести VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# что PRON nsubj
# - PRON nsubj
# то PRON nsubj
# ударить VERB ROOT
# меня PRON obj
# в ADP case
# сердце NOUN obl
# . PUNCT punct
# я PRON nsubj
# вспомнить VERB ROOT
# . PUNCT punct
# я PRON nsubj
# побледнел VERB ROOT
# , PUNCT punct
# в ADP case
# грудь NOUN obl
# стать VERB conj
# тяжёлый ADJ xcomp
# и CCONJ cc
# холодный ADJ conj
# . PUNCT punct
# марта PROPN nsubj
# тревожно ADV advmod
# взглянуть VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# что PRON nsubj
# с ADP case
# тобой PRON parataxis
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# март PROPN parataxis
# . PUNCT punct
# я PRON nsubj
# стать VERB ROOT
# несчастный ADJ xcomp
# … PUNCT punct
# пожалей NOUN ROOT
# меня PRON nmod
# … PUNCT punct
# я PRON nsubj
# уезжать VERB ROOT
# … PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# уезжаешь VERB parataxis
# ? PUNCT punct
# – PUNCT punct
# проговорить VERB parataxis
# она PRON nsubj
# медленно ADV advmod
# , PUNCT punct
# без ADP case
# удивление NOUN conj
# . PUNCT punct
# – PUNCT punct
# так ADV advmod
# рано ADJ ROOT
# ? PUNCT punct
# подождать VERB ROOT
# . PUNCT punct
# ещё ADV advmod
# быть VERB ROOT
# время NOUN nsubj
# . PUNCT punct
# подождать VERB nsubj
# , PUNCT punct
# пока SCONJ mark
# они PRON nsubj
# начать VERB advcl
# осыпаться VERB xcomp
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# не PART advmod
# мочь VERB ROOT
# , PUNCT punct
# не PART advmod
# мочь VERB conj
# … PUNCT punct
# я PRON nsubj
# не PART advmod
# сам ADJ ROOT
# … PUNCT punct
# меня PRON obj
# … PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# ах PROPN parataxis
# , PUNCT punct
# другие ADJ conj
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# она PRON nsubj
# спокойно ADV advmod
# . PUNCT punct
# – PUNCT punct
# они PRON nsubj
# всегда ADV advmod
# мешать VERB ROOT
# , PUNCT punct
# всегда ADV conj
# , PUNCT punct
# в ADP case
# всем PRON conj
# . PUNCT punct
# ступать VERB nsubj
# , PUNCT punct
# не PART advmod
# быть AUX cop
# несчастный ADJ ROOT
# . PUNCT punct
# только PART advmod
# я PRON nsubj
# не PART advmod
# хотеть VERB ROOT
# так ADV advmod
# рано ADV advmod
# … PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# с ADP case
# тоска NOUN obl
# взглянуть VERB ROOT
# в ADP case
# она DET det
# глаз NOUN obl
# . PUNCT punct
# они PRON nsubj:pass
# были AUX aux:pass
# широко ADV advmod
# раскрыть VERB ROOT
# и CCONJ cc
# покойный ADJ conj
# , PUNCT punct
# только PART advmod
# совсем ADV conj
# , PUNCT punct
# до ADP case
# край NOUN conj
# , PUNCT punct
# полный ADJ conj
# слеза NOUN iobj
# . PUNCT punct
# казаться VERB ROOT
# , PUNCT punct
# если SCONJ mark
# она PRON nsubj
# чуть ADV advmod
# пошевельнуть VERB advcl
# ресница NOUN iobj
# или CCONJ cc
# перевести VERB conj
# взгляд NOUN obj
# , PUNCT punct
# слеза NOUN nsubj
# прольются VERB ccomp
# . PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# встать VERB ROOT
# . PUNCT punct
# она PRON nsubj
# остаться VERB ROOT
# на ADP case
# скамейка NOUN obl
# и CCONJ cc
# не PART advmod
# смотреть VERB conj
# на ADP case
# меня PRON obl
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# прощать VERB parataxis
# , PUNCT punct
# март PROPN conj
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# я PRON nsubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# прощать VERB parataxis
# . PUNCT punct
# ты PRON nsubj
# не PART advmod
# забудь VERB ROOT
# … PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# что PRON parataxis
# ? PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# Всего ADV parataxis
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# забыть VERB ROOT
# . PUNCT punct
# мы PRON nsubj
# оба NUM nummod:gov
# теперь ADV advmod
# знать VERB ROOT
# , PUNCT punct
# как ADV advmod
# нужный ADJ ccomp
# жить VERB csubj
# . PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# март PROPN parataxis
# ! PUNCT punct
# но CCONJ cc
# ведь PART advmod
# другие ADJ ROOT
# … PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# да PART parataxis
# , PUNCT punct
# другие ADJ parataxis
# ! PUNCT punct
# а CCONJ cc
# ты PRON nsubj
# не PART advmod
# мочь VERB ROOT
# , PUNCT punct
# ты PRON nsubj
# не PART advmod
# суметь VERB conj
# … PUNCT punct
# Все PART advmod
# - PART advmod
# таки PART advmod
# не PART advmod
# забудь VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# взглянуть VERB ROOT
# на ADP case
# нее PRON obl
# , PUNCT punct
# на ADP discourse
# зелёный ADJ discourse
# , PUNCT punct
# совсем ADV advmod
# светлый ADJ conj
# , PUNCT punct
# небо NOUN obj
# , PUNCT punct
# яблони NOUN conj
# , PUNCT punct
# точно ADV advmod
# осыпать VERB acl
# снег NOUN obl
# , PUNCT punct
# и CCONJ cc
# сказать VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# не PART advmod
# забыть VERB parataxis
# . PUNCT punct
# прощать VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# она PRON nsubj
# кивнуть VERB ROOT
# мне PRON iobj
# голова NOUN obl
# . PUNCT punct
# я PRON nsubj
# уйти VERB ROOT
# . PUNCT punct
#
#
#  SPACE dep
# x ADJ nsubj
#
#  SPACE dep
# что PRON nsubj
# случиться VERB ROOT
# далёкий ADV advmod
# – PUNCT punct
# я PRON nsubj
# рассказать VERB parataxis
# коротко ADV advmod
# и CCONJ cc
# скоро ADV conj
# , PUNCT punct
# мне PRON iobj
# слишком ADV advmod
# тяжёлый ADJ conj
# . PUNCT punct
# она PRON nsubj
# , PUNCT punct
# мама NOUN appos
# , PUNCT punct
# сделать VERB ROOT
# все PRON obj
# нарочно ADV advmod
# , PUNCT punct
# чтобы SCONJ mark
# отомстить VERB advcl
# мне PRON iobj
# , PUNCT punct
# я PRON nsubj
# знать VERB conj
# . PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# она PRON nsubj
# сама ADJ acl
# в ADP case
# этот DET det
# ночь NOUN obl
# похудеть VERB ROOT
# и CCONJ cc
# осунуться VERB conj
# , PUNCT punct
# но CCONJ cc
# я PRON nsubj
# думать VERB conj
# , PUNCT punct
# от ADP case
# сильный ADJ amod
# ненависть NOUN obl
# к ADP case
# мне PRON nmod
# . PUNCT punct
# все PRON nsubj
# тут ADV advmod
# сойтись VERB ROOT
# . PUNCT punct
# да PART cc
# я PRON nsubj
# и PART advmod
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# простить VERB ccomp
# . PUNCT punct
# она PRON nsubj
# не PART advmod
# мочь VERB ROOT
# простить VERB xcomp
# . PUNCT punct
# я PRON nsubj
# и PART advmod
# не PART advmod
# говорить VERB ROOT
# ей PRON iobj
# ничто PRON obj
# . PUNCT punct
# я PRON nsubj
# быть AUX cop
# , PUNCT punct
# как SCONJ mark
# мёртвый ADJ ROOT
# . PUNCT punct
# если SCONJ mark
# б AUX advmod
# она PRON nsubj
# велеть VERB advcl
# мне PRON iobj
# взять VERB xcomp
# револьвер NOUN obj
# и CCONJ cc
# застрелиться VERB conj
# – PUNCT punct
# я PRON nsubj
# бы AUX aux
# , PUNCT punct
# молча ADV parataxis
# , PUNCT punct
# взять VERB ROOT
# револьвер NOUN obj
# и CCONJ cc
# застрелиться VERB conj
# . PUNCT punct
# она PRON nsubj
# велеть VERB ROOT
# мне PRON iobj
# уехать VERB xcomp
# одному NUM iobj
# , PUNCT punct
# сказать VERB conj
# , PUNCT punct
# что SCONJ mark
# никогда ADV advmod
# не PART advmod
# увидеть VERB ccomp
# меня PRON obj
# и CCONJ cc
# не PART advmod
# простить VERB conj
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# она PRON nsubj
# чувствовать VERB ccomp
# , PUNCT punct
# что SCONJ mark
# не PART advmod
# выдержать VERB ccomp
# и CCONJ cc
# простить VERB conj
# , PUNCT punct
# когда SCONJ mark
# увидеть VERB advcl
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# не PART advmod
# мочь VERB ccomp
# жить VERB xcomp
# ; PUNCT punct
# поэтому ADV advmod
# , PUNCT punct
# чтобы SCONJ mark
# не PART advmod
# изменить VERB advcl
# себя PRON iobj
# , PUNCT punct
# она PRON nsubj
# умереть VERB conj
# нарочно ADV advmod
# . PUNCT punct
# да PART parataxis
# , PUNCT punct
# да PART parataxis
# , PUNCT punct
# я PRON nsubj
# не PART advmod
# сомневаться VERB ROOT
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# это PRON obj
# сделать VERB ccomp
# нарочно ADV advmod
# . PUNCT punct
# доктор NOUN nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# у ADP case
# нее PRON obl
# быть VERB ccomp
# дифтерит NOUN nsubj
# , PUNCT punct
# но CCONJ cc
# что PRON fixed
# ж PART advmod
# из ADP case
# это PRON conj
# ? PUNCT punct
# дифтерит NOUN nsubj
# мочь VERB ROOT
# быть VERB xcomp
# , PUNCT punct
# а CCONJ cc
# все PART advmod
# - PART advmod
# таки PART advmod
# она PRON nsubj
# бы AUX aux
# верно ADV advmod
# не PART advmod
# умереть VERB conj
# , PUNCT punct
# если SCONJ mark
# б AUX advmod
# сильно ADV advmod
# хотеть VERB advcl
# не PART advmod
# умереть VERB xcomp
# . PUNCT punct
# я PRON nsubj
# приехать VERB ROOT
# из ADP case
# москва PROPN obl
# на ADP case
# третий ADJ amod
# день NOUN obl
# после ADP case
# смерть NOUN nmod
# . PUNCT punct
# она PRON nsubj
# уже ADV advmod
# стать VERB ROOT
# разлагаться VERB xcomp
# . PUNCT punct
# такой DET det
# уксусный ADJ amod
# и CCONJ cc
# страшный ADJ conj
# запах NOUN nsubj
# идти VERB ROOT
# от ADP case
# нее PRON obl
# . PUNCT punct
# я PRON nsubj
# посмотреть VERB ROOT
# ей PRON iobj
# в ADP case
# лицо NOUN obl
# и CCONJ cc
# ничто PRON obj
# не PART advmod
# сказать VERB conj
# . PUNCT punct
#
#
#  SPACE dep
# какой DET det
# - DET det
# то DET det
# господин NOUN nsubj
# подойти VERB ROOT
# к ADP case
# мне PRON obl
# , PUNCT punct
# долго ADV advmod
# жать VERB conj
# рука NOUN obj
# , PUNCT punct
# просить VERB conj
# подкрепиться VERB xcomp
# и CCONJ cc
# сказать VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# да PART parataxis
# , PUNCT punct
# ваш DET det
# матушка NOUN nsubj
# быть AUX cop
# удивительный ADJ amod
# женщина NOUN parataxis
# . PUNCT punct
# как ADV mark
# вы PRON nsubj:pass
# должный ADJ ROOT
# быть AUX aux:pass
# потрясти VERB xcomp
# ! PUNCT punct
# у ADP case
# вас PRON obl
# были AUX ROOT
# с ADP case
# нею ADV obl
# удивительный ADJ amod
# отношение NOUN nsubj
# … PUNCT punct
#
#
#  SPACE dep
# я PRON nsubj
# неестественно ADV advmod
# рассмеяться VERB conj
# и CCONJ cc
# сказать VERB conj
# : PUNCT punct
#
#
#  SPACE dep
# – PUNCT punct
# да PART parataxis
# , PUNCT punct
# да PART parataxis
# , PUNCT punct
# вы PRON nsubj
# правый ADJ parataxis
# … PUNCT punct
#
#
#  SPACE dep
# и CCONJ cc
# сам ADJ acl
# пожать VERB conj
# рука NOUN obj
# господин NOUN iobj
# . PUNCT punct
#
#
#  SPACE dep
# Потом ADV advmod
# ее PRON obj
# похоронить VERB ROOT
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# уехать VERB conj
# . PUNCT punct
# зачем ADV advmod
# бы AUX aux
# я PRON nsubj
# там ADV advmod
# остаться VERB ROOT
# ? PUNCT punct
# о ADP case
# март PROPN obl
# я PRON nsubj
# не PART advmod
# спросить VERB ROOT
# , PUNCT punct
# в ADP case
# сад NOUN obl
# не PART advmod
# заходить VERB conj
# … PUNCT punct
#
#
#  SPACE dep
# и CCONJ cc
# пройти VERB ROOT
# сколько ADV nummod:gov
# - ADV advmod
# то ADV det
# год NOUN nsubj
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# помнить VERB ROOT
# теперь ADV advmod
# хорошо ADV advmod
# – PUNCT punct
# сколько NUM parataxis
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# помнить VERB ROOT
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# жить VERB ccomp
# . PUNCT punct
# я PRON nsubj
# все PRON det
# стать VERB ROOT
# забывать VERB xcomp
# . PUNCT punct
# пора NOUN advmod
# , PUNCT punct
# впрочем ADV parataxis
# , PUNCT punct
# я PRON nsubj
# вспоминать VERB ROOT
# тот DET det
# ночь NOUN obj
# , PUNCT punct
# когда ADV mark
# распускались VERB acl:relcl
# яблоня NOUN nsubj
# . PUNCT punct
# садиться VERB ROOT
# за ADP case
# рояль NOUN obl
# и CCONJ cc
# играть VERB conj
# маленький ADJ amod
# песенка NOUN obj
# : PUNCT punct
# " PUNCT punct
# ни CCONJ cc
# слово NOUN parataxis
# , PUNCT punct
# о ADP case
# друг PRON parataxis
# мой DET det
# " PUNCT punct
# … PUNCT punct
# мне PRON iobj
# делаться VERB ROOT
# светлый ADJ advmod
# . PUNCT punct
#
#
#  SPACE dep
# но CCONJ cc
# это PRON nsubj
# редко ADV ROOT
# ; PUNCT punct
# я PRON nsubj
# редко ADV advmod
# мочь VERB conj
# вспоминать VERB xcomp
# … PUNCT punct
# и CCONJ cc
# с ADP case
# каждый DET det
# час NOUN obl
# прибавляться VERB ROOT
# тяжесть NOUN nsubj
# жизнь NOUN nmod
# . PUNCT punct
# я PRON nsubj
# жить VERB ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# не PART advmod
# иметь VERB advcl
# сила NOUN obj
# даже PART advmod
# умереть VERB xcomp
# . PUNCT punct
# жить VERB ROOT
# в ADP case
# петербург PROPN obl
# , PUNCT punct
# один DET nummod
# , PUNCT punct
# в ADP case
# тёмный ADJ amod
# и CCONJ cc
# пропахшей ADJ conj
# кухня NOUN amod
# квартира NOUN conj
# , PUNCT punct
# давать VERB conj
# свой DET det
# ненужный ADJ amod
# урок NOUN obj
# музыка NOUN nmod
# и CCONJ cc
# ненужный ADV advmod
# возвращаться VERB conj
# домой ADV advmod
# . PUNCT punct
# сколько NUM nummod:gov
# время NOUN obl
# это PRON nsubj
# ещё ADV advmod
# быть AUX aux
# продолжаться VERB ROOT
# ? PUNCT punct
#
#
#  SPACE dep
# посредине NOUN iobj
# потолок NOUN nmod
# , PUNCT punct
# в ADP case
# большой ADJ amod
# комната NOUN conj
# , PUNCT punct
# быть VERB ROOT
# крюк NOUN nsubj
# … PUNCT punct
# я PRON nsubj
# уж PART advmod
# говорить VERB ROOT
# о ADP case
# нем PRON obl
# . PUNCT punct
# так ADV advmod
# вот PART advmod
# мне PRON iobj
# приходить VERB ROOT
# мысль NOUN nsubj
# : PUNCT punct
# что SCONJ discourse
# , PUNCT punct
# если SCONJ mark
# я PRON nsubj
# принести VERB parataxis
# из ADP case
# передний ADJ amod
# верёвка NOUN obl
# от ADP case
# чемодан NOUN obl
# и CCONJ cc
# закину NOUN conj
# ее PRON obj
# на ADP case
# крюк NOUN obl
# ? PUNCT punct
# ведь PART advmod
# никто PRON nsubj
# даже PART advmod
# и PART advmod
# не PART advmod
# узнавать VERB ROOT
# , PUNCT punct
# особенно ADV advmod
# теперь ADV advmod
# , PUNCT punct
# ночь NOUN conj
# … PUNCT punct
# старуха NOUN nsubj
# , PUNCT punct
# мой DET det
# кухарка NOUN conj
# , PUNCT punct
# спать VERB ROOT
# . PUNCT punct
# и CCONJ cc
# главный ADJ parataxis
# , PUNCT punct
# ничто PRON nsubj
# не PART advmod
# сделаться VERB ROOT
# от ADP case
# того PRON obl
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# закинуть VERB acl
# верёвка NOUN obj
# на ADP case
# крюк NOUN nmod
# . PUNCT punct
# ее PRON iobj
# можно ADV ROOT
# снять VERB csubj
# и CCONJ cc
# снести VERB conj
# обратно ADV advmod
# в ADP case
# передний ADJ obl
# . PUNCT punct
# даже PART advmod
# если SCONJ mark
# я PRON nsubj
# петля NOUN obj
# сделать VERB advcl
# – PUNCT punct
# и CCONJ cc
# то SCONJ mark
# ничто PRON nsubj
# ровно ADV advmod
# не PART advmod
# случиться VERB ROOT
# , PUNCT punct
# ведь SCONJ mark
# не PART advmod
# повеситься VERB advcl
# же PART advmod
# , PUNCT punct
# ведь SCONJ mark
# не PART advmod
# должный ADJ advcl
# же PART advmod
# я PRON nsubj
# , PUNCT punct
# оттого ADV xcomp
# что SCONJ mark
# сделать VERB advcl
# петля NOUN obj
# , PUNCT punct
# непременно ADV advmod
# повеситься VERB conj
# ? PUNCT punct
# это PRON nsubj
# так ADV advmod
# ужасный ADJ ROOT
# , PUNCT punct
# так ADV advmod
# некрасивый ADJ conj
# … PUNCT punct
# как SCONJ mark
# я PRON nsubj
# далеко ADV ROOT
# от ADP case
# марта PROPN obl
# ! PUNCT punct
# .. PUNCT punct
# но CCONJ cc
# разве PART advmod
# я PRON nsubj
# в ADP case
# самом ADJ amod
# дело NOUN ROOT
# ? PUNCT punct
# .. PUNCT punct
# нет PART parataxis
# , PUNCT punct
# нет VERB ROOT
# , PUNCT punct
# я PRON nsubj
# только PART advmod
# попробовать VERB conj
# , PUNCT punct
# никто PRON nsubj
# не PART advmod
# узнавать VERB conj
# , PUNCT punct
# а CCONJ cc
# я PRON nsubj
# попробовать VERB conj
# … PUNCT punct

# %% [markdown]
# ## Practicing with the example text
# When working with languages that have inflection, we typically use `token.lemma_` instead of `token.text` like you'll find in the English examples. This is important when we're counting, so that differently-inflected forms of a word (e.g. masculine vs. feminine or singular vs. plural) aren't counted as if they were different words.

# %%
filepath = "../texts/ru.txt"
document = nlp(open(filepath, encoding="utf-8").read())

# %% [markdown]
# ## Get Adjectives

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |

# %% [markdown]
# To extract and count the adjectives in the example text, we will follow the same model as above, except we'll add an `if` statement that will pull out words only if their POS label matches "ADJ."

# %% [markdown]
# <div class="admonition pythonreview" name="html-admonition" style="background: lightgreen; padding: 10px">
# <p class="title">Python Review</p>
#
# While we demonstrate how to extract parts of speech in the sections below, we're also going to reinforce some integral Python skills. Notice how we use `for` loops and `if` statements to `.append()` specific words to a list. Then we count the words in the list and make a pandas dataframe from the list.
# </div>

# %% [markdown]
# Here we make a list of the adjectives identified in the example text:

# %%
adjs = []
for token in document:
    if token.pos_ == 'ADJ':
        adjs.append(token.lemma_)

# %%
adjs
# Out:
# ['i',
#  'виноватый',
#  'странный',
#  'неодетый',
#  'двадцатиградусный',
#  'хороший',
#  'лёгкий',
#  'последний',
#  'важный',
#  'значительный',
#  'прямой',
#  'унылый',
#  'быстрый',
#  'однообразный',
#  'нужный',
#  'старый',
#  'сам',
#  'красивый',
#  'нежный',
#  'похожий',
#  'больший',
#  'жёлтый',
#  'тёмный',
#  'должный',
#  'последний',
#  'пошлый',
#  'трусливый',
#  'хороший',
#  'порядочный',
#  'хороший',
#  'длинный',
#  'трудный',
#  'холодный',
#  'самые',
#  'обыденный',
#  'скучный',
#  'прекрасный',
#  'сентиментальный',
#  'трудный',
#  'тихий',
#  'глубокий',
#  'пожилой',
#  'первый',
#  'толковый',
#  'маленький',
#  'простой',
#  'малороссийский',
#  'далёкий',
#  'тёмный',
#  'тёплый',
#  'милый',
#  'невольный',
#  'другие',
#  'светлый',
#  'ii',
#  'скучный',
#  'самого',
#  'счастливый',
#  'должный',
#  'печальный',
#  'пожилой',
#  'другой',
#  'молодой',
#  'тоненький',
#  'больший',
#  'чёрный',
#  'свежий',
#  'блестящий',
#  'быстрый',
#  'странный',
#  'самую',
#  'ранний',
#  'необычный',
#  'светлый',
#  'другого',
#  'хороший',
#  'низкий',
#  'тёмный',
#  'равный',
#  'большой',
#  'новый',
#  'неудобный',
#  'холодный',
#  'небольшой',
#  'чистый',
#  'чужой',
#  'бесконечный',
#  'самом',
#  'сама',
#  'хороший',
#  'гимназический',
#  'нарядный',
#  'весёлый',
#  'счастливый',
#  'хорошенький',
#  'похожий',
#  'маленький',
#  'гимназический',
#  'знаменитый',
#  'хороший',
#  'возможный',
#  'влюблены',
#  'должный',
#  'влюблены',
#  'красивый',
#  'похожий',
#  'должный',
#  'сама',
#  'мужской',
#  'чужой',
#  'сама',
#  'похожий',
#  'хороший',
#  'похожий',
#  'сама',
#  'нехороший',
#  'похожий',
#  'красивый',
#  'нежный',
#  'простой',
#  'виноватый',
#  'должный',
#  'большой',
#  'красивый',
#  'бесчисленный',
#  'звенящий',
#  'тамошний',
#  'пошлый',
#  'вечный',
#  'бесцельный',
#  'сам',
#  'чистый',
#  'редкий',
#  'других',
#  'чистый',
#  'чистый',
#  'пошлый',
#  'праздный',
#  'iii',
#  'удивительный',
#  'рад',
#  'старый',
#  'скучный',
#  'хорошенький',
#  'малый',
#  'никитский',
#  'молодой',
#  'странный',
#  'талантливый',
#  'молодой',
#  'должный',
#  'трудный',
#  'нужный',
#  'синий',
#  'больной',
#  'солнечный',
#  'беспокойный',
#  'хороший',
#  'настоящий',
#  'невольный',
#  'молодой',
#  'недовольный',
#  'неважный',
#  'должный',
#  'первый',
#  'первый',
#  'iv',
#  'сам',
#  'довольный',
#  'трескучий',
#  'самое',
#  'тайный',
#  'самое',
#  'тайный',
#  'самое',
#  'глубокий',
#  'равный',
#  'равный',
#  'сам',
#  'умный',
#  'умный',
#  'образованный',
#  'другое',
#  'другая',
#  'необходимый',
#  'нервный',
#  'главный',
#  'слабый',
#  'слабый',
#  'последний',
#  'сам',
#  'лишний',
#  'лишний',
#  'равный',
#  'целый',
#  'довольный',
#  'v',
#  'небольшой',
#  'тёплый',
#  'голубой',
#  'голый',
#  'весёлый',
#  'чёрный',
#  'дальний',
#  'первый',
#  'светлый',
#  'молодой',
#  'жёлтый',
#  'крошечный',
#  'первый',
#  'любопытный',
#  'неловкий',
#  'серый',
#  'холодный',
#  'странный',
#  'радостный',
#  'сам',
#  'жёлтый',
#  'светлый',
#  'весенний',
#  'весенний',
#  'круглый',
#  'крепкий',
#  'нужный',
#  'нужный',
#  'страшный',
#  'узенький',
#  'сырой',
#  'низкий',
#  'самого',
#  'дальний',
#  'живой',
#  'чёрный',
#  'чужой',
#  'обрывистый',
#  'глубокий',
#  'сизый',
#  'чужой',
#  'связный',
#  'высоко',
#  'равный',
#  'весенний',
#  'спокойный',
#  'чужой',
#  'беспокойный',
#  'равнодушный',
#  'хороший',
#  'видный',
#  'первый',
#  'странный',
#  'обыкновенный',
#  'маскарадный',
#  'простой',
#  'возможный',
#  'широкий',
#  'мягкий',
#  'белый',
#  'широкий',
#  'другой',
#  'узкий',
#  'темно',
#  '-',
#  'красный',
#  'странный',
#  'длинный',
#  'небрежный',
#  'красивый',
#  'узкий',
#  'длинный',
#  'воспитанный',
#  'молодой',
#  'другими',
#  'странный',
#  'красивый',
#  'сама',
#  'русский',
#  'русский',
#  'слепой',
#  'богатый',
#  'молоденький',
#  'красивый',
#  'красивый',
#  'красивый',
#  'красивый',
#  'нежный',
#  'душистый',
#  'розовый',
#  'предвечерний',
#  'связный',
#  'последний',
#  'странный',
#  'противный',
#  'резкий',
#  'определённый',
#  'первый',
#  'настоящий',
#  'vi',
#  'сам',
#  'должный',
#  'бледный',
#  'больший',
#  'третий',
#  'слабый',
#  'твёрдый',
#  'жёлтый',
#  'крошечный',
#  'зелёный',
#  'знакомый',
#  'красный',
#  'золотой',
#  'равный',
#  'розовый',
#  'странный',
#  'тёмный',
#  'яркий',
#  'простой',
#  'небрежный',
#  'бледный',
#  'тонкий',
#  'продолговатый',
#  'бледный',
#  'прозрачный',
#  'чистый',
#  'синий',
#  'тоненький',
#  'прямой',
#  'светло',
#  '-',
#  'розовый',
#  'рад',
#  'полный',
#  'хороший',
#  'резкий',
#  'составной',
#  'разный',
#  'хороший',
#  'верный',
#  'простой',
#  'нескорый',
#  'хороший',
#  'непонятный',
#  'петербургской',
#  'тёмный',
#  'черно',
#  '-',
#  'серый',
#  'большой',
#  'угрюмый',
#  'ужасный',
#  'гадкий',
#  'невозможный',
#  'другого',
#  'случайный',
#  'случайный',
#  'трудный',
#  'другие',
#  'второй',
#  'тихий',
#  'простой',
#  'несложный',
#  'лишний',
#  'весенний',
#  'жёлтый',
#  'вечерний',
#  'сам',
#  'хороший',
#  'тёмный',
#  'светлый',
#  'неясный',
#  'молодой',
#  'должный',
#  'хороший',
#  'первый',
#  'первый',
#  'vii',
#  'последний',
#  'нужный',
#  'сам',
#  'вялый',
#  'бледный',
#  'потемневшими',
#  'неожиданный',
#  'следующий',
#  'больший',
#  'собственный',
#  'большой',
#  'неожиданный',
#  'бессмысленный',
#  'безнадёжный',
#  'первый',
#  'лёгкий',
#  'влюблен',
#  'должный',
#  'должный',
#  'безумный',
#  'умный',
#  'сам',
#  'безнадёжный',
#  'инстинктивный',
#  'готовый',
#  'тяжёлый',
#  'хороший',
#  'сам',
#  'таковы',
#  'пассивно',
#  '-',
#  'нежный',
#  'последний',
#  'сама',
#  'дурной',
#  'равный',
#  'справедливый',
#  'способный',
#  'злорадный',
#  'странный',
#  'должный',
#  'слабенький',
#  'хороший',
#  'должный',
#  'тяжёлый',
#  'viii',
#  'больной',
#  'сама',
#  'мёртвый',
#  'полузакрытыми',
#  'равный',
#  'круглый',
#  'большой',
#  'серый',
#  'угловой',
#  '-',
#  'полоцким',
#  'полоцким',
#  'здоровый',
#  'жестокий',
#  'больший',
#  'сильный',
#  'неизбежный',
#  'ix',
#  'лёгкий',
#  'радостный',
#  'смешанный',
#  'разнородный',
#  'разнотонный',
#  'стыдный',
#  'белый',
#  'розовый',
#  'должный',
#  'белый',
#  'маленький',
#  'высоко',
#  'сами',
#  'рад',
#  'короткий',
#  'робкий',
#  'неумелый',
#  'неясный',
#  'крепкий',
#  'безмолвный',
#  'неподвижный',
#  'видный',
#  'невидный',
#  'лунный',
#  'высоко',
#  'холодный',
#  'страшный',
#  'жуткий',
#  'холодный',
#  'близкий',
#  'спокойный',
#  'бледный',
#  'должный',
#  'должный',
#  'близкий',
#  'близкий',
#  'новый',
#  'неясный',
#  'первый',
#  'другие',
#  'рад',
#  'новый',
#  'сильный',
#  'белый',
#  'лунный',
#  'ясный',
#  'холодный',
#  'утренний',
#  'тяжёлый',
#  'холодный',
#  'несчастный',
#  'рано',
#  'сам',
#  'другие',
#  'несчастный',
#  'покойный',
#  'полный',
#  'нужный',
#  'другие',
#  'другие',
#  'зелёный',
#  'светлый',
#  'x',
#  'тяжёлый',
#  'сама',
#  'сильный',
#  'мёртвый',
#  'третий',
#  'уксусный',
#  'страшный',
#  'удивительный',
#  'должный',
#  'удивительный',
#  'правый',
#  'сам',
#  'маленький',
#  'светлый',
#  'тёмный',
#  'пропахшей',
#  'ненужный',
#  'большой',
#  'передний',
#  'главный',
#  'передний',
#  'должный',
#  'ужасный',
#  'некрасивый',
#  'самом']

# %% [markdown]
# Then we count the unique adjectives in this list with the `Counter()` module:

# %%
adjs_tally = Counter(adjs)

# %%
adjs_tally.most_common()
# Out:
# [('должный', 18),
#  ('хороший', 16),
#  ('сам', 13),
#  ('первый', 11),
#  ('странный', 10),
#  ('красивый', 10),
#  ('равный', 8),
#  ('сама', 8),
#  ('тёмный', 7),
#  ('холодный', 7),
#  ('светлый', 7),
#  ('молодой', 7),
#  ('последний', 6),
#  ('нужный', 6),
#  ('похожий', 6),
#  ('простой', 6),
#  ('другие', 6),
#  ('большой', 6),
#  ('больший', 5),
#  ('жёлтый', 5),
#  ('чистый', 5),
#  ('чужой', 5),
#  ('-', 5),
#  ('бледный', 5),
#  ('нежный', 4),
#  ('трудный', 4),
#  ('маленький', 4),
#  ('рад', 4),
#  ('весенний', 4),
#  ('белый', 4),
#  ('розовый', 4),
#  ('тяжёлый', 4),
#  ('лёгкий', 3),
#  ('пошлый', 3),
#  ('длинный', 3),
#  ('скучный', 3),
#  ('глубокий', 3),
#  ('чёрный', 3),
#  ('новый', 3),
#  ('удивительный', 3),
#  ('самое', 3),
#  ('умный', 3),
#  ('слабый', 3),
#  ('лишний', 3),
#  ('серый', 3),
#  ('страшный', 3),
#  ('высоко', 3),
#  ('неясный', 3),
#  ('сильный', 3),
#  ('близкий', 3),
#  ('виноватый', 2),
#  ('прямой', 2),
#  ('быстрый', 2),
#  ('старый', 2),
#  ('тихий', 2),
#  ('пожилой', 2),
#  ('тёплый', 2),
#  ('невольный', 2),
#  ('самого', 2),
#  ('счастливый', 2),
#  ('другой', 2),
#  ('тоненький', 2),
#  ('другого', 2),
#  ('низкий', 2),
#  ('небольшой', 2),
#  ('самом', 2),
#  ('гимназический', 2),
#  ('весёлый', 2),
#  ('хорошенький', 2),
#  ('возможный', 2),
#  ('влюблены', 2),
#  ('синий', 2),
#  ('больной', 2),
#  ('беспокойный', 2),
#  ('настоящий', 2),
#  ('довольный', 2),
#  ('тайный', 2),
#  ('главный', 2),
#  ('дальний', 2),
#  ('крошечный', 2),
#  ('радостный', 2),
#  ('круглый', 2),
#  ('крепкий', 2),
#  ('связный', 2),
#  ('спокойный', 2),
#  ('видный', 2),
#  ('широкий', 2),
#  ('узкий', 2),
#  ('красный', 2),
#  ('небрежный', 2),
#  ('русский', 2),
#  ('резкий', 2),
#  ('третий', 2),
#  ('зелёный', 2),
#  ('полный', 2),
#  ('ужасный', 2),
#  ('случайный', 2),
#  ('неожиданный', 2),
#  ('безнадёжный', 2),
#  ('мёртвый', 2),
#  ('полоцким', 2),
#  ('лунный', 2),
#  ('несчастный', 2),
#  ('передний', 2),
#  ('i', 1),
#  ('неодетый', 1),
#  ('двадцатиградусный', 1),
#  ('важный', 1),
#  ('значительный', 1),
#  ('унылый', 1),
#  ('однообразный', 1),
#  ('трусливый', 1),
#  ('порядочный', 1),
#  ('самые', 1),
#  ('обыденный', 1),
#  ('прекрасный', 1),
#  ('сентиментальный', 1),
#  ('толковый', 1),
#  ('малороссийский', 1),
#  ('далёкий', 1),
#  ('милый', 1),
#  ('ii', 1),
#  ('печальный', 1),
#  ('свежий', 1),
#  ('блестящий', 1),
#  ('самую', 1),
#  ('ранний', 1),
#  ('необычный', 1),
#  ('неудобный', 1),
#  ('бесконечный', 1),
#  ('нарядный', 1),
#  ('знаменитый', 1),
#  ('мужской', 1),
#  ('нехороший', 1),
#  ('бесчисленный', 1),
#  ('звенящий', 1),
#  ('тамошний', 1),
#  ('вечный', 1),
#  ('бесцельный', 1),
#  ('редкий', 1),
#  ('других', 1),
#  ('праздный', 1),
#  ('iii', 1),
#  ('малый', 1),
#  ('никитский', 1),
#  ('талантливый', 1),
#  ('солнечный', 1),
#  ('недовольный', 1),
#  ('неважный', 1),
#  ('iv', 1),
#  ('трескучий', 1),
#  ('образованный', 1),
#  ('другое', 1),
#  ('другая', 1),
#  ('необходимый', 1),
#  ('нервный', 1),
#  ('целый', 1),
#  ('v', 1),
#  ('голубой', 1),
#  ('голый', 1),
#  ('любопытный', 1),
#  ('неловкий', 1),
#  ('узенький', 1),
#  ('сырой', 1),
#  ('живой', 1),
#  ('обрывистый', 1),
#  ('сизый', 1),
#  ('равнодушный', 1),
#  ('обыкновенный', 1),
#  ('маскарадный', 1),
#  ('мягкий', 1),
#  ('темно', 1),
#  ('воспитанный', 1),
#  ('другими', 1),
#  ('слепой', 1),
#  ('богатый', 1),
#  ('молоденький', 1),
#  ('душистый', 1),
#  ('предвечерний', 1),
#  ('противный', 1),
#  ('определённый', 1),
#  ('vi', 1),
#  ('твёрдый', 1),
#  ('знакомый', 1),
#  ('золотой', 1),
#  ('яркий', 1),
#  ('тонкий', 1),
#  ('продолговатый', 1),
#  ('прозрачный', 1),
#  ('светло', 1),
#  ('составной', 1),
#  ('разный', 1),
#  ('верный', 1),
#  ('нескорый', 1),
#  ('непонятный', 1),
#  ('петербургской', 1),
#  ('черно', 1),
#  ('угрюмый', 1),
#  ('гадкий', 1),
#  ('невозможный', 1),
#  ('второй', 1),
#  ('несложный', 1),
#  ('вечерний', 1),
#  ('vii', 1),
#  ('вялый', 1),
#  ('потемневшими', 1),
#  ('следующий', 1),
#  ('собственный', 1),
#  ('бессмысленный', 1),
#  ('влюблен', 1),
#  ('безумный', 1),
#  ('инстинктивный', 1),
#  ('готовый', 1),
#  ('таковы', 1),
#  ('пассивно', 1),
#  ('дурной', 1),
#  ('справедливый', 1),
#  ('способный', 1),
#  ('злорадный', 1),
#  ('слабенький', 1),
#  ('viii', 1),
#  ('полузакрытыми', 1),
#  ('угловой', 1),
#  ('здоровый', 1),
#  ('жестокий', 1),
#  ('неизбежный', 1),
#  ('ix', 1),
#  ('смешанный', 1),
#  ('разнородный', 1),
#  ('разнотонный', 1),
#  ('стыдный', 1),
#  ('сами', 1),
#  ('короткий', 1),
#  ('робкий', 1),
#  ('неумелый', 1),
#  ('безмолвный', 1),
#  ('неподвижный', 1),
#  ('невидный', 1),
#  ('жуткий', 1),
#  ('ясный', 1),
#  ('утренний', 1),
#  ('рано', 1),
#  ('покойный', 1),
#  ('x', 1),
#  ('уксусный', 1),
#  ('правый', 1),
#  ('пропахшей', 1),
#  ('ненужный', 1),
#  ('некрасивый', 1)]

# %% [markdown]
# Then we make a dataframe from this list:

# %%
df = pd.DataFrame(adjs_tally.most_common(), columns=['adj', 'count'])
df[:100]
# Out:
#               adj  count
# 0         должный     18
# 1         хороший     16
# 2             сам     13
# 3          первый     11
# 4        странный     10
# 5        красивый     10
# 6          равный      8
# 7            сама      8
# 8          тёмный      7
# 9        холодный      7
# 10        светлый      7
# 11        молодой      7
# 12      последний      6
# 13         нужный      6
# 14        похожий      6
# 15        простой      6
# 16         другие      6
# 17        большой      6
# 18        больший      5
# 19         жёлтый      5
# 20         чистый      5
# 21          чужой      5
# 22              -      5
# 23        бледный      5
# 24         нежный      4
# 25        трудный      4
# 26      маленький      4
# 27            рад      4
# 28       весенний      4
# 29          белый      4
# 30        розовый      4
# 31        тяжёлый      4
# 32         лёгкий      3
# 33         пошлый      3
# 34        длинный      3
# 35        скучный      3
# 36       глубокий      3
# 37         чёрный      3
# 38          новый      3
# 39   удивительный      3
# 40          самое      3
# 41          умный      3
# 42         слабый      3
# 43         лишний      3
# 44          серый      3
# 45       страшный      3
# 46         высоко      3
# 47        неясный      3
# 48        сильный      3
# 49        близкий      3
# 50      виноватый      2
# 51         прямой      2
# 52        быстрый      2
# 53         старый      2
# 54          тихий      2
# 55        пожилой      2
# 56         тёплый      2
# 57      невольный      2
# 58         самого      2
# 59     счастливый      2
# 60         другой      2
# 61      тоненький      2
# 62        другого      2
# 63         низкий      2
# 64      небольшой      2
# 65          самом      2
# 66  гимназический      2
# 67        весёлый      2
# 68    хорошенький      2
# 69      возможный      2
# 70       влюблены      2
# 71          синий      2
# 72        больной      2
# 73    беспокойный      2
# 74      настоящий      2
# 75      довольный      2
# 76         тайный      2
# 77        главный      2
# 78        дальний      2
# 79      крошечный      2
# 80      радостный      2
# 81        круглый      2
# 82        крепкий      2
# 83        связный      2
# 84      спокойный      2
# 85         видный      2
# 86        широкий      2
# 87          узкий      2
# 88        красный      2
# 89      небрежный      2
# 90        русский      2
# 91         резкий      2
# 92         третий      2
# 93        зелёный      2
# 94         полный      2
# 95        ужасный      2
# 96      случайный      2
# 97    неожиданный      2
# 98    безнадёжный      2
# 99        мёртвый      2

# %% [markdown]
# ## Get Nouns

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |

# %% [markdown]
# To extract and count nouns, we can follow the same model as above, except we will change our `if` statement to check for POS labels that match "NOUN".

# %%
nouns = []
for token in document:
    if token.pos_ == 'NOUN':
        nouns.append(token.lemma_)

nouns_tally = Counter(nouns)

df = pd.DataFrame(nouns_tally.most_common(), columns=['noun', 'count'])
df[:100]
# Out:
#              noun  count
# 0            мама     31
# 1             сад     31
# 2            небо     16
# 3            глаз     15
# 4            день     14
# 5             раз     13
# 6           слово     12
# 7         человек     11
# 8             год     10
# 9          солнце     10
# 10       изгородь     10
# 11          жизнь      9
# 12         платье      9
# 13          весна      9
# 14         яблоня      9
# 15           рука      8
# 16          время      8
# 17         минута      8
# 18           лицо      7
# 19         сердце      7
# 20           отец      7
# 21          вечер      7
# 22        комната      7
# 23        барышня      7
# 24           сила      7
# 25           окно      7
# 26         цветок      7
# 27        счастие      6
# 28           пора      6
# 29         воздух      6
# 30           свет      6
# 31        женщина      6
# 32          земля      6
# 33          мысль      5
# 34           душа      5
# 35            дом      5
# 36          запах      5
# 37         музыка      5
# 38         дерево      5
# 39         голова      5
# 40        дорожка      5
# 41          шорох      5
# 42            час      5
# 43          месяц      5
# 44        чувство      4
# 45       господин      4
# 46      отношение      4
# 47       квартира      4
# 48  консерватория      4
# 49           цвет      4
# 50          конец      4
# 51          рояль      4
# 52            луч      4
# 53       скамейка      4
# 54            шаг      4
# 55           ночь      4
# 56          мотив      4
# 57           утро      4
# 58           крюк      4
# 59           мать      3
# 60           фуга      3
# 61   воспоминание      3
# 62       прелюдия      3
# 63        концерт      3
# 64          слеза      3
# 65        ребёнок      3
# 66           двор      3
# 67           дело      3
# 68         одежда      3
# 69           гора      3
# 70          почка      3
# 71           тень      3
# 72           пояс      3
# 73           звук      3
# 74          голос      3
# 75          шёпот      3
# 76         яблони      3
# 77   возлюбленной      2
# 78       половина      2
# 79         дорога      2
# 80         борода      2
# 81           воля      2
# 82         тишина      2
# 83        песенка      2
# 84         облако      2
# 85        прошлое      2
# 86        мальчик      2
# 87          театр      2
# 88           урок      2
# 89       движение      2
# 90          целое      2
# 91        сторона      2
# 92          книга      2
# 93        экзамен      2
# 94        желание      2
# 95         многие      2
# 96         многое      2
# 97       экономка      2
# 98      профессор      2
# 99          волос      2

# %% [markdown]
# ## Get Verbs

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |

# %% [markdown]
# To extract and count works of art, we can follow a similar-ish model to the examples above. This time, however, we're going to make our code even more economical and efficient (while still changing our `if` statement to match the POS label "VERB").

# %% [markdown]
# <div class="admonition pythonreview" name="html-admonition" style="background: lightgreen; padding: 10px">
# <p class="title">Python Review</p>
#
# We can use a [*list comprehension*](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Python/More-Lists-Loops.html#List-Comprehensions) to get our list of verbs in a single line of code! Closely examine the first line of code below:
# </div>

# %%
verbs = [token.lemma_ for token in document if token.pos_ == 'VERB']

verbs_tally = Counter(verbs)

df = pd.DataFrame(verbs_tally.most_common(), columns=['verb', 'count'])
df[:100]
# Out:
#             verb  count
# 0           мочь     49
# 1          знать     47
# 2           быть     45
# 3        сказать     37
# 4       говорить     31
# 5         думать     27
# 6         любить     25
# 7          стать     24
# 8           жить     20
# 9       казаться     20
# 10        хотеть     19
# 11        играть     16
# 12      смотреть     16
# 13       сделать     14
# 14   чувствовать     13
# 15          идти     12
# 16           нет     11
# 17        понять     11
# 18         пойти     10
# 19        видеть     10
# 20       умереть      9
# 21      понимать      9
# 22      спросить      9
# 23    заниматься      8
# 24     нравиться      8
# 25        сидеть      8
# 26         ждать      7
# 27        забыть      7
# 28        встать      7
# 29          уйти      7
# 30      простить      7
# 31       слышать      7
# 32        прийти      7
# 33       молчать      7
# 34      хотеться      6
# 35       увидеть      6
# 36        бывать      6
# 37      выходить      6
# 38        гулять      6
# 39        ходить      6
# 40         будет      6
# 41        пройти      6
# 42     вспомнить      6
# 43     приходить      6
# 44       помнить      6
# 45     взглянуть      6
# 46  рассказывать      5
# 47       слушать      5
# 48      делаться      5
# 49        уехать      5
# 50       подойти      5
# 51         уметь      4
# 52         иметь      4
# 53       бояться      4
# 54     ухаживать      4
# 55    измениться      4
# 56       поехать      4
# 57     прибавить      4
# 58      подумать      4
# 59    вспоминать      4
# 60      страдать      4
# 61      услышать      4
# 62    посмотреть      4
# 63   проговорить      4
# 64       прощать      4
# 65    показаться      4
# 66         сесть      4
# 67     случиться      4
# 68      остаться      4
# 69      написать      3
# 70       умирать      3
# 71    рассказать      3
# 72         дойти      3
# 73    покориться      3
# 74        верить      3
# 75        давать      3
# 76     стыдиться      3
# 77        делать      3
# 78       бросить      3
# 79        скрыть      3
# 80   сомневаться      3
# 81       учиться      3
# 82         ехать      3
# 83      садиться      3
# 84        суметь      3
# 85       увидать      3
# 86         смочь      3
# 87       плакать      3
# 88      приехать      3
# 89    испугаться      3
# 90        стоять      3
# 91     удивиться      3
# 92       уходить      3
# 93         взять      3
# 94    продолжать      3
# 95     повторить      3
# 96      жениться      3
# 97         ожить      3
# 98        обнять      3
# 99  распуститься      3

# %% [markdown]
# # Keyword Extraction

# %% [markdown]
# ## Get Sentences with Keyword

# %% [markdown]
# spaCy can also identify sentences in a document. To access sentences, we can iterate through `document.sents` and pull out the `.text` of each sentence.

# %% [markdown]
# We can use spaCy's sentence-parsing capabilities to extract sentences that contain particular keywords, such as in the function below. Note that the function assumes that the keyword provided will be exactly the same as it appears in the text.
#
# With the function `find_sentences_with_keyword()`, we will iterate through `document.sents` and pull out any sentence that contains a particular "keyword." Then we will display these sentence with the keywords bolded.

# %%
import re
from IPython.display import Markdown, display

# %%
def find_sentences_with_keyword(keyword, document):
    
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        sentence = sentence.text
        
        #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
        if keyword.lower() in sentence.lower():
            
            #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
            sentence = re.sub('\n', ' ', sentence)
            sentence = re.sub(f"{keyword}", f"**{keyword}**", sentence, flags=re.IGNORECASE)
            
            display(Markdown(sentence))

# %%
find_sentences_with_keyword(keyword="хороший", document=document)
# Out:
# Я музыкант и если не **хороший**, то порядочный, как говорят.

# %% [markdown]
# ## Get Keyword in Context

# %% [markdown]
# We can also find out about a keyword's more immediate context — its neighboring words to the left and right — and we can fine-tune our search with POS tagging.
#
# To do so, we will first create a list of what's called *ngrams*. "Ngrams" are any sequence of *n* tokens in a text. They're an important concept in computational linguistics and NLP. (Have you ever played with [Google's *Ngram* Viewer](https://books.google.com/ngrams)?)
#
# Below we're going to make a list of *bigrams*, that is, all the two-word combinations from the sample text. We're going to use these bigrams to find the neighboring words that appear alongside particular keywords.

# %%
#Make a list of tokens and POS labels from document if the token is a word 
tokens_and_labels = [(token.text, token.pos_) for token in document if token.is_alpha]

# %%
#Make a function to get all two-word combinations
def get_bigrams(word_list, number_consecutive_words=2):
    
    ngrams = []
    adj_length_of_word_list = len(word_list) - (number_consecutive_words - 1)
    
    #Loop through numbers from 0 to the (slightly adjusted) length of your word list
    for word_index in range(adj_length_of_word_list):
        
        #Index the list at each number, grabbing the word at that number index as well as N number of words after it
        ngram = word_list[word_index : word_index + number_consecutive_words]
        
        #Append this word combo to the master list "ngrams"
        ngrams.append(ngram)
        
    return ngrams

# %%
bigrams = get_bigrams(tokens_and_labels)

# %% [markdown]
# Let's take a peek at the bigrams:

# %%
bigrams[5:20]
# Out:
# [[('так', 'ADV'), ('сделала', 'VERB')],
#  [('сделала', 'VERB'), ('что', 'SCONJ')],
#  [('что', 'SCONJ'), ('я', 'PRON')],
#  [('я', 'PRON'), ('не', 'PART')],
#  [('не', 'PART'), ('умею', 'VERB')],
#  [('умею', 'VERB'), ('жить', 'VERB')],
#  [('жить', 'VERB'), ('без', 'ADP')],
#  [('без', 'ADP'), ('нее', 'PRON')],
#  [('нее', 'PRON'), ('Это', 'PRON')],
#  [('Это', 'PRON'), ('она', 'PRON')],
#  [('она', 'PRON'), ('сделала', 'VERB')],
#  [('сделала', 'VERB'), ('я', 'PRON')],
#  [('я', 'PRON'), ('не', 'PART')],
#  [('не', 'PART'), ('виноват', 'ADJ')],
#  [('виноват', 'ADJ'), ('Я', 'PRON')]]

# %% [markdown]
# Now that we have our list of bigrams, we're going to make a function `get_neighbor_words()`. This function will return the most frequent words that appear next to a particular keyword. The function can also be fine-tuned to return neighbor words that match a certain part of speech by changing the `pos_label` parameter.

# %%
def get_neighbor_words(keyword, bigrams, pos_label = None):
    
    neighbor_words = []
    keyword = keyword.lower()
    
    for bigram in bigrams:
        
        #Extract just the lowercased words (not the labels) for each bigram
        words = [word.lower() for word, label in bigram]        
        
        #Check to see if keyword is in the bigram
        if keyword in words:
            
            for word, label in bigram:
                
                #Now focus on the neighbor word, not the keyword
                if word.lower() != keyword:
                    #If the neighbor word matches the right pos_label, append it to the master list
                    if label == pos_label or pos_label == None:
                        neighbor_words.append(word.lower())
    
    return Counter(neighbor_words).most_common()

# %%
get_neighbor_words("сад", bigrams)
# Out:
# [('в', 9),
#  ('и', 6),
#  ('не', 4),
#  ('там', 2),
#  ('как', 2),
#  ('теплый', 1),
#  ('чистый', 1),
#  ('к', 1),
#  ('мой', 1),
#  ('оживший', 1),
#  ('то', 1),
#  ('я', 1),
#  ('люблю', 1),
#  ('увидеть', 1),
#  ('весну', 1),
#  ('ix', 1),
#  ('весь', 1),
#  ('наполнялся', 1)]

# %%
get_neighbor_words("сад", bigrams, pos_label='VERB')
# Out:
# [('оживший', 1), ('люблю', 1), ('увидеть', 1), ('наполнялся', 1)]

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# Try out `find_sentences_with_keyword()` and `get_neighbor_words` with your own keywords of interest.

# %%
find_sentences_with_keyword(keyword="оживший", document=document)
# Out:
# Говорил о саде, о весне, о яблонях, о Марте, и что Марта для меня – **оживший** сад, то же, что небо и ветер…

# %%
get_neighbor_words("оживший", bigrams, pos_label=None)
# Out:
# [('меня', 1), ('сад', 1)]
