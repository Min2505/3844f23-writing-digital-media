# %% [markdown]
# # Text Pre-Processing for Portuguese

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# This lesson is for anyone who wants to try the [TF-IDF](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/TF-IDF.html) or [topic modeling](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/Topic-Modeling.html) lessons on Portuguese texts. Before continuing with those lessons, you need to create a *lemmatized derivative* of your original Portuguese text, which replaces all the words with their dictionary form, which will work much better with the word-count based methods.

# %% [markdown]
# ## Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ## Download Language Model

# %%
# !python -m spacy download pt_core_news_md
# Out:
# Collecting pt-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_md-3.7.0/pt_core_news_md-3.7.0-py3-none-any.whl (42.4 MB)
#      ---------------------------------------- 0.0/42.4 MB ? eta -:--:--
#      ---------------------------------------- 0.1/42.4 MB 2.6 MB/s eta 0:00:16
#      ---------------------------------------- 0.3/42.4 MB 4.2 MB/s eta 0:00:11
#       --------------------------------------- 0.8/42.4 MB 6.4 MB/s eta 0:00:07
#      - -------------------------------------- 1.9/42.4 MB 11.3 MB/s eta 0:00:04
#      -- ------------------------------------- 3.0/42.4 MB 13.9 MB/s eta 0:00:03
#      --- ------------------------------------ 4.0/42.4 MB 15.1 MB/s eta 0:00:03
#      ---- ----------------------------------- 5.1/42.4 MB 16.2 MB/s eta 0:00:03
#      ----- ---------------------------------- 5.9/42.4 MB 16.5 MB/s eta 0:00:03
#      ------ --------------------------------- 7.1/42.4 MB 17.6 MB/s eta 0:00:03
#      ------- -------------------------------- 8.1/42.4 MB 17.8 MB/s eta 0:00:02
#      ------- -------------------------------- 8.4/42.4 MB 17.4 MB/s eta 0:00:02
#      --------- ------------------------------ 9.6/42.4 MB 17.6 MB/s eta 0:00:02
#      --------- ------------------------------ 9.8/42.4 MB 18.0 MB/s eta 0:00:02
#      --------- ------------------------------ 9.8/42.4 MB 18.0 MB/s eta 0:00:02
#      ----------- --------------------------- 12.1/42.4 MB 19.8 MB/s eta 0:00:02
#      ------------ -------------------------- 13.1/42.4 MB 19.9 MB/s eta 0:00:02
#      ------------- ------------------------- 14.3/42.4 MB 20.5 MB/s eta 0:00:02
#      -------------- ------------------------ 15.4/42.4 MB 20.5 MB/s eta 0:00:02
#      --------------- ----------------------- 16.5/42.4 MB 21.1 MB/s eta 0:00:02
#      ---------------- ---------------------- 17.7/42.4 MB 21.1 MB/s eta 0:00:02
#      ----------------- --------------------- 18.8/42.4 MB 22.6 MB/s eta 0:00:02
#      ------------------ -------------------- 19.9/42.4 MB 22.5 MB/s eta 0:00:01
#      ------------------- ------------------- 21.0/42.4 MB 26.2 MB/s eta 0:00:01
#      ------------------- ------------------- 21.7/42.4 MB 23.4 MB/s eta 0:00:01
#      -------------------- ------------------ 22.6/42.4 MB 22.6 MB/s eta 0:00:01
#      --------------------- ----------------- 23.4/42.4 MB 22.6 MB/s eta 0:00:01
#      --------------------- ----------------- 23.6/42.4 MB 21.8 MB/s eta 0:00:01
#      --------------------- ----------------- 23.8/42.4 MB 18.7 MB/s eta 0:00:01
#      ----------------------- --------------- 26.0/42.4 MB 20.5 MB/s eta 0:00:01
#      ------------------------ -------------- 27.1/42.4 MB 20.5 MB/s eta 0:00:01
#      ------------------------- ------------- 28.2/42.4 MB 20.5 MB/s eta 0:00:01
#      -------------------------- ------------ 29.3/42.4 MB 20.5 MB/s eta 0:00:01
#      --------------------------- ----------- 30.3/42.4 MB 20.5 MB/s eta 0:00:01
#      ---------------------------- ---------- 31.4/42.4 MB 21.1 MB/s eta 0:00:01
#      ----------------------------- --------- 32.5/42.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------ -------- 33.5/42.4 MB 21.8 MB/s eta 0:00:01
#      ------------------------------- ------- 34.6/42.4 MB 25.1 MB/s eta 0:00:01
#      -------------------------------- ------ 35.7/42.4 MB 22.5 MB/s eta 0:00:01
#      --------------------------------- ----- 36.7/42.4 MB 23.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 37.8/42.4 MB 23.4 MB/s eta 0:00:01
#      ----------------------------------- --- 39.0/42.4 MB 23.4 MB/s eta 0:00:01
#      ------------------------------------ -- 39.4/42.4 MB 22.6 MB/s eta 0:00:01
#      ------------------------------------- - 40.3/42.4 MB 21.9 MB/s eta 0:00:01
#      ------------------------------------- - 41.2/42.4 MB 21.8 MB/s eta 0:00:01
#      --------------------------------------  42.0/42.4 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------  42.4/42.4 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  42.4/42.4 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  42.4/42.4 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  42.4/42.4 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  42.4/42.4 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  42.4/42.4 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------- 42.4/42.4 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\minh\anaconda3\lib\site-packages (from pt-core-news-md==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\minh\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\minh\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\minh\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\minh\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\minh\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\minh\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\minh\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\minh\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\minh\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\minh\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\minh\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.1.1)
# Installing collected packages: pt-core-news-md
# Successfully installed pt-core-news-md-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_md')

# %% [markdown]
# ## Import Libraries

# %%
import spacy

# %% [markdown]
# ## Load Language Model
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# 1. We can import the model as a module and then load it from the module.

# %%
import pt_core_news_md
nlp = pt_core_news_md.load()

# %% [markdown]
# 2. We can load the model by name.

# %%
#nlp = spacy.load('pt_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it’s advisable to use Option 1. Then you can use the model immediately. Otherwise, you’ll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel… in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document
# To create a derivative text file that we can use with TF-IDF, topic modeling, or other word-count based methods, we need to use spaCy to *lemmatize* the text, replacing each word with its dictionary form. The result will be an ungrammatical text that will produce better results than the original version when used with word-count methods.
#
# The example text for Portuguese is *Contos e Phantasias* by Maria Amália Vaz de Carvalho [from Project Gutenberg](http://www.gutenberg.org/ebooks/63406).

# %% [markdown]
# Here we open the text and process it with the Portuguese spaCy model.

# %%
filepath = '../texts/pt.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# Then we loop through each token in the original text, lemmatize each token and insert a space between the tokens, and finally write them to our new derivative text file.

# %%
outname = filepath.replace('.txt', '-lemmatized.txt')

# Create a lemmatized version of the original text file
with open(outname, 'w', encoding='utf8') as out:
    for token in document:
        # Get the lemma for each token
        out.write(token.lemma_.lower())
        # Insert white space between each token
        out.write(' ')

# %% [markdown]
# ## Examine Differences
# The code cell below prints the original word in the text, a dash, then the lemmatized form that was written to the derivative text document that you'll use for TF-IDF and topic modeling. It's a good idea to take a look at this so you can see if there are places where the model consistently makes mistakes.
#
# For instance, an earlier version of spaCy often associated the Spanish preposition `para` ("for") with the verb `parar` ("to stop"). If you just took that derivative file and used it for TF-IDF or topic modeling without realizing what was happening, you might reach the surprising conclusion that "stop" is a very frequent word in your text, when actually it's lemmatization problem.

# %%
for token in document:
    print(token.text + ' - ' + token.lemma_)
# Out:
# PRIMEIRA - ﻿PRIMEIRA
# PARTE - PARTE
#
#
#
#
#
#  -
#
#
#
#
#
# UMA - UMA
# HISTORIA - HISTORIA
# VERDADEIRA - VERDADEIRA
#
#
#
#  -
#
#
#
# I - I
#
#
#  -
#
#
# Era - ser
# uma - um
# physionomia - physionomia
# incaracteristica - incaracteristico
# , - ,
# apagada - apagar
# , - ,
# tristissima - tristissimo
# . - .
#
#
#  -
#
#
# Não - não
# se - se
# podia - poder
# dizer - dizer
# a - o
# idade - idade
# que - que
# tinha - ter
# , - ,
# nem - nem
# mesmo - mesmo
# se - se
# tinha - ter
# idade - idade
# . - .
#
#
#  -
#
#
# Tanto - tanto
# podia - poder
# ter - ter
# trinta - trinta
# ou - ou
# quarenta - quarenta
# como - como
# setenta - setenta
# annos - annos
# . - .
#
#
#  -
#
#
# Curvado - curvar
# pela - por o
# idade - idade
# ou - ou
# pelos - por o
# desgostos - desgosto
# ? - ?
# Encanecido - Encanecido
# porque - porque
# os - o
# annos - anno
# tinham - ter
#
#  -
#
# corrido - corrido
# por - por
# sobre - sobre
# a - o
# cabeça - cabeça
# d'elle - de 'elle
# , - ,
# ou - ou
# porque - porque
# lhe - ele
# tinham - ter
# pesado - pesar
#
#  -
#
# duplamente - duplamente
# sobre - sobre
# os - o
# hombros - hombro
# debeis - debei
# ? - ?
#
#
#  -
#
#
# Quem - quem
# o - ele
# podia - poder
# dizer - dizer
# ? - ?
#
#
#  -
#
#
# Era - ser
# uma - um
# organisação - organisação
# acanhada - acanhar
# e - e
# rachitica - rachitico
# , - ,
# podia - poder
# mesmo - mesmo
# chamar-se - chamar se
#
#  -
#
# incompleta - incompleto
# . - .
#
#
#  -
#
#
# Para - para
# elle - elle
# com - com
# certeza - certeza
# que - que
# a - o
# adolescencia - adolescencia
# não - não
# tivera - tiver
# as - o
# suas - seu
# madrugadas - madrugada
#
#  -
#
# azues - azue
# tão - tão
# gorgeadas - gorgeada
# e - e
# tão - tão
# festivas - festiva
# , - ,
# nem - nem
# a - o
# virilidade - virilidade
# tivera - tivera
# a - o
# fanfarra - fanfarra
#
#  -
#
# estridente - estridente
# dos - de o
# seus - seu
# clarins - clarin
# , - ,
# a - o
# florescencia - florescencia
# escarlate - escarlate
# dos - de o
# seus - seu
# rosaes - rosaes
#
#  -
#
# voluptuosos - voluptuoso
# . - .
#
#
#  -
#
#
# Tinha - ter
# sempre - sempre
# vivido - viver
# debaixo - debaixo
# de - de
# uma - um
# estranha - estranho
# pressão - pressão
# dolorosa - doloroso
# . - .
#
#
#  -
#
#
# Dependêra - Dependêra
# de - de
# todos - todo
# primeiro - primeiro
# porque - porque
# era - ser
# fraco - fraco
# e - e
# inerme - inerme
# , - ,
# depois - depois
# porque - porque
#
#  -
#
# fôra - sfôr
# pobre - pobre
# , - ,
# dependente - dependente
# , - ,
# sem - sem
# aquella - aquelle
# aspera - asperar
# dignidade - dignidade
# que - que
# os - o
# atrictos - atricto
# da - de o
#
#  -
#
# vida - vida
# tornam - tornar
# mais - mais
# rude - rude
# e - e
# que - que
# é - ser
# a - o
# armadura - armadura
# moral - moral
# que - que
# salvaguarda - salvaguardar
# o - o
# homem - homem
#
#  -
#
# nos - em o
# duros - duro
# combates - combate
# sociaes - sociaes
# . - .
#
#
#  -
#
#
# Nasceu - Nascer
# n'uma - n'um
# casa - casa
# opulenta - opulento
# que - que
# lhe - ele
# não - não
# pertencia - pertencer
# , - ,
# cresceu - crescer
# no - em o
# meio - meio
# de - de
# um - um
#
#  -
#
# luxo - luxo
# de - de
# que - que
# seus - seu
# paes - paes
# erão - er
# parasitas - parasita
# voluntarios - voluntario
# e - e
# de - de
# que - que
# elle - elle
# era - ser
# ... - ...
#
#  -
#
# parasita - parasita
# inconsciente - inconsciente
# . - .
#
#
#  -
#
#
# Começára - Começára
# por - por
# ter - ter
# medo - medo
# de - de
# tudo - tudo
# e - e
# de - de
# todos - todo
# ; - ;
# um - um
# medo - medo
# que - que
# não - não
# raciocinava - raciocinar
# , - ,
#
#  -
#
# que - que
# não - não
# sabia - saber
# , - ,
# que - que
# não - não
# indagava - indagar
# mesmo - mesmo
# a - o
# sua - seu
# propria - proprio
# origem - origem
# . - .
#
#
#  -
#
#
# Nasceu - Nasceu
# assustadiço - assustadiço
# , - ,
# como - como
# certos - certos
# animaes - animaes
# silvestres - silvestr
# , - ,
# e - e
# toda - todo
# a - o
# vida - vida
#
#  -
#
# conservou - conservar
# a - o
# mesma - mesmo
# expressão - expressão
# inquieta - inquieto
# e - e
# medrosa - medroso
# da - de o
# lebre - lebre
# perseguida - perseguir
# . - .
#
#
#  -
#
#
# Em - em
# primeiro - primeiro
# lugar - lugar
# tinha - ter
# medo - medo
# de - de
# seu - seu
# pae - pae
# ; - ;
# um - um
# homem - homem
# alto - alto
# , - ,
# espadaúdo - espadaúdo
# , - ,
#
#  -
#
# plethorico - plethorico
# , - ,
# de - de
# voz - voz
# grossa - grosso
# e - e
# modos - modo
# brutaes - brutaes
# , - ,
# que - que
# comia - comir
# como - como
# um - um
# abbade - Abbade
# , - ,
# que - que
#
#  -
#
# bebia - beber
# como - como
# um - um
# _ - _
# lansquenete - lansquenete
# _ - _
# , - ,
# que - que
# praguejava - praguejar
# como - como
# um - um
# carreiro - carreiro
# , - ,
# e - e
# que - que
# se - se
#
#  -
#
# vingava - vingar
# nos - em o
# poucos - pouco
# entes - ente
# que - que
# tinha - ter
# debaixo - debaixo
# do - de o
# seu - seu
# dominio - dominio
# , - ,
# das - de o
#
#  -
#
# complacencias - complacencia
# servis - servis
# que - que
# era - ser
# obrigado - obrigar
# a - a
# mostrar - mostrar
# aos - a o
# que - que
# o - ele
# mantinham - mantinhar
#
#  -
#
# n'aquella - n'aquella
# farta - farto
# ociosidade - ociosidade
# de - de
# commensal - commensal
# que - que
# só - só
# goza - gozar
# e - e
# não - não
# paga - pagar
# . - .
#
#
#  -
#
#
# Depois - depois
# tinha - ter
# medo - medo
# de - de
# sua - seu
# tia - tia
# ; - ;
# a - o
# dona - dona
# da - de o
# casa - casa
# , - ,
# a - o
# _ - _
# senhora - senhora
# _ - _
# , - ,
# a - o
# suzerana - suzerano
#
#  -
#
# ante - ante
# a - o
# qual - qual
# todos - todo
# se - se
# curvavam - curvar
# submissos - submisso
# . - .
#
#
#  -
#
#
# E - e
# no - em o
# emtanto - emtanto
# ella - ella
# era - ser
# bonita - bonito
# , - ,
# delgada - delgar
# , - ,
# flexivel - flexivel
# , - ,
# muito - muito
# branca - branco
# . - .
#
#
#  -
#
#
# Uma - um
# figura - figura
# ideal - ideal
# de - de
# pintor - pintor
# inglez - inglez
# . - .
#
#
#  -
#
#
# Mas - mas
# que - que
# culpa - culpa
# tinha - ter
# elle - elle
# , - ,
# o - o
# pequenino - pequenino
# parea - parear
# , - ,
# se - se
# os - o
# olhos - olho
# d'essa - de 'esse
# graciosa - gracioso
#
#  -
#
# e - e
# delicada - delicado
# senhora - senhora
# lhe - ele
# pareciam - parec
# frios - frio
# e - e
# metalicos - metalico
# , - ,
# com - com
# umas - um
#
#  -
#
# scintillações - scintillação
# azuladas - azular
# como - como
# as - a
# do - de o
# aço - aço
# fino - fino
# ? - ?
# se - se
# as - o
# suas - seu
# mãos - mão
# esguias - esguio
# e - e
#
#  -
#
# brancas - branco
# se - se
# lhe - ele
# affiguravam - affigurar
# duas - dois
# tenazes - tenaz
# que - que
# podiam - poder
# apertal-o - apertal-o
# , - ,
# apertal-o - apertal-o
#
#  -
#
# até - até
# o - ele
# torcerem - torcer
# todo - todo
# , - ,
# até - até
# o - ele
# esphacelarem - esphacelarem
# e - e
# fazerem - fazer
# d'elle - de 'elle
# , - ,
# do - de o
# seu - seu
# pequeno - pequeno
#
#  -
#
# corpo - corpo
# tão - tão
# fraquinho - fraquinho
# , - ,
# uma - um
# grotesca - grotesco
# massa - massa
# informe - informe
# , - ,
# que - que
# o - o
# mundo - mundo
# inteiro - inteiro
#
#  -
#
# pisasse - pisar
# , - ,
# onde - onde
# o - o
# mundo - mundo
# inteiro - inteiro
# cuspisse - cuspir
# ! - !
#
#
#  -
#
#
# Seria - ser
# allucinação - allucinação
# d'aquelle - d'aquelle
# cerebro - cerebro
# enfermo - enfermor
# e - e
# condemnado - condemnar
# ás - ás
# scismas - scisma
#
#  -
#
# doentias - doentia
# ? - ?
#
#
#  -
#
#
# Quem - quem
# sabe - saber
# ? - ?
#
#
#  -
#
#
# O - o
# caso - caso
# é - ser
# que - que
# o - ele
# sentia - sentir
# , - ,
# e - e
# que - que
# nunca - nunca
# pudera - puderar
# esquivar-se - esquivar se
# a - a
# essa - esse
#
#  -
#
# preoccupação - preoccupação
# intensa - intenso
# e - e
# dilacerante - dilacerante
# ! - !
#
#
#  -
#
#
# Um - um
# d'estes - d'este
# dous - dous
# entes - ente
# que - que
# dominaram - dominar
# de - de
# estranho - estranho
# terror - terror
# a - o
# sua - seu
# infancia - infancia
# , - ,
#
#  -
#
# maltratava-o - maltratava-o
# nas - em o
# explosões - explosão
# brutaes - brutaes
# de - de
# seu - seu
# temperamento - temperamento
# de - de
# touro - touro
# bravo - bravo
# . - .
#
#
#  -
#
#
# O - o
# outro - outro
# -- - --
# a - o
# senhora - senhora
# -- - --
# muito - muito
# altiva - altivo
# , - ,
# muito - muito
# fria - fria
# , - ,
# muito - muito
# desdenhosa - desdenhoso
# , - ,
# nem - nem
#
#  -
#
# sequer - sequer
# lhe - ela
# fallava - fallar
# . - .
#
#
#  -
#
#
# Olhava-o - Olhava-o
# ás - ás
# vezes - vez
# como - como
# se - se
# olha - olhar
# para - para
# um - um
# animal - animal
# repugnante - repugnante
# , - ,
# para - para
# um - um
# sapo - sapo
# , - ,
#
#  -
#
# ou - ou
# para - para
# uma - um
# carocha - carocha
# , - ,
# e - e
# passava - passar
# adiante - adiante
# , - ,
# imperturbavel - imperturbavel
# e - e
# olympica - olympico
# . - .
#
#
#  -
#
#
# Havia - Havia
# , - ,
# porém - porém
# , - ,
# um - um
# outro - outro
# sêr - sêr
# , - ,
# dos - de o
# que - que
# mais - mais
# em - em
# contacto - contacto
# estavam - estar
# com - com
# elle - elle
# , - ,
#
#  -
#
# que - que
# nem - nem
# o - ele
# maltratava - maltratar
# , - ,
# nem - nem
# o - ele
# desprezava - desprezar
# com - com
# a - o
# glacial - glacial
# frieza - frieza
# do - de o
# seu - seu
#
#  -
#
# desdem - desdem
# . - .
#
#
#  -
#
#
# E - e
# comtudo - comtudo
# era - ser
# d'esse - d'esse
# que - que
# elle - elle
# tinha - ter
# ainda - ainda
# mais - mais
# medo - medo
# . - .
#
#
#  -
#
#
# Era - ser
# seu - seu
# tio - tio
# ; - ;
# uma - um
# figura - figura
# original - original
# , - ,
# uma - um
# physionomia - physionomia
# de - de
# titan - titan
# que - que
# por - por
# um - um
#
#  -
#
# engano - engano
# qualquer - qualquer
# da - de o
# natureza - natureza
# não - não
# pôde - poder
# conseguir - conseguir
# passar - passar
# de - de
# anão - anão
# . - .
#
#
#  -
#
#
# Seu - seu
# tio - tio
# ! - !
# ... - ...
# Como - como
# esta - este
# individualidade - individualidade
# extraordinariamente - extraordinariamente
# accentuada - accentuar
# , - ,
#
#  -
#
# como - como
# este - este
# rosto - rosto
# ironico - ironico
# , - ,
# irregular - irregular
# , - ,
# convulsionado - convulsionar
# , - ,
# dominou - dominar
# para - para
# sempre - sempre
# o - o
#
#  -
#
# destino - destino
# obscuro - obscuro
# da - de o
# infeliz - infeliz
# creança - creança
# que - que
# eu - eu
# conheci - conhecer
# já - já
# velho - velho
# ! - !
#
#
#  -
#
#
# Seu - seu
# tio - tio
# não - não
# o - o
# perseguia - perseguia
# nem - nem
# lhe - ele
# manifestava - manifestar
# uma - um
# repugnancia - repugnancia
# muda - mudar
# , - ,
# pelo - por o
#
#  -
#
# contrario - contrario
# . - .
#
#
#  -
#
#
# Chamava-o - Chamava-o
# continuamente - continuamente
# para - para
# o - o
# pé - pé
# de - de
# si - se
# , - ,
# ensinava-lhe - ensinava-lhe
# , - ,
# quando - quando
# estava - estar
# só - só
# , - ,
#
#  -
#
# palavras - palavra
# , - ,
# esgares - esgar
# , - ,
# visagens - visagem
# grotescas - grotesco
# que - que
# lhe - ele
# fazia - fazer
# repetir - repetir
# diante - diante
# de - de
#
#  -
#
# gente - gente
# , - ,
# n'um - n'um
# côro - côro
# de - de
# gargalhadas - gargalhada
# asperas - aspera
# e - e
# hostis - hostil
# como - como
# gumes - gumes
# de - de
# espadas - espada
# ! - !
#
#
#  -
#
#
# Vestia-o - vestia-o
# de - de
# um - um
# modo - modo
# desusado - desusar
# e - e
# extravagante - extravagante
# , - ,
# vestia-o - vestia-o
# de - de
# marujo - marujo
# , - ,
# de - de
#
#  -
#
# escossez - escossez
# , - ,
# com - com
# as - o
# suas - seu
# pequenas - pequeno
# pernas - perna
# magras - magro
# , - ,
# trigueiras - trigueira
# , - ,
# ossudas - ossuda
# , - ,
# n'uma - n'uma
#
#  -
#
# nudez - nudez
# friorenta - friorento
# que - que
# lhe - ele
# doia - doiar
# , - ,
# e - e
# o - ele
# fazia - fazer
# tiritar - tiritar
# ; - ;
# vestia-o - vestia-o
# de - de
# tyrolez - Tyrolez
# , - ,
# o - o
#
#  -
#
# que - que
# lhe - ele
# dava - dar
# um - um
# aspecto - aspecto
# comico - comico
# , - ,
# que - que
# arrebentava - arrebentar
# com - com
# riso - riso
# a - o
# criadagem - criadagem
# . - .
#
#
#  -
#
#
# Ás - Ás
# vezes - vez
# nos - em o
# seus - seu
# dias - dia
# de - de
# melhor - bom
# humor - humor
# sahia - sahia
# com - com
# elle - elle
# , - ,
# que - que
# tinha - ter
# apenas - apenas
#
#  -
#
# sete - sete
# annos - annos
# de - de
# idade - idade
# , - ,
# de - de
# casaca - casaca
# , - ,
# chapéo-alto - chapéo-alto
# , - ,
# e - e
# berloques - berloque
# na - em o
# cadeia - cadeia
# do - de o
#
#  -
#
# relogio - relogio
# . - .
#
#
#  -
#
#
# Tinha - ter
# tempos - tempo
# em - em
# que - que
# não - não
# podia - poder
# passar - passar
# sem - sem
# a - o
# sua - seu
# companhia - companhia
# ; - ;
# a - o
# creança - creança
# era - ser
#
#  -
#
# a - o
# unica - unico
# distracção - distracção
# do - de o
# anão - anão
# . - .
#
#
#  -
#
#
# As - o
# caricias - caricia
# d'esse - d'esse
# homem - homem
# singular - singular
# , - ,
# de - de
# olhar - olhar
# faiscante - faiscante
# , - ,
# de - de
# cabelladura - cabelladura
#
#  -
#
# revolta - revoltar
# e - e
# electrica - electrico
# , - ,
# de - de
# voz - voz
# sonora - sonoro
# e - e
# rica - rico
# de - de
# inflexões - inflexão
# estranhas - estranho
# , - ,
# doíam - doíam
# , - ,
#
#  -
#
# porém - porém
# , - ,
# ao - a o
# pequeno - pequeno
# muito - muito
# mais - mais
# do - de o
# que - que
# os - o
# desprezos - desprezos
# ou - ou
# os - o
# máos - máo
# tratos - trato
# dos - de o
#
#  -
#
# outros - outro
# . - .
#
#
#  -
#
#
# Ao - a o
# pé - pé
# d'estes - d'este
# sentia-se - sentia-se
# perseguido - perseguir
# , - ,
# ao - a o
# pé - pé
# d'aquelle - d'aquelle
# sentia-se - sentia-se
# humilhado - humilhar
# . - .
#
#
#  -
#
#
# Um - um
# dia - dia
# o - o
# marquez - marquez
# -- - --
# o - o
# tio - tio
# do - de o
# pequeno - pequeno
# Thadeu - Thadeu
# era - ser
# marquez,--achou - marquez,--achar
# comico - comico
#
#  -
#
# mandar - mandar
# introduzir - introduzir
# a - o
# creança - creança
# no - em o
# cofre - cofre
# acharoado - acharoar
# que - que
# havia - haver
# junto - junto
# ao - a o
# fogão - fogão
#
#  -
#
# do - de o
# gabinete - gabinete
# de - de
# trabalho - trabalho
# , - ,
# destinado - destinar
# a - a
# guardar - guardar
# a - o
# lenha - lenha
# ou - ou
# o - o
# carvão - carvão
# que - que
# se - se
#
#  -
#
# consumia - consumia
# . - .
#
#
#  -
#
#
# De - de
# minuto - minuto
# em - em
# minuto - minuto
# abria-se - abria-se
# a - o
# tampa - tampa
# e - e
# sahia - sahia
# a - o
# cara - cara
# vermelha - vermelho
# e - e
#
#  -
#
# congestionada - congestionar
# do - de o
# pequeno - pequeno
# , - ,
# uma - um
# cara - cara
# de - de
# animal - animal
# assustado - assustado
# , - ,
# o - o
# que - que
# divertia - divertiar
#
#  -
#
# extraordinariamente - extraordinariamente
# as - o
# visitas - visita
# . - .
#
#
#  -
#
#
# Outra - outro
# vez - vez
# , - ,
# n'uma - n'uma
# ceia - ceia
# alegre - alegre
# em - em
# que - que
# havia - haver
# rios - rio
# de - de
# _ - _
# champagne - champagne
# _ - _
# e - e
# risadas - risada
#
#  -
#
# crystallinas - crystallina
# de - de
# mulheres - mulher
# , - ,
# Thadeu - Thadeu
# com - com
# um - um
# fato - fato
# de - de
# meia - meia
# preta - preto
# a - a
# cobril-o - cobril-o
#
#  -
#
# todo - todo
# e - e
# dous - dous
# castiçaes - castiçaes
# nas - em o
# pequenas - pequeno
# mãos - mão
# , - ,
# servia - servia
# de - de
# centro - Centro
# agachado - agachar
# n'uma - em 'uma
#
#  -
#
# posição - posição
# grotesca - grotesco
# no - em o
# meio - meio
# da - de o
# meza - meza
# . - .
#
#
#  -
#
#
# Sahiu - Sahiu
# d'alli - d'alli
# com - com
# uma - um
# febre - febre
# que - que
# o - ele
# teve - ter
# um - um
# mez - mez
# entre - entre
# a - o
# morte - morte
# e - e
# a - o
# vida - vida
# , - ,
#
#  -
#
# delirante - delirante
# , - ,
# sem - sem
# conhecer - conhecer
# ninguem - ninguem
# , - ,
# com - com
# a - o
# mãe - mãe
# debulhada - debulhar
# em - em
# lagrimas - lagrima
# á - á
#
#  -
#
# cabeceira - cabeceira
# . - .
#
#
#  -
#
#
# Mas - mas
# Thadeu - Thadeu
# não - não
# gostava - gostar
# de - de
# sua - seu
# mãe - mãe
# . - .
#
#
#  -
#
#
# Era - ser
# uma - um
# creatura - creatura
# tão - tão
# debil - debil
# como - como
# elle - elle
# , - ,
# pallida - paller
# como - como
# uma - um
# defunta - defunta
# , - ,
# inerme - inerme
# , - ,
#
#  -
#
# estupida - estupido
# , - ,
# sem - sem
# vontade - vontade
# . - .
#
#
#  -
#
#
# As - o
# lobas - loba
# defendem - defender
# os - o
# seus - seu
# filhos - filho
# , - ,
# a - o
# mãe - mãe
# de - de
# Thadeu - Thadeu
# não - não
# o - ele
# sabia - saber
# defender - defender
# ! - !
#
#
#  -
#
#
# Entregava-o - Entregava-o
# ás - ás
# coleras - colera
# descompostas - descomposta
# do - de o
# pae - pae
# ; - ;
# aos - a o
# desprezos - desprezos
# gelidos - gelido
# da - de o
#
#  -
#
# tia - tia
# ; - ;
# aos - a o
# caprichos - capricho
# monstruosamente - monstruosamente
# comicos - comico
# do - de o
# marquez - marquez
# ; - ;
# ás - ás
# apupadas - apupada
#
#  -
#
# brutaes - brutaes
# das - de o
# aias - aia
# e - e
# dos - de o
# lacaios - lacaio
# ; - ;
# aos - a o
# risos - riso
# das - de o
# visitas - visita
# ; - ;
# ao - a o
# pasmo - pasmo
#
#  -
#
# desprezador - desprezador
# das - de o
# outras - outro
# creanças - creança
# , - ,
# que - que
# iam - ir
# áquella - áquella
# casa - casa
# opulenta - opulento
# e - e
# ruidosa - ruidoso
#
#  -
#
# acompanhadas - acompanhar
# por - por
# seus - seu
# paes - paes
# , - ,
# vestidas - vestir
# de - de
# velludo - velludo
# , - ,
# com - com
# plumas - pluma
# nos - em o
# seus - seu
#
#  -
#
# lindos - lindo
# chapéus - chapéu
# , - ,
# o - o
# ar - ar
# grave - grave
# de - de
# meninos - menino
# bem - bem
# creados - creado
# , - ,
# e - e
# que - que
# não - não
# tinham - ter
#
#  -
#
# licença - licença
# de - de
# brincar - brincar
# com - com
# aquelle - aquelle
# pequeno - pequeno
# histrião - histrião
# , - ,
# feio - feio
# , - ,
# ridiculo - ridiculo
# , - ,
# doente - doente
# , - ,
#
#  -
#
# com - com
# gesto - gesto
# de - de
# epileptico - epileptico
# , - ,
# com - com
# fatos - fato
# de - de
# palhaço - palhaço
# e - e
# com - com
# soluços - soluço
# de - de
# martyr - martyr
# . - .
#
#
#
#  -
#
#
#
# II - II
#
#
#  -
#
#
# Um - um
# dia - dia
# , - ,
# porém - porém
# , - ,
# fez-se - fazer se
# na - em o
# vida - vida
# atormentada - atormentar
# e - e
# tempestuosa - tempestuosa
# do - de o
# pequeno - pequeno
#
#  -
#
# Thadeu - Thadeu
# uma - um
# claridade - claridade
# de - de
# luar - luar
# , - ,
# uma - um
# claridade - claridade
# opalisada - opalisar
# e - e
# doce - doce
# . - .
#
#
#  -
#
#
# Houve - Houve
# treguas - tregua
# nos - em o
# seus - seu
# varios - vario
# martyrios - martyrio
# , - ,
# e - e
# sua - seu
# mãe - mãe
# , - ,
# n'uma - n'um
# bella - bella
# manhã - manhã
# de - de
#
#  -
#
# primavera - primavera
# em - em
# que - que
# os - o
# passaros - passaro
# cantavam - cantar
# ao - a o
# desafio - desafio
# nas - em o
# grandes - grande
# arvores - arvore
# do - de o
#
#  -
#
# jardim - Jardim
# , - ,
# levou-o - levar ele
# pela - por o
# mão - mão
# , - ,
# pé - pé
# ante - ante
# pé - pé
# , - ,
# a - a
# um - um
# quarto - quarto
# forrado - forrar
# de - de
# setim - setim
# côr - côr
#
#  -
#
# de - de
# rosa - Rosa
# , - ,
# um - um
# quarto - quarto
# digno - digno
# de - de
# servir - servir
# de - de
# habitação - habitação
# á - á
# fada - fada
# mais - mais
# linda - lindo
# que - que
#
#  -
#
# uma - um
# phantasia - phantasia
# de - de
# poeta - poeta
# oriental - oriental
# houvesse - houvesse
# imaginado - imaginar
# . - .
#
#
#  -
#
#
# N'aquelle - N'aquelle
# quarto - quarto
# havia - haver
# um - um
# ninho - ninho
# todo - todo
# branco - branco
# feito - fazer
# de - de
# rendas - renda
# , - ,
# de - de
# fitas - fita
# de - de
#
#  -
#
# setim - setim
# , - ,
# de - de
# pennugem - pennugem
# de - de
# passaros - passaro
# , - ,
# e - e
# n'esse - n'er
# ninho - ninho
# dormia - dormer
# uma - um
# creancinha - creancinha
# que - que
#
#  -
#
# parecia - parecer
# uma - um
# rosa - rosa
# . - .
#
#
#  -
#
#
# --É - --É
# tua - tua
# prima - prima
# ; - ;
# murmurou - murmurar
# baixinho - baixinho
# a - o
# mãe - mãe
# de - de
# Thadeu - Thadeu
# , - ,
# emquanto - emquanto
# este - este
# , - ,
# mudo - mudo
# , - ,
#
#  -
#
# surpreso - surpreso
# , - ,
# extasiado - extasiar
# , - ,
# fitava - fitar
# os - o
# seus - seu
# olhos - olho
# vitreos - vitreo
# , - ,
# onde - onde
# o - o
# jubilo - jubilo
# acendia - acender
#
#  -
#
# uma - um
# luz - luz
# desusada - desusar
# , - ,
# nos - em o
# grandes - grande
# olhos - olho
# luminosos - luminoso
# e - e
# pasmados - pasmar
# do - de o
# _ - _
# bébé - bébé
# _ - _
# que - que
#
#  -
#
# acordára - Acordára
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# como - como
# Thadeu - Thadeu
# adorava - adorar
# aquella - aquelle
# creança - creança
# ! - !
# Como - como
# na - em o
# sua - seu
# vida - vida
# houve - haver
# de - de
#
#  -
#
# repente - repente
# um - um
# ficto - ficto
# , - ,
# uma - um
# esperança - esperança
# , - ,
# uma - um
# luz - luz
# ! - !
#
#
#  -
#
#
# Sua - seu
# tia - tia
# , - ,
# uma - uma
# vez - vez
# em - em
# que - que
# a - a
# _ - _
# bebé - bebé
# _ - _
# chorava - chorar
# muito - muito
# nos - em o
# braços - braço
# da - de o
# ama - ama
# , - ,
#
#  -
#
# dissera - dissera
# a - a
# Thadeu - Thadeu
# com - com
# uma - um
# voz - voz
# menos - menos
# glacial - glacial
# do - de o
# que - que
# o - o
# costume - costume
# : - :
#
#
#  -
#
#
# --Thadeu - --Thadeu
# , - ,
# brinca - brincar
# com - com
# a - o
# prima - prima
# a - o
# vêr - vêr
# se - se
# ella - ella
# se - se
# cala - calar
# . - .
#
#
#  -
#
#
# E - e
# elle - elle
# fizera - fazer
# calar - calar
# a - o
# rabujenta - rabujenta
# pequerrucha - pequerrucha
# . - .
#
#
#  -
#
#
# Desde - desde
# esse - esse
# dia - dia
# soube-se - soube-se
# que - que
# a - o
# _ - _
# menina - menina
# _ - _
# tinha - ter
# o - o
# insolito - insolito
# capricho - capricho
# de - de
#
#  -
#
# adorar - adorar
# Thadeu - Thadeu
# , - ,
# de - de
# rir - rir
# quando - quando
# elle - elle
# estava - estar
# de - de
# joelhos - joelho
# dobrado - dobrar
# sobre - sobre
# o - o
# seu - seu
#
#  -
#
# berço - berço
# , - ,
# de - de
# chorar - chorar
# quando - quando
# alguem - alguem
# o - ele
# levava - levar
# d'alli - d'alli
# para - para
# fóra - fóra
# . - .
#
#
#  -
#
#
# A - o
# ama - ama
# tomou - tomar
# o - o
# costume - costume
# de - de
# o - ele
# chamar - chamar
# e - e
# de - de
# o - ele
# fazer - fazer
# estar - estar
# horas - hora
# e - e
# horas - hora
# a - a
#
#  -
#
# entreter - entreter
# a - a
# _ - _
# menina - menina
# _ - _
# . - .
#
#
#  -
#
#
# Ao - a o
# principio - principio
# elle - elle
# fazia-lhe - fazia-lhe
# carêtas - carêta
# e - e
# momices - momice
# , - ,
# como - como
# as - o
# que - que
# usava - usar
# fazer - fazer
#
#  -
#
# para - para
# divertir - divertir
# seu - seu
# tio - tio
# ; - ;
# depois - depois
# , - ,
# sem - sem
# bem - bem
# perceber - perceber
# porque - porque
# , - ,
# adoptou - adoptar
# outro - outro
#
#  -
#
# systema - systema
# inteiramente - inteiramente
# opposto - opposto
# . - .
#
#
#  -
#
#
# Percebeu - Percebeu
# que - que
# a - o
# pequenina - pequenino
# não - não
# queria - querer
# um - um
# bôbo - bôbo
# , - ,
# como - como
# esse - esse
# espirito - espirito
# embotado - embotar
#
#  -
#
# e - e
# pervertido - pervertir
# que - que
# o - o
# victimára - victimára
# com - com
# os - o
# seus - seu
# caprichos - capricho
# . - .
# O - o
# que - que
# a - a
# _ - _
# bebé - bebé
# _ - _
#
#  -
#
# queria - querer
# , - ,
# na - em o
# ingenuidade - ingenuidade
# adoravel - adoravel
# do - de o
# seu - seu
# despotismo - despotismo
# infantil - infantil
# , - ,
# era - ser
# um - um
#
#  -
#
# companheiro - companheiro
# de - de
# seus - seu
# brinquedos - brinquedo
# , - ,
# um - um
# socio - socio
# , - ,
# um - um
# escravo - escravo
# que - que
# a - ela
# adorasse - adorar
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# era - ser
# tudo - tudo
# para - para
# ella - ella
# : - :
# queria-o - queria-o
# perto - perto
# da - de o
# grande - grande
# tina - tina
# em - em
# que - que
# tomava - tomar
# o - o
#
#  -
#
# seu - seu
# banho - banho
# de - de
# manhã - manhã
# ; - ;
# queria-o - queria-o
# junto - junto
# da - de o
# pequena - pequeno
# mesa - mesa
# de - de
# nacar - nacar
# onde - onde
# a - ela
# ama - amar
#
#  -
#
# lhe - ele
# dava - dar
# as - o
# sopinhas - sopinha
# ; - ;
# queria-o - queria-o
# no - em o
# berço - berço
# ao - a o
# adormecer - adormecer
# ; - ;
# queria-o - queria-o
# no - em o
#
#  -
#
# jardim - jardim
# , - ,
# á - á
# sombra - sombra
# das - de o
# arvores - arvore
# , - ,
# sobre - sobre
# a - o
# arêa - arêa
# finissima - Finissima
# , - ,
# onde - onde
# se - se
# rolava - rolar
# , - ,
#
#  -
#
# vestida - vester
# de - de
# rendas - renda
# brancas - branco
# , - ,
# a - a
# rir - rir
# como - como
# uma - um
# perdida - perdida
# . - .
#
#
#  -
#
#
# Chamaram-lhe - Chamaram-lhe
# Margarida - Margarida
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# quer - querer
# dizer - dizer
# perola - perola
# , - ,
# e - e
# Thadeu - Thadeu
# , - ,
# que - que
# vira - virar
# muitas - muitas
# vezes - vez
# sua - seu
# tia - tia
#
#  -
#
# vestida - vester
# de - de
# baile - baile
# , - ,
# achava - achar
# um - um
# nome - nome
# muito - muito
# bem - bem
# posto - posto
# áquella - áquella
# creança - creança
# branca - branco
# , - ,
#
#  -
#
# transparente - transparente
# , - ,
# loura - louro
# , - ,
# idealmente - idealmente
# graciosa - gracioso
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# Thadeu - Thadeu
# ainda - ainda
# andava - andar
# muita - muito
# vez - vez
# vestido - vestir
# de - de
# marujo - marujo
# , - ,
# de - de
# granadeiro - granadeiro
# , - ,
# de - de
#
#  -
#
# tyrolez - Tyrolez
# e - e
# de - de
# alferes - alferes
# , - ,
# ainda - ainda
# o - ele
# introduziam - introduzir
# no - em o
# cofre - cofre
# da - de o
# lenha - lenha
# , - ,
# ainda - ainda
# o - o
#
#  -
#
# faziam - fazer
# fumar - fumar
# um - um
# charuto - charuto
# depois - depois
# de - de
# jantar - jantar
# , - ,
# cheio - cheio
# de - de
# ancias - ancia
# , - ,
# de - de
# nauseas - nausea
# , - ,
#
#  -
#
# de - de
# gritos - grito
# abafados - abafar
# de - de
# angustia - Angustia
# ! - !
# ... - ...
# Mas - mas
# que - que
# importava - importar
# ! - !
#
#
#  -
#
#
# Logo - logo
# que - que
# podia - poder
# escapava-se - escapava se
# para - para
# o - o
# quarto - quarto
# da - de o
# fada - fada
# , - ,
# para - para
# o - o
# estojo - estojo
# côr - côr
# de - de
#
#  -
#
# rosa - Rosa
# da - de o
# sua - seu
# _ - _
# perola - perola
# _ - _
# , - ,
# da - de o
# sua - seu
# Margarida - Margarida
# , - ,
# e - e
# então - então
# eram - ser
# risadas - risada
# sem - sem
# fim - fim
# , - ,
#
#  -
#
# eram - ser
# corridas - corrida
# delirantes - delirante
# por - por
# sobre - sobre
# o - o
# tapete - tapete
# , - ,
# era - ser
# um - um
# papaguear - papaguear
# de - de
# duas - dois
#
#  -
#
# aves - ave
# felizes - feliz
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# com - com
# a - o
# idade - idade
# ia-se - ia-se
# fazendo - fazer
# despotica - despotico
# . - .
#
#
#  -
#
#
# Pudera - Pudera
# ! - !
#
#
#  -
#
#
# Ou - ou
# ella - ella
# não - não
# fosse - ser
# mulher - mulher
# , - ,
# e - e
# estremecida - estremecir
# pelo - por o
# seu - seu
# humilde - humilde
# escravo - escravo
# ! - !
#
#
#  -
#
#
# Mas - mas
# era - ser
# assim - assim
# mesmo - mesmo
# que - que
# elle - elle
# a - ela
# queria - querer
# . - .
#
#
#  -
#
#
# Quando - quando
# as - o
# mãosinhas - mãosinha
# polpudas - polpuda
# e - e
# brancas - branco
# de - de
# Margarida - Margarida
# lhe - ele
# batiam - bat
# , - ,
# Thadeu - Thadeu
#
#  -
#
# sentia-se - sentia se
# feliz - feliz
# como - como
# um - um
# rei - rei
# . - .
#
#
#  -
#
#
# Quando - quando
# ella - ella
# o - ele
# obrigava - obrigar
# a - a
# agachar-se - agachar se
# no - em o
# chão - chão
# para - para
# lhe - ele
# servir - servir
# de - de
# jumento - jumento
# , - ,
#
#  -
#
# o - o
# rapazinho - rapazinho
# tinha - ter
# tentações - tentação
# de - de
# rinchar - rinchar
# de - de
# prazer - prazer
# , - ,
# fazendo - fazer
# o - o
# passo - passo
# bem - bem
# ao - a o
#
#  -
#
# vivo - vivo
# . - .
#
#
#  -
#
#
# Porque - porque
# no - em o
# fim - fim
# de - de
# contas - conta
# , - ,
# apezar - apezar
# de - de
# todas - todo
# as - o
# suas - seu
# adoraveis - adoravel
# crueldades - crueldade
# , - ,
#
#  -
#
# Margarida - Margarida
# gostava - gostar
# d'elle - d'elle
# . - .
#
#
#  -
#
#
# A - o
# presença - presença
# de - de
# Thadeu - Thadeu
# illuminava - illuminar
# de - de
# risos - riso
# o - o
# seu - seu
# rosto - rosto
# oval - oval
# coroado - coroado
# de - de
#
#  -
#
# cabellos - cabello
# louros - louro
# annellados - annellado
# , - ,
# o - o
# seu - seu
# rosto - rosto
# a - a
# um - um
# tempo - tempo
# angelico - angelico
# e - e
# gaiato - gaiato
# ! - !
#
#
#  -
#
#
# Margarida - Margarida
# não - não
# o - ele
# achava - achar
# feio - feio
# , - ,
# nem - nem
# tolo - tolo
# , - ,
# nem - nem
# ridiculo - ridiculo
# , - ,
# nem - nem
# doente - doente
# . - .
#
#
#  -
#
#
# Não - não
# desprezava - desprezar
# a - o
# fraqueza - fraqueza
# dos - de o
# seus - seu
# braços - braço
# , - ,
# nem - nem
# a - o
# pobreza - pobreza
# absoluta - absoluta
# da - de o
# sua - seu
#
#  -
#
# imaginação - imaginação
# . - .
#
#
#  -
#
#
# Pelo - por o
# contrario - contrario
# ! - !
# Admirava - Admirava
# o - o
# ! - !
#
#
#  -
#
#
# Sim - sim
# ; - ;
# ella - ella
# dera-lhe - dera ele
# essa - esse
# sensação - sensação
# poderosa - poderoso
# e - e
# extraordinaria - extraordinario
# , - ,
# a - o
# sensação - sensação
#
#  -
#
# dos - de o
# que - que
# se - se
# vêem - ver
# admirados - admirar
# com - com
# ingenua - ingenuo
# confiança - confiança
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# pedia-lhe - pedia-lhe
# cousas - cousa
# enormes - enorme
# , - ,
# com - com
# uma - um
# serenidade - serenidade
# ineffavel - ineffavel
# de - de
#
#  -
#
# crente - crente
# ! - !
#
#
#  -
#
#
# Pedira-lhe - Pedira-lhe
# um - um
# ninho - ninho
# de - de
# melros - melro
# , - ,
# e - e
# o - o
# que - que
# é - ser
# mais - mais
# ! - !
# conseguira - conseguira
# que - que
# elle - elle
# tão - tão
#
#  -
#
# medroso - medroso
# , - ,
# tão - tão
# debil - debil
# , - ,
# tão - tão
# assustado - assustado
# , - ,
# trepasse - trepasse
# pelos - por o
# braços - braço
# nodosos - nodoso
# de - de
# uma - um
#
#  -
#
# grande - grande
# arvore - arvore
# e - e
# lh'o - lh'o
# fosse - ser
# buscar - buscar
# lá - lá
# cima - cima
# . - .
#
#
#  -
#
#
# Que - que
# triumpho - triumpho
# este - este
# d'ella - d'ella
# , - ,
# ao - a o
# ver - ver
# satisfeito - satisfeito
# o - o
# seu - seu
# capricho - capricho
# ! - !
# mas - mas
# que - que
#
#  -
#
# triumpho - triumpho
# maior - grande
# ainda - ainda
# o - o
# d'elle - d'elle
# ao - a o
# comprehender - comprehender
# , - ,
# que - que
# alcançara - alcançarar
# essa - esse
# cousa - cousa
#
#  -
#
# prodigiosa - prodigioso
# , - ,
# que - que
# nem - nem
# nos - em o
# sonhos - sonho
# mais - mais
# arrojados - arrojado
# das - de o
# suas - seu
# noites - noite
# de - de
# febre - febre
#
#  -
#
# elle - elle
# ousara - ousarar
# até - até
# ali - ali
# conceber - conceber
# ! - !
#
#
#  -
#
#
# Um - um
# dia - dia
# Margarida - Margarida
# , - ,
# em - em
# frente - frente
# d'aquelle - d'aquelle
# rasgo - rasgo
# assombroso - assombroso
# de - de
# valentia - valentia
# que - que
#
#  -
#
# collocara - collocara
# Thadeu - Thadeu
# ao - a o
# lado - lado
# dos - de o
# maiores - grande
# heroes - heroes
# , - ,
# puzera - puzerar
# se - se
# grave - gravar
# , - ,
#
#  -
#
# meditativa - meditativa
# , - ,
# e - e
# apontando - apontar
# com - com
# serena - sereno
# magestade - magestade
# para - para
# a - o
# lua - lua
# que - que
# se - se
# reflectia - reflectiar
#
#  -
#
# n'um - n'um
# tanque - tanque
# do - de o
# jardim - jardim
# , - ,
# pedira - pedirar
# a - o
# lua - lua
# ao - a o
# seu - seu
# amigo - amigo
# Thadeu - Thadeu
# ! - !
#
#
#  -
#
#
# Está - estar
# claro - claro
# que - que
# elle - elle
# lh'a - lh'a
# não - não
# pôde - poder
# dar - dar
# , - ,
# mas - mas
# gostou - gostar
# d'aquillo - d'aquillo
# ! - !
#
#
#  -
#
#
# Percebeu - Percebeu
# que - que
# o - ele
# julgavam - julgar
# capaz - capaz
# de - de
# cousas - cousa
# grandes - grande
# , - ,
# de - de
# levar - levar
# a - a
# cabo - cabo
#
#  -
#
# emprezas - emprezas
# impossiveis - impossivel
# , - ,
# e - e
# esta - este
# idéa - idéa
# que - que
# alguem - alguem
# tinha - ter
# da - de o
# sua - seu
# força - força
# , - ,
# fê-lo - fê-lo
#
#  -
#
# crescer - crescer
# aos - a o
# seus - seu
# proprios - proprio
# olhos - olho
# . - .
#
#
#  -
#
#
# O - o
# marquez - marquez
# conhecendo - conhecer
# que - que
# o - o
# pequeno - pequeno
# deixára - deixára
# de - de
# ser - ser
# seu - seu
# joguete - joguete
# , - ,
#
#  -
#
# simplesmente - simplesmente
# para - para
# ser - ser
# joguete - joguete
# de - de
# sua - seu
# filha - filha
# e - e
# herdeira - herdeira
# , - ,
# applaudiu-se - applaudiu-se
# de - de
#
#  -
#
# lhe - ele
# haver - haver
# dado - dar
# aquella - aquelle
# educação - educação
# especial - especial
# , - ,
# e - e
# prohibiu - prohibir
# que - que
# o - ele
# distrahissem - distrahir
# , - ,
#
#  -
#
# fosse - ser
# sob - sob
# que - que
# pretexto - pretexto
# fosse - ser
# , - ,
# das - de o
# suas - seu
# novas - novo
# funcções - funcção
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# era - ser
# ainda - ainda
# muito - muito
# pequenina - pequenino
# para - para
# entreter - entreter
# os - o
# paes - paes
# . - .
#
#
#  -
#
#
# Elle - Elle
# precisava - precisar
# das - de o
# excitações - excitação
# da - de o
# politica - politica
# , - ,
# das - de o
# luctas - lucta
# do - de o
# parlamento - parlamento
# , - ,
# dos - de o
#
#  -
#
# sorrisos - sorriso
# falsos - falso
# ou - ou
# verdadeiros - verdadeiro
# , - ,
# caros - caro
# ou - ou
# baratos - barato
# das - de o
# formosas - formoso
# mulheres - mulher
# , - ,
#
#  -
#
# do - de o
# jogo - jogo
# , - ,
# da - de o
# ambição - ambição
# , - ,
# do - de o
# amor - amor
# , - ,
# da - de o
# violencia - violencia
# corrosiva - corrosivo
# de - de
# todas - todo
# as - o
#
#  -
#
# pequenas - pequeno
# e - e
# grandes - grande
# paixões - paixão
# ! - !
#
#
#  -
#
#
# Ella - ella
# precisava - precisar
# do - de o
# luxo - luxo
# , - ,
# das - de o
# joias - joia
# que - que
# scintillam - scintillar
# , - ,
# das - de o
# sedas - seda
# que - que
# se - se
#
#  -
#
# quebram - quebrar
# em - em
# ondulações - ondulação
# brilhantes - brilhante
# , - ,
# do - de o
# côro - côro
# das - de o
# adulações - adulação
# mentidas - mentir
# , - ,
# de - de
#
#  -
#
# todas - todo
# as - o
# ephemeras - ephemera
# alegrias - alegria
# que - que
# só - só
# o - o
# mundo - mundo
# lhe - ele
# podia - poder
# dar - dar
# . - .
#
#
#  -
#
#
# Para - para
# ambos - ambos
# Margarida - Margarida
# seria - ser
# um - um
# remorso - remorso
# , - ,
# se - se
# a - a
# não - não
# vissem - vir
# tão - tão
# nedia - nedia
# , - ,
# tão - tão
#
#  -
#
# roliça - roliça
# , - ,
# tão - tão
# alegre - alegre
# , - ,
# com - com
# chispas - chispa
# de - de
# travessura - travessura
# maliciosa - malicioso
# no - em o
# olhar - olhar
# , - ,
# sempre - sempre
#
#  -
#
# acompanhada - acompanhar
# do - de o
# seu - seu
# pequeno - pequeno
# amigo - amigo
# , - ,
# submisso - submisso
# e - e
# fiel - fiel
# como - como
# um - um
# cão - cão
# . - .
#
#
#  -
#
#
# Deixaram-os - deixaram-os
# , - ,
# pois - pois
# , - ,
# crescer - crescer
# e - e
# viver - viver
# juntos - junto
# sob - sob
# o - o
# olhar - olhar
# das - de o
# aias - aia
# , - ,
# sempre - sempre
#
#  -
#
# um - um
# pouco - pouco
# hostil - hostil
# para - para
# Thadeu - Thadeu
# e - e
# por - por
# isso - isso
# tanto - tanto
# mais - mais
# insuspeito - insuspeito
# . - .
#
#
#  -
#
#
# Foi - ser
# o - o
# verdadeiro - verdadeiro
# paraiso - paraiso
# que - que
# este - este
# conheceu - conhecer
# na - em o
# terra - terra
# , - ,
# foi - ser
# a - o
# sua - seu
# idade - idade
# de - de
#
#  -
#
# ouro - ouro
# . - .
#
#
#  -
#
#
# Ha - Ha
# entes - ente
# que - que
# nunca - nunca
# nem - nem
# por - por
# um - um
# instante - instante
# só - só
# conheceram - conhecer
# a - o
# completa - completo
# ventura - ventura
# . - .
#
#
#  -
#
#
# São - ser
# de - de
# todos - todo
# os - o
# mais - mais
# desgraçados - desgraçado
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# mais - mais
# tarde - tarde
# podia - poder
# ao - a o
# menos - menos
# recordar-se - recordar se
# ! - !
#
#
#  -
#
#
# E - e
# elle - elle
# sabia - saber
# apreciar - apreciar
# tão - tão
# bem - bem
# aquellas - aquellas
# alegrias - alegria
# que - que
# em - em
# manhã - manhã
# abençoada - abençoar
#
#  -
#
# tinham - ter
# cahido - cahido
# sobre - sobre
# a - o
# sua - seu
# pobre - pobre
# cabeça - cabeça
# ! - !
# ... - ...
#
#
#  -
#
#
# Um - um
# dia - dia
# Margarida - Margarida
# travessa - travessa
# e - e
# caprichosa - caprichoso
# como - como
# era - ser
# , - ,
# desattendendo - desattender
# todas - todo
# as - o
#
#  -
#
# advertencias - advertencia
# de - de
# Thadeu - Thadeu
# , - ,
# deixara-se - deixara-se
# cahir - cahir
# dentro - dentro
# do - de o
# tanque - tanque
# do - de o
# jardim - jardim
# . - .
#
#
#  -
#
#
# O - o
# pequeno - pequeno
# não - não
# sabia - saber
# nadar - nadar
# . - .
#
#
#  -
#
#
# Que - que
# importa - importar
# ! - !
#
#
#  -
#
#
# Sem - sem
# premeditação - premeditação
# , - ,
# sem - sem
# raciocinio - raciocinio
# , - ,
# obedecendo - obedecer
# a - a
# um - um
# instincto - instincto
# de - de
# dedicação - dedicação
#
#  -
#
# inteiramente - inteiramente
# canina - canino
# , - ,
# deitou-se - deitar se
# n'agua - n'agua
# atrás - atrás
# d'ella - d'ella
# . - .
#
#
#  -
#
#
# As - o
# criadas - criar
# , - ,
# acudindo - acudir
# , - ,
# tiraram - tirar
# do - de o
# tanque - tanque
# as - o
# duas - dois
# creanças - creança
# abraçadas - abraçar
# . - .
#
#
#  -
#
#
# Imagine-se - Imagine-se
# o - o
# que - que
# iria - ir
# em - em
# casa - casa
# ! - !
#
#
#  -
#
#
# Thadeu - Thadeu
# , - ,
# castigado - castigar
# severamente - severamente
# , - ,
# não - não
# quiz - quiz
# condemnar - condemnar
# a - o
# sua - seu
# amiguinha - amiguinha
# , - ,
# para - para
#
#  -
#
# se - se
# salvar - salvar
# a - a
# si - se
# . - .
#
#
#  -
#
#
# Foi - ser
# ella - ella
# que - que
# , - ,
# soberba - soberba
# , - ,
# graciosa - gracioso
# , - ,
# com - com
# a - o
# sua - seu
# magestade - magestade
# de - de
# pequena - pequeno
# rainha - rainha
# , - ,
#
#  -
#
# disse - dizer
# aos - a o
# paes - paes
# : - :
#
#
#  -
#
#
# --Não - --Não
# batam - batar
# n'elle - n'elle
# . - .
# Elle - Elle
# pediu-me - pediu-me
# que - que
# não - não
# fosse - ser
# . - .
# Eu - eu
# é - ser
# que - que
# quiz - quiz
# ir - ir
# . - .
#
#
#  -
#
#
# Acharam-na - Acharam-na
# adoravel - adoravel
# ; - ;
# encheram-na - encheram-na
# de - de
# caricias - caricia
# e - e
# de - de
# gulodices - gulodice
# , - ,
# mas - mas
# ninguem - ninguem
#
#  -
#
# pensou - pensar
# na - em o
# acção - acção
# tão - tão
# simples - simples
# e - e
# tão - tão
# heroica - heroica
# do - de o
# pequeno - pequeno
# Thadeu - Thadeu
# , - ,
# a - a
# quem - quem
#
#  -
#
# tinham - ter
# posto - posto
# a - a
# alcunha - alcunha
# de - de
# _ - _
# medroso - medroso
# _ - _
# . - .
#
#
#
#  -
#
#
#
# III - III
#
#
#  -
#
#
# Foi - foi
# assim - assim
# que - que
# Margarida - Margarida
# fez - fazer
# nove - nove
# annos - anno
# . - .
#
#
#  -
#
#
# Era - ser
# linda - lindo
# e - e
# indomita - indomito
# . - .
#
#
#  -
#
#
# Tinha - ter
# um - um
# corpo - corpo
# airoso - airoso
# , - ,
# flexivel - flexivel
# e - e
# forte - forte
# . - .
#
#
#  -
#
#
# Ninguem - ninguem
# opprimira - opprimira
# nunca - nunca
# aquella - aquelle
# altiva - altivo
# natureza - natureza
# aristocratica - aristocratico
# . - .
#
#
#  -
#
#
# D'ahi - d'ahi
# a - o
# sua - seu
# isenção - isenção
# , - ,
# a - o
# liberdade - liberdade
# dos - de o
# seus - seu
# movimentos - movimento
# , - ,
# o - o
# fulgor - fulgor
# radioso - radioso
#
#  -
#
# dos - de o
# seus - seu
# grandes - grande
# olhos - olho
# azues - azue
# , - ,
# onde - onde
# um - um
# observador - observador
# veria - ver
# talvez - talvez
# as - o
#
#  -
#
# scintillações - scintillação
# metallicas - metallico
# que - que
# davam - dar
# tamanha - tamanho
# dureza - dureza
# ao - a o
# olhar - olhar
# de - de
# sua - seu
# mãe - mãe
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# tinha - ter
# uma - um
# vontade - vontade
# de - de
# ferro - ferro
# , - ,
# e - e
# uns - um
# nervos - nervo
# de - de
# mulher - mulher
# caprichosa - caprichoso
# . - .
#
#
#  -
#
#
# Quando - quando
# a - o
# professora - professora
# allemã - allemã
# que - que
# seus - seu
# paes - paes
# mandaram - mandar
# buscar - buscar
# , - ,
# quiz - quiz
# sujeitar - sujeitar
#
#  -
#
# o - o
# seu - seu
# espirito - espirito
# a - a
# uma - um
# certa - certo
# disciplina - disciplina
# , - ,
# Margarida - Margarida
# revoltou-se - revoltor se
# n'um - n'um
# impeto - impeto
#
#  -
#
# de - de
# insubordinação - insubordinação
# selvatica - selvatico
# . - .
#
#
#  -
#
#
# Tivera - Tivera
# criadas - criar
# que - que
# a - ela
# serviam - server
# , - ,
# um - um
# escravo - escravo
# que - que
# tremia - tremer
# diante - diante
# d'ella - d'ella
# , - ,
# e - e
#
#  -
#
# paes - paes
# que - que
# transigiam - transig
# com - com
# todos - todo
# os - o
# seus - seu
# pequenos - pequeno
# desejos - desejo
# de - de
# creança - creança
# . - .
#
#
#  -
#
#
# Dera-se - Dera-se
# bem - bem
# n'aquelle - n'aquelle
# meio - meio
# , - ,
# não - não
# queria - querer
# outro - outro
# , - ,
# não - não
# o - ele
# aceitava - aceitar
# , - ,
# nem - nem
#
#  -
#
# curvaria - curvar
# a - o
# sua - seu
# cabecinha - cabecinha
# erecta - erecto
# e - e
# firme - firme
# com - com
# uma - um
# aureola - aureola
# de - de
# anneis - annel
# de - de
#
#  -
#
# ouro - ouro
# a - a
# cerca-la - cerca-la
# , - ,
# a - a
# nenhum - nenhum
# dominio - dominio
# que - que
# não - não
# fosse - ser
# o - o
# da - de o
# sua - seu
# vontade - vontade
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Um - um
# dia - dia
# Thadeu - Thadeu
# ouviu - ouvir
# fallar - fallar
# vagamente - vagamente
# n'uma - n'uma
# viagem - viagem
# que - que
# seus - seu
# tios - tio
# iam - ir
#
#  -
#
# fazer - fazer
# ao - a o
# estrangeiro - estrangeiro
# , - ,
# e - e
# viu - ver
# começar - começar
# os - o
# preparativos - preparativo
# para - para
# ella - ella
# . - .
#
#
#  -
#
#
# Ficou - ficar
# no - em o
# céo - céo
# . - .
#
#
#  -
#
#
# Viveria - Viveria
# só - só
# na - em o
# grande - grande
# casa - casa
# com - com
# Margarida - Margarida
# e - e
# o - o
# rancho - rancho
# dos - de o
# criados - criado
# . - .
#
#
#  -
#
#
# Seriam - Seriam
# livres - livre
# . - .
#
#
#  -
#
#
# Ella - ella
# teria - ter
# um - um
# balouço - balouço
# no - em o
# jardim - jardim
# , - ,
# uma - um
# rede - rede
# brazileira - brazileiro
# no - em o
# kiosque - kiosque
# , - ,
# e - e
# um - um
#
#  -
#
# barquinho - barquinho
# no - em o
# lago - lago
# . - .
#
#
#  -
#
#
# Eram - Eram
# os - o
# seus - seu
# tres - tr
# sonhos - sonho
# ainda - ainda
# irrealizados - irrealizar
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# dirigiria - dirigir
# todos - todo
# os - o
# trabalhos - trabalho
# . - .
#
#
#  -
#
#
# Diria - Diria
# aos - a o
# operarios - operario
# que - que
# tinha - ter
# dezeseis - dezeseis
# annos - anno
# , - ,
# e - e
# que - que
# era - ser
# sobrinho - sobrinho
# do - de o
#
#  -
#
# marquez - Marquez
# . - .
#
#
#  -
#
#
# Os - o
# operarios - operario
# haviam - haver
# de - de
# respeital-o - respeital-o
# . - .
#
#
#  -
#
#
# Elles - Elles
# não - não
# tinham - ter
# precisão - precisão
# nenhuma - nenhum
# de - de
# se - se
# rir - rir
# do - de o
# seu - seu
# corpo - corpo
# enfezado - enfezar
# e - e
#
#  -
#
# rachitico - rachitico
# . - .
#
#
#  -
#
#
# Não - não
# é - ser
# preciso - preciso
# ser-se - ser se
# athletico - athletico
# para - para
# se - se
# ser - ser
# respeitado - respeitar
# pelos - por o
# homens - homem
# a - a
#
#  -
#
# quem - quem
# se - se
# paga - pagar
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# havia - haver
# de - de
# arranjar - arranjar
# algum - algum
# meio - meio
# de - de
# lhes - eles
# pagar - pagar
# . - .
#
#
#  -
#
#
# Andava - Andava
# então - então
# doente - doente
# , - ,
# exquisito - exquisito
# , - ,
# com - com
# uma - um
# excitação - excitação
# nervosa - nervoso
# que - que
# o - o
#
#  -
#
# torturava - torturava
# . - .
#
#
#  -
#
#
# O - o
# seu - seu
# affecto - affecto
# por - por
# Margarida - Margarida
# tivera - tiver
# uma - um
# recrudescencia - recrudescencia
# violenta - violento
# e - e
#
#  -
#
# dolorosa - doloroso
# . - .
#
#
#  -
#
#
# Tinha - ter
# vagos - vago
# presentimentos - presentimento
# que - que
# o - ele
# faziam - fazer
# chorar - chorar
# . - .
#
#
#  -
#
#
# Parecêra-lhe - parecêra-lhe
# que - que
# sua - seu
# tia - tia
# , - ,
# uma - uma
# vez - vez
# , - ,
# ao - a o
# encontral-o - encontral-o
# n'um - n'um
# corredor - corredor
# , - ,
# olhára - olhára
#
#  -
#
# para - para
# elle - elle
# com - com
# uma - um
# aguda - agudo
# ironia - ironio
# malevola - malevola
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# --Não - --Não
# sabes - sabes
# , - ,
# Thadeu - Thadeu
# ? - ?
# gritou - gritar
# Margarida - Margarida
# entrando - entrar
# como - como
# um - um
# raio - raio
# de - de
# sol - sol
# no - em o
#
#  -
#
# quarto - quarto
# onde - onde
# costumava - costumar
# brincar - brincar
# com - com
# o - o
# primo - primo
# . - .
# Não - não
# sabes?--E - Sabes?--E
# atirou-lhe - atirou-lhe
#
#  -
#
# negligentemente - negligentemente
# aos - a o
# pés - pé
# com - com
# um - um
# feixe - feixe
# de - de
# flôres - flôres
# e - e
# de - de
# folhas - folha
# verdes - verde
# que - que
#
#  -
#
# estivera - estivera
# colhendo - colher
# na - em o
# quinta.--Tambem - quinta.--Tambem
# eu - eu
# vou - ir
# com - com
# o - o
# papá - papá
# e - e
# a - o
# mamã - mamã
# . - .
# Vamos - ir
#
#  -
#
# a - a
# Paris - Paris
# ... - ...
# muito - muito
# longe - longe
# ... - ...
# muito - muito
# longe - longe
# ... - ...
# Estive - Estive
# á - á
# escuta - escuta
# ... - ...
# percebi - percebi
# umas - um
#
#  -
#
# cousas - cousa
# mas - mas
# não - não
# percebi - percebi
# outras - outro
# . - .
# Fallaram - Fallaram
# n'um - n'um
# convento - convento
# ... - ...
# no - em o
# _ - _
# Sacré - Sacré
#
#  -
#
# Cœur - Cœur
# _ - _
# ... - ...
# Sabes - Sabes
# o - o
# que - que
# é - ser
# ? - ?
# ... - ...
#
#
#  -
#
#
# Thadeu - Thadeu
# sabia - saber
# . - .
#
#
#  -
#
#
# Não - não
# disse - dizer
# nada - nada
# , - ,
# mas - mas
# no - em o
# outro - outro
# dia - dia
# não - não
# pôde - poder
# levantar-se - levantar se
# da - de o
# cama - cama
# . - .
#
#
#  -
#
#
# Tinha - ter
# dôres - dôr
# em - em
# todo - todo
# o - o
# corpo - corpo
# e - e
# um - um
# grande - grande
# cançasso - cançasso
# , - ,
# como - como
# de - de
# quem - quem
# deu - dar
# uma - um
#
#  -
#
# larga - larga
# caminhada - caminhada
# . - .
#
#
#  -
#
#
# Gemia - Gemia
# baixinho - baixinho
# abrazado - abrazar
# em - em
# febre - febre
# , - ,
# e - e
# quando - quando
# pediu - pedir
# muito - muito
# humildemente - humildemente
# , - ,
# com - com
#
#  -
#
# medo - medo
# de - de
# recusa - recusa
# , - ,
# para - para
# ver - ver
# Margarida - Margarida
# , - ,
# disseram-lhe - disseram-lhe
# que - que
# a - o
# doença - doença
# d'elle - de 'elle
#
#  -
#
# podia - poder
# pegar-se - pegar se
# e - e
# que - que
# as - o
# meninas - menina
# não - não
# iam - ir
# ao - a o
# quarto - quarto
# dos - de o
# homens - homem
# . - .
#
#
#  -
#
#
# Pois - pois
# isto - isto
# é - ser
# um - um
# homem - homem
# ? - ?
# pensava - pensar
# Thadeu - Thadeu
# desolado - desolar
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Margarida - Margarida
# de - de
# endoudecida - endoudecida
# com - com
# a - o
# mudança - mudança
# , - ,
# com - com
# o - o
# movimento - movimento
# , - ,
# com - com
# a - o
#
#  -
#
# espectativa - espectativa
# de - de
# uma - um
# existencia - existencia
# desconhecida - desconhecer
# e - e
# nova - novo
# , - ,
# esqueceu-se - esqueceu-se
#
#  -
#
# completamente - completamente
# do - de o
# enfermo - enfermo
# . - .
#
#
#  -
#
#
# Partiu - Partiu
# sem - sem
# pedir - pedir
# sequer - sequer
# para - para
# lhe - ele
# dizer - dizer
# adeus - adeus
# ! - !
# ... - ...
#
#
#  -
#
#
# Quando - quando
# Thadeu - Thadeu
# ao - a o
# cabo - cabo
# de - de
# um - um
# mez - mez
# de - de
# doença - doença
# sahiu - sahiu
# do - de o
# quarto - quarto
# com - com
# o - o
# rosto - rosto
#
#  -
#
# macilento - macilento
# , - ,
# abatido - abatir
# , - ,
# cançado - cançar
# , - ,
# como - como
# o - o
# de - de
# um - um
# velho - velho
# , - ,
# com - com
# a - o
# espinha - espinha
# dobrada - dobrar
# e - e
#
#  -
#
# as - o
# magras - magro
# pernas - perna
# vacillantes - vacillante
# , - ,
# pediu - pedir
# para - para
# ir - ir
# ao - a o
# quarto - quarto
# onde - onde
# brincava - brincar
# com - com
#
#  -
#
# a - o
# sua - seu
# _ - _
# perola - perolar
# _ - _
# , - ,
# e - e
# agachou-se - agachor se
# a - a
# um - um
# cantinho - cantinho
# a - a
# chorar - chorar
# com - com
# uns - um
# uivos - uivo
#
#  -
#
# dolorosos - doloroso
# , - ,
# com - com
# uns - um
# uivos - uivo
# caninos - canino
# que - que
# faziam - fazer
# mal - mal
# . - .
#
#
#  -
#
#
# Sentia-se - Sentia-se
# para - para
# sempre - sempre
# só - só
# ... - ...
#
#
#
#  -
#
#
#
# IV - IV
#
#
#  -
#
#
# O - o
# marquez - marquez
# tinha - ter
# ido - ir
# sósinho - sósinho
# para - para
# França - França
# . - .
# Fôra - Fôra
# , - ,
# ao - a o
# que - que
# se - se
# dizia - dizer
# , - ,
# buscar - buscar
# a - o
#
#  -
#
# filha - filha
# ao - a o
# _ - _
# Sacré-Cœur - Sacré-Cœur
# _ - _
# . - .
#
#
#  -
#
#
# A - o
# educação - educação
# de - de
# Margarida - Margarida
# devia - dever
# estar - estar
# completa - completo
# . - .
# Fôra-se - Fôra-se
# embora - embora
# com - com
# nove - nove
#
#  -
#
# annos - annos
# de - de
# idade - idade
# , - ,
# e - e
# haviam - haver
# já - já
# passado - passar
# sete - sete
# depois - depois
# que - que
# ella - ella
# partira - partira
# . - .
#
#
#  -
#
#
# Sete - sete
# annos - annos
# ! - !
# que - que
# longo - longo
# periodo - periodo
# ! - !
#
#
#  -
#
#
# A - o
# casa - casa
# dos - de o
# marquezes - marquez
# era - ser
# pouco - pouco
# mais - mais
# ou - ou
# menos - menos
# a - o
# mesma - mesmo
# cousa - cousa
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# perdêra - perdêra
# sua - seu
# mãe - mãe
# , - ,
# mas - mas
# aquella - aquelle
# figura - figura
# apagada - apagar
# , - ,
# melancolica - melancolica
# , - ,
# de - de
# uma - um
#
#  -
#
# debilidade - debilidade
# de - de
# valetudinaria - valetudinario
# , - ,
# pouca - pouco
# falta - falta
# havia - haver
# feito - fazer
# no - em o
# palacio - palacio
#
#  -
#
# illuminado - illuminar
# e - e
# radioso - radioso
# . - .
#
#
#  -
#
#
# O - o
# marquez - marquez
# aconselhado - aconselhar
# por - por
# alguma - algum
# pessoa - pessoa
# de - de
# juizo - juizo
# e - e
# de - de
# caridade - caridade
# tinha - ter
#
#  -
#
# consentido - consentido
# a - a
# que - que
# logo - logo
# depois - depois
# da - de o
# partida - partida
# de - de
# Margarida - Margarida
# seu - seu
# sobrinho - sobrinho
#
#  -
#
# entrasse - entrar
# para - para
# um - um
# collegio - collegio
# . - .
#
#
#  -
#
#
# Tambem - Tambem
# já - já
# lhe - ele
# não - não
# servia - servia
# para - para
# nada - nada
# . - .
#
#
#  -
#
#
# Com - com
# o - o
# seu - seu
# corpo - corpo
# magro - magro
# e - e
# desengonçado - desengonçar
# , - ,
# um - um
# corpo - corpo
# de - de
# funambulo - funambulo
# , - ,
# um - um
# corpo - corpo
# de - de
#
#  -
#
# grotesco - grotesco
# , - ,
# tinha - ter
# melancolias - melancolia
# _ - _
# quixotescas - quixotesco
# _ - _
# que - que
# incommodavam - incommodar
# quem - quem
# o - o
# via - ver
# . - .
#
#
#  -
#
#
# Os - o
# criados - criado
# deram - dar
# por - por
# mais - mais
# de - de
# uma - um
# vez - vez
# com - com
# o - o
# rapazola - rapazola
# a - a
# chorar - chorar
# de - de
# bruços - bruços
#
#  -
#
# n'um - n'um
# recanto - recanto
# do - de o
# jardim - jardim
# , - ,
# chamado - chamar
# o - o
# _ - _
# canteiro - canteiro
# de - de
# Margarida - Margarida
# _ - _
# . - .
#
#
#  -
#
#
# Era - ser
# um - um
# pequeno - pequeno
# espaço - espaço
# semeado - semear
# de - de
# flôres - flôres
# , - ,
# onde - onde
# principalmente - principalmente
# abundavam - abundar
#
#  -
#
# os - o
# malmequeres - malmequer
# brancos - branco
# que - que
# tinham - ter
# o - o
# poetico - poetico
# nome - nome
# da - de o
# filha - filha
# do - de o
# marquez - Marquez
# . - .
#
#
#  -
#
#
# Havia - Haver
# ali - ali
# uma - um
# grande - grande
# arvore - arvore
# , - ,
# um - um
# castanheiro - castanheiro
# copado - copar
# cuja - cujo
# rama - rama
# folhuda - folhudar
#
#  -
#
# abrigava - abrigar
# as - o
# longas - longo
# scismas - scisma
# dolorosas - doloroso
# de - de
# Thadeu - Thadeu
# . - .
#
#
#  -
#
#
# Não - não
# se - se
# podia - poder
# consolar - consolar
# ! - !
#
#
#  -
#
#
# Era - ser
# ali - ali
# n'aquelle - n'aquelle
# sitio - sitio
# fresco - fresco
# , - ,
# esmaltado - esmaltado
# de - de
# flores - flor
# , - ,
# exhalando - exhalar
# um - um
# cheiro - cheiro
#
#  -
#
# agreste - agreste
# e - e
# sadio - sadio
# , - ,
# que - que
# elle - elle
# se - se
# deixava - deixar
# ficar - ficar
# horas - hora
# e - e
# horas - hora
# esquecido - esquecer
# de - de
#
#  -
#
# todos - todo
# , - ,
# n'uma - n'uma
# especie - especie
# de - de
# lethargo - lethargo
# bestial - bestial
# , - ,
# o - o
# lethargo - lethargo
# de - de
# um - um
# animal - animal
#
#  -
#
# ferido - ferir
# . - .
#
#
#  -
#
#
# E - e
# desfiava - desfiar
# na - em o
# memoria - memoria
# todo - todo
# o - o
# seu - seu
# passado - passado
# , - ,
# toda - todo
# a - o
# vida - vida
# que - que
# vivêra - vivêra
# , - ,
#
#  -
#
# abandonado - abandonar
# , - ,
# desprezado - desprezar
# , - ,
# perseguido - perseguir
# de - de
# chufas - chufa
# ou - ou
# de - de
# maus - mau
# tratos - trato
# , - ,
# de - de
#
#  -
#
# caprichos - capricho
# humilhantes - humilhante
# , - ,
# ou - ou
# de - de
# observações - observação
# glacialmente - glacialmente
# desdenhosas - desdenhoso
# . - .
#
#
#  -
#
#
# Só - só
# _ - _
# ella - ella
# _ - _
# nunca - nunca
# o - o
# ferira - ferira
# ! - !
# só - só
# ella - ella
# fôra - sfôr
# no - em o
# seu - seu
# viver - viver
# de - de
# cão - cão
# apedrejado - apedrejar
# um - um
#
#  -
#
# consolo - consolo
# dulcissimo - dulcissimo
# ! - !
# uma - um
# nesga - nesga
# do - de o
# céo - céo
# que - que
# se - se
# entreabrira - entreabriro
# ! - !
#
#
#  -
#
#
# Só - só
# _ - _
# ella - ella
# _ - _
# ...
#
#  -
#
# esquecimento - esquecimento
# . - .
#
#
#  -
#
#
# E - e
# em - em
# troca - troca
# d'esse - d'er
# consolo - consolo
# supremo - supremo
# a - a
# que - que
# se - se
# julgam - julgar
# sem - sem
# direito - direito
# , - ,
# são - ser
#
#  -
#
# capazes - capaz
# de - de
# todos - todo
# os - o
# sacrificios - sacrificio
# , - ,
# de - de
# todos - todo
# os - o
# renunciamentos - renunciamento
# sublimes - sublimes
#
#  -
#
# que - que
# inventa - inventar
# a - o
# mulher - mulher
# depois - depois
# de - de
# ter - ter
# perdido - perder
# a - o
# esperança - esperança
# de - de
# ser - ser
# feliz - feliz
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Leitora - Leitora
# , - ,
# estás - estás
# cansada - cansado
# das - de o
# chatas - chato
# e - e
# incaracteristicas - incaracteristico
# figuras - figura
# que - que
# tens - tens
#
#  -
#
# encontrado - encontrar
# na - em o
# vida - vida
# real - real
# ? - ?
# Entristecem-te - entristecem-te
# dolorosamente - dolorosamente
# os - o
# typos - typo
# hediondos - hediondo
#
#  -
#
# ou - ou
# repugnantes - repugnante
# da - de o
# moderna - moderno
# arte - arte
# ? - ?
#
#
#  -
#
#
# As - o
# Gervasias - Gervasias
# , - ,
# as - o
# Bovarys - Bovarys
# , - ,
# as - o
# Fannys - Fannys
# , - ,
# as - o
# peccadoras - peccadora
# da - de o
# França - França
# juvenil - juvenil
# ? - ?
#
#
#  -
#
#
# Pois - pois
# bem - bem
# , - ,
# deixa - deixar
# que - que
# desfile - desfile
# por - por
# diante - diante
# do - de o
# teu - teu
# olhar - olhar
# pensativo - pensativo
# a - o
# gloriosa - glorioso
#
#  -
#
# legião - legião
# das - de o
# filhas - filha
# de - de
# Victor - Victor
# Hugo - Hugo
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# crê - crer
# que - que
# não - não
# aprenderás - aprenderás
# com - com
# ellas - ella
# cousa - cousa
# alguma - algum
# que - que
# rebaixe - rebaixe
# o - o
# teu - teu
#
#  -
#
# espirito - espirito
# , - ,
# que - que
# fira - fira
# o - o
# teu - teu
# coração - coração
# , - ,
# que - que
# surprehenda - surprehendar
# cruelmente - cruelmente
# o - ele
# teu - teu
#
#  -
#
# entendimento - entendimento
# . - .
#
#
#  -
#
#
# Ellas - Ellas
# sabem - saber
# todas - todo
# o - o
# que - que
# é - ser
# o - o
# amor - amor
# , - ,
# muitas - muito
# o - o
# que - que
# é - ser
# o - o
# arrependimento - arrependimento
# , - ,
# o - o
#
#  -
#
# remorso - remorso
# , - ,
# a - o
# vergonha - vergonha
# , - ,
# a - o
# expiação - expiação
# ; - ;
# nenhuma - nenhum
# sabe - saber
# o - o
# que - que
# é - ser
# o - o
# triumpho - triumpho
#
#  -
#
# impudico - impudico
# do - de o
# vicio - vicio
# , - ,
# a - o
# ostentação - ostentação
# criminosa - criminoso
# das - de o
# vaidades - vaidade
# mundanas - mundano
# , - ,
# a - o
#
#  -
#
# impenitencia - impenitencia
# immoral - immoral
# das - de o
# que - que
# medram - medr
# no - em o
# meio - meio
# do - de o
# crime - crime
# . - .
#
#
#  -
#
#
# As - o
# peccadoras - peccadora
# contar-te-hão - contar-te-hão
# a - o
# dolorosa - doloroso
# historia - historia
# das - de o
# suas - seu
# amarguras - amargura
# , - ,
# as - o
#
#  -
#
# virgens - virgem
# a - o
# doçura - doçura
# sonhadora - sonhador
# dos - de o
# seus - seu
# extasis - extasi
# ! - !
#
#
#  -
#
#
# Amaram - Amaram
# , - ,
# acreditaram - acreditar
# , - ,
# sentiram - sentir
# na - em o
# plenitude - plenitude
# do - de o
# coração - coração
# que - que
# a - o
# vida - vida
# é - ser
# boa - bom
# , - ,
#
#  -
#
# e - e
# que - que
# o - o
# paraiso - paraiso
# póde - póder
# encontrar-se - encontrar se
# n'um - n'um
# canto - canto
# da - de o
# terra - terra
# . - .
#
#
#  -
#
#
# Não - não
# sabem - saber
# nada - nada
# de - de
# _ - _
# toilettes - toilette
# _ - _
# , - ,
# de - de
# pequenas - pequeno
# intrigas - intriga
# , - ,
# de - de
# namoros - namoro
# , - ,
# de - de
#
#  -
#
# vicios - vicio
# mesquinhos - mesquinho
# , - ,
# de - de
# invejas - invejas
# e - e
# de - de
# tagarelices - tagarelices
# ; - ;
# atravessaram - atravessar
# o - o
# mundo - mundo
# com - com
#
#  -
#
# os - o
# olhos - olho
# fitos - fitos
# n'outros - n'outro
# olhos - olho
# , - ,
# com - com
# as - o
# mãos - mão
# enlaçadas - enlaçar
# n'outras - n'outro
# mãos - mão
# , - ,
# com - com
#
#  -
#
# a - o
# alma - alma
# a - a
# cantar-lhes - cantar-lhes
# um - um
# _ - _
# hosanna - hosanna
# _ - _
# de - de
# mysticos - mystico
# arroubos - arroubo
# ! - !
#
#
#  -
#
#
# Se - se
# queres - querer
# estudar - estudar
# os - o
# escaninhos - escaninho
# caprichosos - caprichoso
# de - de
# um - um
# coração - coração
# de - de
# mulher - mulher
#
#  -
#
# bonita - bonito
# e - e
# garrida - garrer
# , - ,
# não - não
# as - elas
# procures - procures
# , - ,
# mas - mas
# tambem - tambem
# lhes - eles
# não - não
# peças - peça
# que - que
# te - te
#
#  -
#
# fallem - fallem
# nos - em o
# nossos - nosso
# piedosos - piedoso
# e - e
# obscuros - obscuro
# deveres - dever
# de - de
# todos - todo
# os - o
# dias - dia
# . - .
#
#
#  -
#
#
# São - ser
# as - o
# hallucinadas - hallucinada
# do - de o
# amor - amor
# ! - !
# Arrastou-as - arrastour as
# uma - um
# tempestade - tempestade
# para - para
# outras - outro
#
#  -
#
# espheras - esphera
# ardentes - ardente
# onde - onde
# se - se
# não - não
# vive - viver
# a - o
# vida - vida
# que - que
# conhecemos - conhecer
# ! - !
#
#
#  -
#
#
# Vê - Vêer
# tu - tu
# -- - --
# Esmeralda - Esmeralda
# ! - !
# que - que
# bem - bem
# posto - postar
# nome - nome
# ! - !
#
#
#  -
#
#
# Toda - toda
# ella - ella
# scintilla - scintill
# ao - a o
# sol - sol
# como - como
# a - o
# pedra - pedra
# preciosa - precioso
# que - que
# lhe - ele
# serviu - servir
# de - de
#
#  -
#
# baptismo - baptismo
# ; - ;
# os - o
# seus - seu
# dedos - dedo
# de - de
# _ - _
# gitana - gitanar
# _ - _
# crestados - crestado
# e - e
# finos - fino
# arrancam - arrancar
# ao - a o
#
#  -
#
# pandeiro - pandeiro
# do - de o
# seu - seu
# paiz - paiz
# doidos - doir
# e - e
# extranhos - extranho
# sons - som
# ! - !
# Fascina - Fascina
# com - com
# um - um
# olhar - olhar
#
#  -
#
# inconsciente - inconsciente
# dos - de o
# seus - seu
# olhos - olho
# de - de
# velludo - velludo
# , - ,
# com - com
# uma - um
# nota - nota
# da - de o
# sua - seu
# voz - voz
#
#  -
#
# crystallina - crystallinar
# , - ,
# com - com
# um - um
# meneio - meneio
# do - de o
# seu - seu
# corpo - corpo
# de - de
# serpente - serpente
# . - .
#
#
#  -
#
#
# Que - que
# sabe - saber
# ella - ella
# da - de o
# vida - vida
# ? - ?
# Nada - nada
# ; - ;
# a - a
# não - não
# ser - ser
# que - que
# a - o
# vida - vida
# é - ser
# bella - bello
# , - ,
# visto - ver
# que - que
# ha - ha
#
#  -
#
# dous - dous
# olhos - olho
# que - que
# ao - a o
# fixar - fixar
# nos - em o
# seus - seu
# os - o
# banharam - banhar
# de - de
# fulgor - fulgor
# ! - !
#
#
#  -
#
#
# E - e
# Cosette - Cosette
# ! - !
# vive - viver
# ao - a o
# pé - pé
# d'ella - d'ella
# um - um
# enygma - enygma
# sombrio - sombrio
# ! - !
# um - um
# espirito - espirito
# sobrehumano - sobrehumano
# ! - !
#
#  -
#
# um - um
# luctador - luctador
# d'estas - d'estas
# luctas - lucta
# interiores - interior
# cujo - cujo
# reflexo - reflexo
# se - se
# estampa - estampar
# na - em o
# frente - frente
#
#  -
#
# que - que
# as - elas
# encerra - encerrar
# . - .
#
#
#  -
#
#
# Ella - ella
# nunca - nunca
# interrogou - interrogar
# essa - esse
# alma - alma
# , - ,
# e - e
# nunca - nunca
# tentou - tentar
# decifrar - decifrar
# esse - esse
# enygma - enygma
# , - ,
# e - e
#
#  -
#
# nunca - nunca
# sequer - sequer
# comprehendeu - comprehender
# a - o
# existencia - existencia
# d'essas - d'essas
# luctas - lucta
# . - .
#
#
#  -
#
#
# Ao - ao
# seu - seu
# companheiro - companheiro
# triste - triste
# , - ,
# humilde - humilde
# , - ,
# heroico - heroico
# , - ,
# adoravel - adoravel
# ella - ella
# deve - dever
# durante - durante
#
#  -
#
# quinze - quinze
# annos - anno
# a - o
# ventura - ventura
# mais - mais
# perfeita - perfeito
# que - que
# póde - póder
# gosar-se - gosar-se
# na - em o
# terra - terra
# . - .
#
#
#  -
#
#
# Satisfez-lhe - Satisfez-lhe
# todos - todo
# os - o
# desejos - desejo
# ; - ;
# todos - todo
# os - o
# brinquedos - brinquedo
# d'aquella - D'aquella
# fada - fada
# , - ,
#
#  -
#
# encarregou-se - encarregou se
# de - de
# os - eles
# fornecer - fornecer
# a - o
# natureza - natureza
# na - em o
# liberdade - liberdade
# plena - pleno
# , - ,
# nos - em o
# seus - seu
#
#  -
#
# idyllios - idyllio
# primaveris - primaveris
# ! - !
# Estava - estar
# na - em o
# escuridão - escuridão
# , - ,
# e - e
# deram-lhe - deram-lhe
# luz - luz
# ; - ;
# era - ser
# escrava - escrar
#
#  -
#
# fizeram-n'a - fizeram-n'a
# rainha - rainha
# . - .
#
#
#  -
#
#
# Não - não
# importa - importar
# ! - !
# Marius - Marius
# appareceu - apparecer
# e - e
# Cosette - Cosette
# louca - louco
# , - ,
# deslumbrada - deslumbrar
# , - ,
# esquecida - esquecer
# , - ,
#
#  -
#
# deixa - deixar
# morrer - morrer
# de - de
# dôr - dôr
# o - o
# amigo - amigo
# da - de o
# sua - seu
# risonha - risonho
# mocidade - mocidade
# . - .
#
#
#  -
#
#
# É - ser
# má - má
# ? - ?
#
#
#  -
#
#
# Não - não
# ; - ;
# é - ser
# ignorante - ignorante
# . - .
# Não - não
# sabe - saber
# que - que
# se - se
# morre - morrer
# visto - ver
# que - que
# elle - elle
# vive - viver
# na - em o
# posse - posse
# de - de
#
#  -
#
# uma - um
# ventura - ventura
# que - que
# nunca - nunca
# até - até
# alli - alli
# conhecera - conhecerar
# . - .
#
#
#  -
#
#
# Não - não
# sabe - saber
# que - que
# se - se
# tem - ter
# saudades - saudade
# , - ,
# porque - porque
# ao - a o
# pé - pé
# de - de
# Marius - Marius
# nunca - nunca
# esse - esse
# espinho - espinho
#
#  -
#
# lhe - ele
# mordeu - morder
# no - em o
# coração - coração
# ! - !
#
#
#  -
#
#
# Pois - pois
# é - ser
# possivel - possivel
# ser - ser
# desgraçado - desgraçar
# quando - quando
# eu - eu
# sou - ser
# tão - tão
# feliz - feliz
# ! - !
# pergunta - perguntar
#
#  -
#
# tacitamente - tacitamente
# com - com
# barbaridade - barbaridade
# que - que
# se - se
# ignora - ignorar
# , - ,
# cada - cada
# um - um
# dos - de o
# sorrisos - sorriso
# de - de
#
#  -
#
# ventura - ventura
# que - que
# ella - ella
# atirara - atirar
# em - em
# redor - redor
# de - de
# si - se
# , - ,
# sem - sem
# se - se
# importar - importar
# onde - onde
# lhe - ele
# vão - ir
#
#  -
#
# cahir - cahir
# ! - !
#
#
#  -
#
#
# Ai - ai
# ! - !
# Cosette - cosette
# , - ,
# Cosette - Cosette
# ! - !
# eu - eu
# gosto - gostar
# de - de
# ti - ti
# , - ,
# borboleta - borboleta
# , - ,
# ébria - ébr
# de - de
# luz - luz
# ! - !
# és - és
# uma - um
#
#  -
#
# das - de o
# visões - visão
# luminosas - luminoso
# que - que
# ficarás - ficarásr
# para - para
# sempre - sempre
# moça - moça
# e - e
# querida - querido
# ! - !
# és - és
# uma - um
#
#  -
#
# estatua - estatua
# branca - branco
# que - que
# ninguem - ninguem
# ousará - ousar
# mutilar - mutilar
# e - e
# que - que
# os - o
# seculos - seculo
# verão - ver
# erguida - erguer
#
#  -
#
# no - em o
# teu - teu
# pedestal - pedestal
# de - de
# flôres - flôres
# ! - !
# Mas - mas
# como - como
# eu - eu
# te - te
# amaria - amar
# muito - muito
# mais - mais
# ainda - ainda
# se - se
# em - em
#
#  -
#
# vez - vez
# de - de
# seres - ser
# o - o
# Amor - Amor
# fosses - sesr
# o - o
# Sacrificio - sacrificio
# ! - !
#
#
#  -
#
#
# Um - um
# dia - dia
# Victor - Victor
# Hugo - Hugo
# pediu - pedir
# ás - ás
# neblinas - neblina
# matinaes - matinaes
# dos - de o
# climas - Climas
# do - de o
# norte - norte
# , - ,
# uma - um
#
#  -
#
# porção - porção
# de - de
# renda - renda
# branca - branco
# e - e
# transparente - transparente
# com - com
# que - que
# ellas - ella
# corôam - corôam
# a - a
# crista - crista
# das - de o
#
#  -
#
# montanhas - montanha
# e - e
# ... - ...
# fez - fazer
# Déa - Déa
# ! - !
#
#
#  -
#
#
# Que - que
# doce - doce
# , - ,
# vaporosa - vaporoso
# e - e
# lendaria - lendario
# visão - visão
# ! - !
#
#
#  -
#
#
# Não - não
# ha - ha
# n'ella - n'ella
# cousa - cousa
# alguma - algum
# que - que
# seja - ser
# realidade - realidade
# ! - !
#
#
#  -
#
#
# Toca - Toca
# na - em o
# terra - terra
# ao - a o
# de - de
# leve - leve
# ; - ;
# não - não
# tanto - tanto
# que - que
# pareça - parecer
# filha - filha
# d'ella - d'ella
# , - ,
# não - não
# tão - tão
#
#  -
#
# pouco - pouco
# que - que
# lhe - ele
# não - não
# seja - ser
# dado - dar
# consolar - consolar
# alguem - alguem
# votado - votado
# ás - ás
# dores - dor
# sem - sem
# consolo - consolo
# . - .
#
#
#  -
#
#
# É - ser
# cega - cega
# ! - !
#
#
#  -
#
#
# Amada - Amar
# por - por
# um - um
# monstro - monstro
# sabe - saber
# verter-lhe - verter-lhe
# n'alma - n'almar
# as - o
# alegrias - alegria
# de - de
# um - um
# Deus - Deus
# ! - !
#
#
#  -
#
#
# Não - não
# vê - ver
# o - o
# homem - homem
# que - que
# a - ela
# ama - amar
# , - ,
# vê - ver
# o - o
# amor - amor
# de - de
# que - que
# elle - elle
# a - a
# veste - vestir
# ! - !
#
#
#  -
#
#
# Abençoada - abençoar
# cegueira - cegueira
# que - que
# faz - fazer
# dous - dous
# felizes - feliz
# ! - !
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Ao - ao
# lado - lado
# d'ella - d'ella
# -- - --
# supremo - Supremo
# contraste!--sorri - contraste!--sorri
# Josiane - Josiane
# com - com
# o - o
# seu - seu
# sorriso - sorriso
# de - de
#
#  -
#
# deusa - deusa
# pagã - pagã
# ! - !
#
#
#  -
#
#
# No - em o
# olho - olho
# azul - azul
# da - de o
# patricia - patricia
# ingleza - ingleza
# scintilla - scintilla
# em - em
# chispas - chispa
# uma - um
# diabolica - diabolico
#
#  -
#
# ironia - ironia
# . - .
#
#
#  -
#
#
# Josiane - Josiane
# é - ser
# a - o
# amante - amante
# do - de o
# impossivel - impossivel
# ! - !
# Procura - procura
# o - o
# que - que
# nunca - nunca
# ninguem - ninguem
# achou - achar
# ! - !
#
#
#  -
#
#
# Quer - querer
# um - um
# sonho - sonho
# que - que
# a - o
# sacie - sacie
# , - ,
# o - o
# amor - amor
# de - de
# um - um
# Titan - Titan
# , - ,
# ou - ou
# de - de
# um - um
# cyclope - cyclope
# , - ,
# o - o
# amor - amor
#
#  -
#
# de - de
# Apollo - Apollo
# ou - ou
# de - de
# Polyphemo - Polyphemo
# ! - !
#
#
#  -
#
#
# Estranha - estranha
# figura - figurar
# , - ,
# producto - producto
# doentio - doentio
# de - de
# uma - um
# noite - noite
# de - de
# febre - febre
# ! - !
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Dona - Dona
# Sol - Sol
# , - ,
# Maria - Maria
# de - de
# Neuburgo - Neuburgo
# , - ,
# Marion - Marion
# , - ,
# Eponine - Eponine
# , - ,
# Cosette - Cosette
# , - ,
# Déa - Déa
# , - ,
# quantas - quantas
#
#  -
#
# figuras - figura
# radiosas - radioso
# , - ,
# quantas - quantas
# humanições - humanição
# esplendidas - esplendir
# da - de o
# mulher - mulher
# sonhada - sonhar
# ! - !
#
#
#  -
#
#
# Nas - em o
# horas - hora
# de - de
# desalento - desalento
# ou - ou
# de - de
# amarga - amarga
# duvida - duvida
# , - ,
# nas - em o
# horas - hora
# em - em
# que - que
# as - o
# miserias - miseria
#
#  -
#
# que - que
# nos - nós
# cercam - cercar
# , - ,
# nos - nós
# fizeram - fazer
# encarar - encarar
# a - o
# vida - vida
# pelo - por o
# seu - seu
# aspecto - aspecto
# mais - mais
#
#  -
#
# desolado - desolar
# e - e
# mais - mais
# escuro - escuro
# olhemos - olher
# para - para
# ellas - ella
# ! - !
#
#
#  -
#
#
# Dir-nos-hão - dir-nos-hão
# os - o
# poetas - poeta
# de - de
# hoje - hoje
# que - que
# ellas - ella
# não - não
# existem - existir
# , - ,
# e - e
# , - ,
# o - o
# que - que
# é - ser
# peior - peior
# , - ,
#
#  -
#
# que - que
# ellas - ella
# não - não
# puderam - puder
# existir - existir
# nunca - nunca
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# é - ser
# bem - bem
# triste - triste
# , - ,
# é - ser
# bem - bem
# esteril - esteril
# a - o
# arte - arte
# que - que
# só - só
# trata - tratar
# de - de
# rebaixar - rebaixar
# o - o
# que - que
# em - em
#
#  -
#
# nós - nós
# é - ser
# de - de
# mais - mais
# elevada - elevado
# essencia - essencia
# , - ,
# e - e
# só - só
# quer - querer
# que - que
# vejamos - vejar
# a - o
# fatalidade - fatalidade
#
#  -
#
# brutal - brutal
# do - de o
# instincto - instincto
# , - ,
# onde - onde
# viamos - viar
# d'antes - d'ante
# a - o
# fatalidade - fatalidade
# mais - mais
# nobre - nobre
# do - de o
#
#  -
#
# sentimento - sentimento
# . - .
#
#
#  -
#
#
# Não - não
# acreditemos - acrediter
# o - o
# que - que
# elles - elle
# nos - nós
# dizem - dizer
# , - ,
# porque - porque
# na - em o
# sua - seu
# preoccupação - preoccupação
#
#  -
#
# exagerada - exagerar
# do - de o
# horrivel - horrivel
# , - ,
# elles - elle
# mentem - menter
# muito - muito
# mais - mais
# do - de o
# que - que
# os - o
# outros - outro
# mentiam - menter
#
#  -
#
# na - em o
# sua - seu
# preoccupação - preoccupação
# exagerada - exagerar
# do - de o
# bello - bello
# ! - !
#
#
#  -
#
#
# Estes - este
# reunindo - reunir
# todos - todo
# os - o
# vicios - vicio
# e - e
# hediondezas - hediondeza
# que - que
# encontraram - encontrar
# dispersos - disperso
#
#  -
#
# n'uma - n'uma
# só - só
# figura - figurar
# , - ,
# conseguem - conseguir
# apenas - apenas
# crear - crear
# ... - ...
# um - um
# monstro - monstro
# , - ,
# um - um
# ser - ser
# hybrido - hybrido
# e - e
#
#  -
#
# infecundo - infecundo
# que - que
# a - a
# ninguem - ninguem
# aproveita - aproveitar
# ! - !
#
#
#  -
#
#
# Os - o
# outros - outro
# synthetisando - synthetisar
# n'uma - n'um
# filha - filha
# do - de o
# seu - seu
# genio - genio
# as - o
# harmonias - harmonia
# , - ,
# as - o
#
#  -
#
# feições - feição
# , - ,
# os - o
# encantos - encanto
# , - ,
# que - que
# estudaram - estudarar
# e - e
# amaram - amar
# em - em
# toda - todo
# a - o
# natureza - natureza
# , - ,
#
#  -
#
# conseguiram - conseguir
# alguma - algum
# coisa - coisa
# mais - mais
# ! - !
#
#
#  -
#
#
# Crearam - Crearam
# o - o
# ideal - ideal
# immutavel - immutavel
# e - e
# eterno - eterno
# e - e
# ensinaram-nos - ensinaram-nos
# a - a
# fitar - fitar
# n'elle - n'elle
# os - o
#
#  -
#
# olhos - olho
# da - de o
# nossa - nosso
# alma - alma
# , - ,
# e - e
# a - o
# invocal-o - invocal-o
# como - como
# um - um
# consolo - consolo
# adoravel - adoravel
# nas - em o
# nossas - nosso
#
#  -
#
# horas - hora
# de - de
# desalento - desalento
# e - e
# de - de
# agonia - agonia
# . - .
